# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import japanize_matplotlib

# %%
CENSUS_POPULATION_PATH = 'data/FEH_00200521_250109010954.csv'
LG_CODE_PATH = 'data/000925835.xlsx'
TOKYO_ADMIN_PATH = 'data/shape/N03-20240101_13.geojson'

# %%
df_population = pd.read_csv(CENSUS_POPULATION_PATH, encoding='shift-jis', skiprows=14, dtype={'全国，都道府県，市区町村（人口集中地区） コード' : 'str'})
df_population
# Out:
#       時間軸（年次） コード  時間軸（年次） 補助コード 時間軸（年次）  国籍総数か日本人 コード  国籍総数か日本人 補助コード  \
# 0      2020000000            NaN   2020年             0             NaN
# 1      2020000000            NaN   2020年             0             NaN
# 2      2020000000            NaN   2020年             0             NaN
# 3      2020000000            NaN   2020年             0             NaN
# 4      2020000000            NaN   2020年             0             NaN
# ...           ...            ...     ...           ...             ...
# 6223   2020000000            NaN   2020年             1             NaN
# 6224   2020000000            NaN   2020年             1             NaN
# 6225   2020000000            NaN   2020年             1             NaN
# 6226   2020000000            NaN   2020年             1             NaN
# 6227   2020000000            NaN   2020年             1             NaN
#
#      国籍総数か日本人  男女 コード  男女 補助コード  男女 全国，都道府県，市区町村（人口集中地区） コード  ...  90〜94歳  \
# 0        国籍総数       0       NaN  総数                    00000  ...  983383
# 1        国籍総数       0       NaN  総数                    01000  ...   57245
# 2        国籍総数       0       NaN  総数                    01100  ...   25388
# 3        国籍総数       0       NaN  総数                    01101  ...    3176
# 4        国籍総数       0       NaN  総数                    01102  ...    3394
# ...       ...     ...       ...  ..                      ...  ...     ...
# 6223    うち日本人       2       NaN   女                    47328  ...      19
# 6224    うち日本人       2       NaN   女                    47329  ...      61
# 6225    うち日本人       2       NaN   女                    47348  ...     101
# 6226    うち日本人       2       NaN   女                    47350  ...     137
# 6227    うち日本人       2       NaN   女                    47362  ...      37
#
#       95〜99歳  100歳以上   年齢「不詳」  （再掲）15歳未満  （再掲）15〜64歳  （再掲）65歳以上  （再掲）75歳以上  \
# 0     253476   39738  2555614   10660791    52836316   22233206   11399430
# 1      15091    2263    52478     432950     2303957    1183622     587281
# 2       6645     993    30514     209256     1156977     519290     252071
# 3        800     113     9537      23694      156945      56397      27876
# 4        846     133     4328      32538      169440      73872      35192
# ...      ...     ...      ...        ...         ...        ...        ...
# 6223      14       1      149       1006        2782        399        172
# 6224      16       1        6        908        3201       1285        553
# 6225      40      12        6       1592        5186       1751        857
# 6226      40       8       15       3361        9927       2880       1317
# 6227      15       4       10       1334        3180        743        324
#
#       （再掲）85歳以上  （再掲）20〜69歳
# 0       3479063    53909973
# 1        194610     2419768
# 2         84863     1205248
# 3         10309      161415
# 4         11313      174756
# ...         ...         ...
# 6223         68        2666
# 6224        187        3334
# 6225        330        5229
# 6226        462        9983
# 6227        122        3154
#
# [6228 rows x 42 columns]

# %%
df_population.columns
# Out:
# Index(['時間軸（年次） コード', '時間軸（年次） 補助コード', '時間軸（年次）', '国籍総数か日本人 コード',
#        '国籍総数か日本人 補助コード', '国籍総数か日本人', '男女 コード', '男女 補助コード', '男女',
#        '全国，都道府県，市区町村（人口集中地区） コード', '全国，都道府県，市区町村（人口集中地区） 補助コード',
#        '全国，都道府県，市区町村（人口集中地区）', '/年齢', '総数', '0〜4歳', '5〜9歳', '10〜14歳', '15〜19歳',
#        '20〜24歳', '25〜29歳', '30〜34歳', '35〜39歳', '40〜44歳', '45〜49歳', '50〜54歳',
#        '55〜59歳', '60〜64歳', '65〜69歳', '70〜74歳', '75〜79歳', '80〜84歳', '85〜89歳',
#        '90〜94歳', '95〜99歳', '100歳以上', '年齢「不詳」', '（再掲）15歳未満', '（再掲）15〜64歳',
#        '（再掲）65歳以上', '（再掲）75歳以上', '（再掲）85歳以上', '（再掲）20〜69歳'],
#       dtype='object')

# %%
columns = ['総数', '0〜4歳', '5〜9歳', '10〜14歳', '15〜19歳',
       '20〜24歳', '25〜29歳', '30〜34歳', '35〜39歳', '40〜44歳', '45〜49歳', '50〜54歳',
       '55〜59歳', '60〜64歳', '65〜69歳', '70〜74歳', '75〜79歳', '80〜84歳', '85〜89歳',
       '90〜94歳', '95〜99歳', '100歳以上']

for column in columns:
    df_population[column] = df_population[column].apply(pd.to_numeric, errors='coerce').fillna(0)

# %%
df_population['young'] = (df_population['0〜4歳'] + df_population['5〜9歳'] + df_population['10〜14歳'] + df_population['15〜19歳']) / df_population['総数']
df_population
# Out:
#       時間軸（年次） コード  時間軸（年次） 補助コード 時間軸（年次）  国籍総数か日本人 コード  国籍総数か日本人 補助コード  \
# 0      2020000000            NaN   2020年             0             NaN
# 1      2020000000            NaN   2020年             0             NaN
# 2      2020000000            NaN   2020年             0             NaN
# 3      2020000000            NaN   2020年             0             NaN
# 4      2020000000            NaN   2020年             0             NaN
# ...           ...            ...     ...           ...             ...
# 6223   2020000000            NaN   2020年             1             NaN
# 6224   2020000000            NaN   2020年             1             NaN
# 6225   2020000000            NaN   2020年             1             NaN
# 6226   2020000000            NaN   2020年             1             NaN
# 6227   2020000000            NaN   2020年             1             NaN
#
#      国籍総数か日本人  男女 コード  男女 補助コード  男女 全国，都道府県，市区町村（人口集中地区） コード  ...    95〜99歳  \
# 0        国籍総数       0       NaN  総数                    00000  ...  253476.0
# 1        国籍総数       0       NaN  総数                    01000  ...   15091.0
# 2        国籍総数       0       NaN  総数                    01100  ...    6645.0
# 3        国籍総数       0       NaN  総数                    01101  ...     800.0
# 4        国籍総数       0       NaN  総数                    01102  ...     846.0
# ...       ...     ...       ...  ..                      ...  ...       ...
# 6223    うち日本人       2       NaN   女                    47328  ...      14.0
# 6224    うち日本人       2       NaN   女                    47329  ...      16.0
# 6225    うち日本人       2       NaN   女                    47348  ...      40.0
# 6226    うち日本人       2       NaN   女                    47350  ...      40.0
# 6227    うち日本人       2       NaN   女                    47362  ...      15.0
#
#        100歳以上   年齢「不詳」  （再掲）15歳未満  （再掲）15〜64歳  （再掲）65歳以上  （再掲）75歳以上  \
# 0     39738.0  2555614   10660791    52836316   22233206   11399430
# 1      2263.0    52478     432950     2303957    1183622     587281
# 2       993.0    30514     209256     1156977     519290     252071
# 3       113.0     9537      23694      156945      56397      27876
# 4       133.0     4328      32538      169440      73872      35192
# ...       ...      ...        ...         ...        ...        ...
# 6223      1.0      149       1006        2782        399        172
# 6224      1.0        6        908        3201       1285        553
# 6225     12.0        6       1592        5186       1751        857
# 6226      8.0       15       3361        9927       2880       1317
# 6227      4.0       10       1334        3180        743        324
#
#       （再掲）85歳以上  （再掲）20〜69歳     young
# 0       3479063    53909973  0.165756
# 1        194610     2419768  0.152529
# 2         84863     1205248  0.152123
# 3         10309      161415  0.134913
# 4         11313      174756  0.165024
# ...         ...         ...       ...
# 6223         68        2666  0.291052
# 6224        187        3334  0.221852
# 6225        330        5229  0.239836
# 6226        462        9983  0.257863
# 6227        122        3154  0.308525
#
# [6228 rows x 43 columns]

# %%
df_population = df_population[(df_population['男女'] == '総数') & (df_population['国籍総数か日本人'] == '国籍総数')]
df_population
# Out:
#       時間軸（年次） コード  時間軸（年次） 補助コード 時間軸（年次）  国籍総数か日本人 コード  国籍総数か日本人 補助コード  \
# 0      2020000000            NaN   2020年             0             NaN
# 1      2020000000            NaN   2020年             0             NaN
# 2      2020000000            NaN   2020年             0             NaN
# 3      2020000000            NaN   2020年             0             NaN
# 4      2020000000            NaN   2020年             0             NaN
# ...           ...            ...     ...           ...             ...
# 1033   2020000000            NaN   2020年             0             NaN
# 1034   2020000000            NaN   2020年             0             NaN
# 1035   2020000000            NaN   2020年             0             NaN
# 1036   2020000000            NaN   2020年             0             NaN
# 1037   2020000000            NaN   2020年             0             NaN
#
#      国籍総数か日本人  男女 コード  男女 補助コード  男女 全国，都道府県，市区町村（人口集中地区） コード  ...    95〜99歳  \
# 0        国籍総数       0       NaN  総数                    00000  ...  253476.0
# 1        国籍総数       0       NaN  総数                    01000  ...   15091.0
# 2        国籍総数       0       NaN  総数                    01100  ...    6645.0
# 3        国籍総数       0       NaN  総数                    01101  ...     800.0
# 4        国籍総数       0       NaN  総数                    01102  ...     846.0
# ...       ...     ...       ...  ..                      ...  ...       ...
# 1033     国籍総数       0       NaN  総数                    47328  ...      16.0
# 1034     国籍総数       0       NaN  総数                    47329  ...      20.0
# 1035     国籍総数       0       NaN  総数                    47348  ...      49.0
# 1036     国籍総数       0       NaN  総数                    47350  ...      46.0
# 1037     国籍総数       0       NaN  総数                    47362  ...      17.0
#
#        100歳以上   年齢「不詳」  （再掲）15歳未満  （再掲）15〜64歳  （再掲）65歳以上  （再掲）75歳以上  \
# 0     39738.0  2555614   10660791    52836316   22233206   11399430
# 1      2263.0    52478     432950     2303957    1183622     587281
# 2       993.0    30514     209256     1156977     519290     252071
# 3       113.0     9537      23694      156945      56397      27876
# 4       133.0     4328      32538      169440      73872      35192
# ...       ...      ...        ...         ...        ...        ...
# 1033      1.0      849       2092        5648        720        295
# 1034      2.0      104       1930        6482       2440        995
# 1035     13.0      270       3343       10150       3168       1413
# 1036     10.0      265       6875       19493       5332       2324
# 1037      5.0       17       2702        6121       1402        552
#
#       （再掲）85歳以上  （再掲）20〜69歳     young
# 0       3479063    53909973  0.165756
# 1        194610     2419768  0.152529
# 2         84863     1205248  0.152123
# 3         10309      161415  0.134913
# 4         11313      174756  0.165024
# ...         ...         ...       ...
# 1033         97        5387  0.280696
# 1034        304        6699  0.231745
# 1035        479       10242  0.250133
# 1036        694       19512  0.267105
# 1037        182        6044  0.321031
#
# [1038 rows x 43 columns]

# %%
df_population = df_population.rename(columns={
    '全国，都道府県，市区町村（人口集中地区） コード': 'code',
    '全国，都道府県，市区町村（人口集中地区）': 'name'
})

df_population = df_population[['code', 'name', 'young']]
df_population
# Out:
#        code    name     young
# 0     00000      全国  0.165756
# 1     01000     北海道  0.152529
# 2     01100     札幌市  0.152123
# 3     01101  札幌市中央区  0.134913
# 4     01102   札幌市北区  0.165024
# ...     ...     ...       ...
# 1033  47328     中城村  0.280696
# 1034  47329     西原町  0.231745
# 1035  47348    与那原町  0.250133
# 1036  47350    南風原町  0.267105
# 1037  47362    八重瀬町  0.321031
#
# [1038 rows x 3 columns]

# %%
df_lg = pd.read_excel(LG_CODE_PATH, dtype=str)
df_lg
# Out:
#        団体コード 都道府県名\n（漢字） 市区町村名\n（漢字） 都道府県名\n（カナ） 市区町村名\n（カナ）
# 0     010006         北海道         NaN     ﾎｯｶｲﾄﾞｳ         NaN
# 1     011002         北海道         札幌市     ﾎｯｶｲﾄﾞｳ      ｻｯﾎﾟﾛｼ
# 2     012025         北海道         函館市     ﾎｯｶｲﾄﾞｳ      ﾊｺﾀﾞﾃｼ
# 3     012033         北海道         小樽市     ﾎｯｶｲﾄﾞｳ        ｵﾀﾙｼ
# 4     012041         北海道         旭川市     ﾎｯｶｲﾄﾞｳ      ｱｻﾋｶﾜｼ
# ...      ...         ...         ...         ...         ...
# 1789  473618         沖縄県        久米島町      ｵｷﾅﾜｹﾝ    ｸﾒｼﾞﾏﾁｮｳ
# 1790  473626         沖縄県        八重瀬町      ｵｷﾅﾜｹﾝ      ﾔｴｾﾁｮｳ
# 1791  473758         沖縄県        多良間村      ｵｷﾅﾜｹﾝ       ﾀﾗﾏｿﾝ
# 1792  473812         沖縄県         竹富町      ｵｷﾅﾜｹﾝ     ﾀｹﾄﾐﾁｮｳ
# 1793  473821         沖縄県        与那国町      ｵｷﾅﾜｹﾝ    ﾖﾅｸﾞﾆﾁｮｳ
#
# [1794 rows x 5 columns]

# %%
df_lg = df_lg.rename(columns = {
    '団体コード': 'code',
    '都道府県名\n（漢字）': 'prefecture',
    '市区町村名\n（漢字）': 'city'
})
df_lg = df_lg[['code', 'prefecture', 'city']]
df_lg
# Out:
#         code prefecture  city
# 0     010006        北海道   NaN
# 1     011002        北海道   札幌市
# 2     012025        北海道   函館市
# 3     012033        北海道   小樽市
# 4     012041        北海道   旭川市
# ...      ...        ...   ...
# 1789  473618        沖縄県  久米島町
# 1790  473626        沖縄県  八重瀬町
# 1791  473758        沖縄県  多良間村
# 1792  473812        沖縄県   竹富町
# 1793  473821        沖縄県  与那国町
#
# [1794 rows x 3 columns]

# %%
df_lg['code'] = df_lg['code'].apply(lambda x: x[:5])
df_lg = df_lg[~df_lg['code'].str.endswith('000')]
df_lg
# Out:
#        code prefecture  city
# 1     01100        北海道   札幌市
# 2     01202        北海道   函館市
# 3     01203        北海道   小樽市
# 4     01204        北海道   旭川市
# 5     01205        北海道   室蘭市
# ...     ...        ...   ...
# 1789  47361        沖縄県  久米島町
# 1790  47362        沖縄県  八重瀬町
# 1791  47375        沖縄県  多良間村
# 1792  47381        沖縄県   竹富町
# 1793  47382        沖縄県  与那国町
#
# [1747 rows x 3 columns]

# %%
df_lg_population = df_population.merge(df_lg, how='inner')
df_lg_population
# Out:
#       code  name     young prefecture  city
# 0    01100   札幌市  0.152123        北海道   札幌市
# 1    01202   函館市  0.136903        北海道   函館市
# 2    01203   小樽市  0.126287        北海道   小樽市
# 3    01204   旭川市  0.148517        北海道   旭川市
# 4    01205   室蘭市  0.145401        北海道   室蘭市
# ..     ...   ...       ...        ...   ...
# 810  47328   中城村  0.280696        沖縄県   中城村
# 811  47329   西原町  0.231745        沖縄県   西原町
# 812  47348  与那原町  0.250133        沖縄県  与那原町
# 813  47350  南風原町  0.267105        沖縄県  南風原町
# 814  47362  八重瀬町  0.321031        沖縄県  八重瀬町
#
# [815 rows x 5 columns]

# %%
df_lg_population.sort_values('young', ascending=False)
# Out:
#       code     name     young prefecture     city
# 814  47362     八重瀬町  0.321031        沖縄県     八重瀬町
# 493  23441     阿久比町  0.319372        愛知県     阿久比町
# 810  47328      中城村  0.280696        沖縄県      中城村
# 733  40345      新宮町  0.273934        福岡県      新宮町
# 140  08235  つくばみらい市  0.273517        茨城県  つくばみらい市
# ..     ...      ...       ...        ...      ...
# 22   01226      砂川市  0.104908        北海道      砂川市
# 572  27321      豊能町  0.097152        大阪府      豊能町
# 610  29207      五條市  0.091867        奈良県      五條市
# 428  22205      熱海市  0.084222        静岡県      熱海市
# 220  11348      鳩山町  0.080291        埼玉県      鳩山町
#
# [815 rows x 5 columns]

# %%
gdf_tokyo_admin = gpd.read_file(TOKYO_ADMIN_PATH)
gdf_tokyo_admin
# Out:
#      N03_001 N03_002 N03_003 N03_004 N03_005 N03_007  \
# 0        東京都    None    None   所属未定地    None   13000
# 1        東京都    None    None   所属未定地    None   13000
# 2        東京都    None    None   所属未定地    None   13000
# 3        東京都    None    None   所属未定地    None   13000
# 4        東京都    None    None   所属未定地    None   13000
# ...      ...     ...     ...     ...     ...     ...
# 6899     東京都    None    None    小笠原村    None   13421
# 6900     東京都    None    None    小笠原村    None   13421
# 6901     東京都    None    None    小笠原村    None   13421
# 6902     東京都    None    None    小笠原村    None   13421
# 6903     東京都    None    None    小笠原村    None   13421
#
#                                                geometry
# 0     POLYGON ((140.28925 30.48135, 140.28968 30.480...
# 1     POLYGON ((139.82167 35.58322, 139.82187 35.583...
# 2     POLYGON ((139.84130 35.64702, 139.84129 35.646...
# 3     POLYGON ((140.05004 31.43993, 140.05002 31.439...
# 4     POLYGON ((140.34167 29.79385, 140.34174 29.793...
# ...                                                 ...
# 6899  POLYGON ((141.28634 24.79924, 141.28633 24.799...
# 6900  POLYGON ((141.29279 24.74890, 141.29278 24.748...
# 6901  POLYGON ((141.37959 24.78060, 141.37958 24.780...
# 6902  POLYGON ((141.29002 24.74740, 141.29002 24.747...
# 6903  POLYGON ((141.37960 24.78061, 141.37961 24.780...
#
# [6904 rows x 7 columns]

# %%
gdf_tokyo_admin_grouped = gdf_tokyo_admin.dissolve(by='N03_007')
gdf_tokyo_admin_grouped = gdf_tokyo_admin_grouped.reset_index()
gdf_tokyo_admin_grouped
# Out:
#    N03_007                                           geometry N03_001 N03_002  \
# 0    13000  MULTIPOLYGON (((140.34167 29.79385, 140.34161 ...     東京都    None
# 1    13101  POLYGON ((139.77287 35.70370, 139.77287 35.703...     東京都    None
# 2    13102  POLYGON ((139.78341 35.69645, 139.78334 35.696...     東京都    None
# 3    13103  MULTIPOLYGON (((139.77115 35.62838, 139.77115 ...     東京都    None
# 4    13104  POLYGON ((139.73333 35.70770, 139.73321 35.707...     東京都    None
# ..     ...                                                ...     ...     ...
# 58   13381  MULTIPOLYGON (((139.38455 34.04434, 139.38458 ...     東京都    None
# 59   13382  MULTIPOLYGON (((139.29851 33.65146, 139.29837 ...     東京都    None
# 60   13401  MULTIPOLYGON (((139.83879 33.04832, 139.83878 ...     東京都    None
# 61   13402  MULTIPOLYGON (((139.76717 32.44306, 139.76718 ...     東京都    None
# 62   13421  MULTIPOLYGON (((136.07369 20.42317, 136.07373 ...     東京都    None
#
#    N03_003 N03_004 N03_005
# 0     None   所属未定地    None
# 1     None    千代田区    None
# 2     None     中央区    None
# 3     None      港区    None
# 4     None     新宿区    None
# ..     ...     ...     ...
# 58    None     三宅村    None
# 59    None    御蔵島村    None
# 60    None     八丈町    None
# 61    None    青ヶ島村    None
# 62    None    小笠原村    None
#
# [63 rows x 7 columns]

# %%
gdf_tokyo_population = gdf_tokyo_admin_grouped.merge(df_population, left_on='N03_007', right_on='code')
gdf_tokyo_population
# Out:
#    N03_007                                           geometry N03_001 N03_002  \
# 0    13000  MULTIPOLYGON (((140.34167 29.79385, 140.34161 ...     東京都    None
# 1    13101  POLYGON ((139.77287 35.70370, 139.77287 35.703...     東京都    None
# 2    13102  POLYGON ((139.78341 35.69645, 139.78334 35.696...     東京都    None
# 3    13103  MULTIPOLYGON (((139.77115 35.62838, 139.77115 ...     東京都    None
# 4    13104  POLYGON ((139.73333 35.70770, 139.73321 35.707...     東京都    None
# 5    13105  POLYGON ((139.75000 35.73338, 139.75000 35.733...     東京都    None
# 6    13106  POLYGON ((139.76667 35.71330, 139.76667 35.713...     東京都    None
# 7    13107  POLYGON ((139.79517 35.70466, 139.79500 35.704...     東京都    None
# 8    13108  MULTIPOLYGON (((139.79859 35.59561, 139.79861 ...     東京都    None
# 9    13109  MULTIPOLYGON (((139.74949 35.59155, 139.74951 ...     東京都    None
# 10   13110  POLYGON ((139.68053 35.60445, 139.68054 35.604...     東京都    None
# 11   13111  MULTIPOLYGON (((139.80834 35.53221, 139.80960 ...     東京都    None
# 12   13112  POLYGON ((139.62930 35.60800, 139.62940 35.607...     東京都    None
# 13   13113  POLYGON ((139.71102 35.66637, 139.71128 35.666...     東京都    None
# 14   13114  POLYGON ((139.67457 35.72124, 139.67458 35.721...     東京都    None
# 15   13115  POLYGON ((139.64076 35.66664, 139.64081 35.666...     東京都    None
# 16   13116  POLYGON ((139.68226 35.72472, 139.68229 35.724...     東京都    None
# 17   13117  POLYGON ((139.75694 35.73333, 139.75788 35.732...     東京都    None
# 18   13118  POLYGON ((139.75734 35.74561, 139.75720 35.745...     東京都    None
# 19   13119  POLYGON ((139.67325 35.74779, 139.67317 35.747...     東京都    None
# 20   13120  POLYGON ((139.56569 35.72264, 139.56568 35.722...     東京都    None
# 21   13121  POLYGON ((139.81650 35.75000, 139.81650 35.750...     東京都    None
# 22   13122  POLYGON ((139.81650 35.75000, 139.81650 35.750...     東京都    None
# 23   13123  MULTIPOLYGON (((139.87146 35.63864, 139.87073 ...     東京都    None
# 24   13201  POLYGON ((139.37981 35.60248, 139.37995 35.602...     東京都    None
# 25   13202  POLYGON ((139.37883 35.72496, 139.37891 35.725...     東京都    None
# 26   13203  POLYGON ((139.53228 35.70548, 139.53228 35.705...     東京都    None
# 27   13204  POLYGON ((139.56659 35.66397, 139.56667 35.663...     東京都    None
# 28   13205  POLYGON ((139.29710 35.75751, 139.29716 35.757...     東京都    None
# 29   13206  MULTIPOLYGON (((139.52100 35.64978, 139.52101 ...     東京都    None
# 30   13207  POLYGON ((139.37500 35.72517, 139.37500 35.725...     東京都    None
# 31   13208  POLYGON ((139.58781 35.64610, 139.58786 35.646...     東京都    None
# 32   13209  POLYGON ((139.39990 35.58179, 139.39995 35.581...     東京都    None
# 33   13210  POLYGON ((139.48940 35.70827, 139.48888 35.708...     東京都    None
# 34   13211  POLYGON ((139.42780 35.73002, 139.42644 35.730...     東京都    None
# 35   13212  POLYGON ((139.37789 35.64105, 139.37772 35.641...     東京都    None
# 36   13213  POLYGON ((139.44852 35.74910, 139.44851 35.749...     東京都    None
# 37   13214  POLYGON ((139.43032 35.70354, 139.43079 35.702...     東京都    None
# 38   13215  POLYGON ((139.45396 35.68867, 139.45402 35.688...     東京都    None
# 39   13218  POLYGON ((139.31476 35.74764, 139.31387 35.747...     東京都    None
# 40   13219  POLYGON ((139.56197 35.63259, 139.56247 35.632...     東京都    None
# 41   13220  POLYGON ((139.40774 35.74860, 139.40833 35.748...     東京都    None
# 42   13221  POLYGON ((139.49723 35.76282, 139.49720 35.762...     東京都    None
# 43   13222  POLYGON ((139.50452 35.73333, 139.50450 35.733...     東京都    None
# 44   13223  POLYGON ((139.40741 35.74980, 139.40740 35.750...     東京都    None
# 45   13224  POLYGON ((139.39390 35.60819, 139.39402 35.608...     東京都    None
# 46   13225  MULTIPOLYGON (((139.50002 35.60728, 139.50000 ...     東京都    None
# 47   13227  POLYGON ((139.31826 35.74990, 139.31833 35.750...     東京都    None
# 48   13228  POLYGON ((139.21271 35.74977, 139.21276 35.749...     東京都    None
# 49   13229  POLYGON ((139.52109 35.72500, 139.52146 35.724...     東京都    None
# 50   13303  MULTIPOLYGON (((139.35725 35.74574, 139.35757 ...     東京都    None
#
#    N03_003 N03_004 N03_005   code   name     young
# 0     None   所属未定地    None  13000    東京都  0.150268
# 1     None    千代田区    None  13101   千代田区  0.167516
# 2     None     中央区    None  13102    中央区  0.160564
# 3     None      港区    None  13103     港区  0.160773
# 4     None     新宿区    None  13104    新宿区  0.110737
# 5     None     文京区    None  13105    文京区  0.149944
# 6     None     台東区    None  13106    台東区  0.114782
# 7     None     墨田区    None  13107    墨田区  0.134642
# 8     None     江東区    None  13108    江東区  0.162703
# 9     None     品川区    None  13109    品川区  0.139803
# 10    None     目黒区    None  13110    目黒区  0.140603
# 11    None     大田区    None  13111    大田区  0.138851
# 12    None    世田谷区    None  13112   世田谷区  0.154478
# 13    None     渋谷区    None  13113    渋谷区  0.118950
# 14    None     中野区    None  13114    中野区  0.112886
# 15    None     杉並区    None  13115    杉並区  0.132132
# 16    None     豊島区    None  13116    豊島区  0.117858
# 17    None      北区    None  13117     北区  0.135887
# 18    None     荒川区    None  13118    荒川区  0.149047
# 19    None     板橋区    None  13119    板橋区  0.139534
# 20    None     練馬区    None  13120    練馬区  0.155757
# 21    None     足立区    None  13121    足立区  0.148771
# 22    None     葛飾区    None  13122    葛飾区  0.153664
# 23    None    江戸川区    None  13123   江戸川区  0.170068
# 24    None    八王子市    None  13201   八王子市  0.161852
# 25    None     立川市    None  13202    立川市  0.162858
# 26    None    武蔵野市    None  13203   武蔵野市  0.151609
# 27    None     三鷹市    None  13204    三鷹市  0.162566
# 28    None     青梅市    None  13205    青梅市  0.155468
# 29    None     府中市    None  13206    府中市  0.172571
# 30    None     昭島市    None  13207    昭島市  0.161340
# 31    None     調布市    None  13208    調布市  0.160156
# 32    None     町田市    None  13209    町田市  0.170968
# 33    None    小金井市    None  13210   小金井市  0.161802
# 34    None     小平市    None  13211    小平市  0.173373
# 35    None     日野市    None  13212    日野市  0.166243
# 36    None    東村山市    None  13213   東村山市  0.162215
# 37    None    国分寺市    None  13214   国分寺市  0.160234
# 38    None     国立市    None  13215    国立市  0.155204
# 39    None     福生市    None  13218    福生市  0.141920
# 40    None     狛江市    None  13219    狛江市  0.153860
# 41    None    東大和市    None  13220   東大和市  0.173914
# 42    None     清瀬市    None  13221    清瀬市  0.160840
# 43    None   東久留米市    None  13222  東久留米市  0.165428
# 44    None   武蔵村山市    None  13223  武蔵村山市  0.187664
# 45    None     多摩市    None  13224    多摩市  0.158817
# 46    None     稲城市    None  13225    稲城市  0.192658
# 47    None     羽村市    None  13227    羽村市  0.170118
# 48    None   あきる野市    None  13228  あきる野市  0.170780
# 49    None    西東京市    None  13229   西東京市  0.165410
# 50    西多摩郡     瑞穂町    None  13303    瑞穂町  0.160056

# %%
min_lon, min_lat = 138.0, 35.0
max_lon, max_lat = 140.0, 36.0
   
bbox_polygon = Polygon([(min_lon, min_lat), (min_lon, max_lat), (max_lon, max_lat), (max_lon, min_lat)])

# %%
gdf_tokyo_population_clipped = gdf_tokyo_population[gdf_tokyo_population.within(bbox_polygon)]
gdf_tokyo_population_clipped
# Out:
#    N03_007                                           geometry N03_001 N03_002  \
# 1    13101  POLYGON ((139.77287 35.70370, 139.77287 35.703...     東京都    None
# 2    13102  POLYGON ((139.78341 35.69645, 139.78334 35.696...     東京都    None
# 3    13103  MULTIPOLYGON (((139.77115 35.62838, 139.77115 ...     東京都    None
# 4    13104  POLYGON ((139.73333 35.70770, 139.73321 35.707...     東京都    None
# 5    13105  POLYGON ((139.75000 35.73338, 139.75000 35.733...     東京都    None
# 6    13106  POLYGON ((139.76667 35.71330, 139.76667 35.713...     東京都    None
# 7    13107  POLYGON ((139.79517 35.70466, 139.79500 35.704...     東京都    None
# 8    13108  MULTIPOLYGON (((139.79859 35.59561, 139.79861 ...     東京都    None
# 9    13109  MULTIPOLYGON (((139.74949 35.59155, 139.74951 ...     東京都    None
# 10   13110  POLYGON ((139.68053 35.60445, 139.68054 35.604...     東京都    None
# 11   13111  MULTIPOLYGON (((139.80834 35.53221, 139.80960 ...     東京都    None
# 12   13112  POLYGON ((139.62930 35.60800, 139.62940 35.607...     東京都    None
# 13   13113  POLYGON ((139.71102 35.66637, 139.71128 35.666...     東京都    None
# 14   13114  POLYGON ((139.67457 35.72124, 139.67458 35.721...     東京都    None
# 15   13115  POLYGON ((139.64076 35.66664, 139.64081 35.666...     東京都    None
# 16   13116  POLYGON ((139.68226 35.72472, 139.68229 35.724...     東京都    None
# 17   13117  POLYGON ((139.75694 35.73333, 139.75788 35.732...     東京都    None
# 18   13118  POLYGON ((139.75734 35.74561, 139.75720 35.745...     東京都    None
# 19   13119  POLYGON ((139.67325 35.74779, 139.67317 35.747...     東京都    None
# 20   13120  POLYGON ((139.56569 35.72264, 139.56568 35.722...     東京都    None
# 21   13121  POLYGON ((139.81650 35.75000, 139.81650 35.750...     東京都    None
# 22   13122  POLYGON ((139.81650 35.75000, 139.81650 35.750...     東京都    None
# 23   13123  MULTIPOLYGON (((139.87146 35.63864, 139.87073 ...     東京都    None
# 24   13201  POLYGON ((139.37981 35.60248, 139.37995 35.602...     東京都    None
# 25   13202  POLYGON ((139.37883 35.72496, 139.37891 35.725...     東京都    None
# 26   13203  POLYGON ((139.53228 35.70548, 139.53228 35.705...     東京都    None
# 27   13204  POLYGON ((139.56659 35.66397, 139.56667 35.663...     東京都    None
# 28   13205  POLYGON ((139.29710 35.75751, 139.29716 35.757...     東京都    None
# 29   13206  MULTIPOLYGON (((139.52100 35.64978, 139.52101 ...     東京都    None
# 30   13207  POLYGON ((139.37500 35.72517, 139.37500 35.725...     東京都    None
# 31   13208  POLYGON ((139.58781 35.64610, 139.58786 35.646...     東京都    None
# 32   13209  POLYGON ((139.39990 35.58179, 139.39995 35.581...     東京都    None
# 33   13210  POLYGON ((139.48940 35.70827, 139.48888 35.708...     東京都    None
# 34   13211  POLYGON ((139.42780 35.73002, 139.42644 35.730...     東京都    None
# 35   13212  POLYGON ((139.37789 35.64105, 139.37772 35.641...     東京都    None
# 36   13213  POLYGON ((139.44852 35.74910, 139.44851 35.749...     東京都    None
# 37   13214  POLYGON ((139.43032 35.70354, 139.43079 35.702...     東京都    None
# 38   13215  POLYGON ((139.45396 35.68867, 139.45402 35.688...     東京都    None
# 39   13218  POLYGON ((139.31476 35.74764, 139.31387 35.747...     東京都    None
# 40   13219  POLYGON ((139.56197 35.63259, 139.56247 35.632...     東京都    None
# 41   13220  POLYGON ((139.40774 35.74860, 139.40833 35.748...     東京都    None
# 42   13221  POLYGON ((139.49723 35.76282, 139.49720 35.762...     東京都    None
# 43   13222  POLYGON ((139.50452 35.73333, 139.50450 35.733...     東京都    None
# 44   13223  POLYGON ((139.40741 35.74980, 139.40740 35.750...     東京都    None
# 45   13224  POLYGON ((139.39390 35.60819, 139.39402 35.608...     東京都    None
# 46   13225  MULTIPOLYGON (((139.50002 35.60728, 139.50000 ...     東京都    None
# 47   13227  POLYGON ((139.31826 35.74990, 139.31833 35.750...     東京都    None
# 48   13228  POLYGON ((139.21271 35.74977, 139.21276 35.749...     東京都    None
# 49   13229  POLYGON ((139.52109 35.72500, 139.52146 35.724...     東京都    None
# 50   13303  MULTIPOLYGON (((139.35725 35.74574, 139.35757 ...     東京都    None
#
#    N03_003 N03_004 N03_005   code   name     young
# 1     None    千代田区    None  13101   千代田区  0.167516
# 2     None     中央区    None  13102    中央区  0.160564
# 3     None      港区    None  13103     港区  0.160773
# 4     None     新宿区    None  13104    新宿区  0.110737
# 5     None     文京区    None  13105    文京区  0.149944
# 6     None     台東区    None  13106    台東区  0.114782
# 7     None     墨田区    None  13107    墨田区  0.134642
# 8     None     江東区    None  13108    江東区  0.162703
# 9     None     品川区    None  13109    品川区  0.139803
# 10    None     目黒区    None  13110    目黒区  0.140603
# 11    None     大田区    None  13111    大田区  0.138851
# 12    None    世田谷区    None  13112   世田谷区  0.154478
# 13    None     渋谷区    None  13113    渋谷区  0.118950
# 14    None     中野区    None  13114    中野区  0.112886
# 15    None     杉並区    None  13115    杉並区  0.132132
# 16    None     豊島区    None  13116    豊島区  0.117858
# 17    None      北区    None  13117     北区  0.135887
# 18    None     荒川区    None  13118    荒川区  0.149047
# 19    None     板橋区    None  13119    板橋区  0.139534
# 20    None     練馬区    None  13120    練馬区  0.155757
# 21    None     足立区    None  13121    足立区  0.148771
# 22    None     葛飾区    None  13122    葛飾区  0.153664
# 23    None    江戸川区    None  13123   江戸川区  0.170068
# 24    None    八王子市    None  13201   八王子市  0.161852
# 25    None     立川市    None  13202    立川市  0.162858
# 26    None    武蔵野市    None  13203   武蔵野市  0.151609
# 27    None     三鷹市    None  13204    三鷹市  0.162566
# 28    None     青梅市    None  13205    青梅市  0.155468
# 29    None     府中市    None  13206    府中市  0.172571
# 30    None     昭島市    None  13207    昭島市  0.161340
# 31    None     調布市    None  13208    調布市  0.160156
# 32    None     町田市    None  13209    町田市  0.170968
# 33    None    小金井市    None  13210   小金井市  0.161802
# 34    None     小平市    None  13211    小平市  0.173373
# 35    None     日野市    None  13212    日野市  0.166243
# 36    None    東村山市    None  13213   東村山市  0.162215
# 37    None    国分寺市    None  13214   国分寺市  0.160234
# 38    None     国立市    None  13215    国立市  0.155204
# 39    None     福生市    None  13218    福生市  0.141920
# 40    None     狛江市    None  13219    狛江市  0.153860
# 41    None    東大和市    None  13220   東大和市  0.173914
# 42    None     清瀬市    None  13221    清瀬市  0.160840
# 43    None   東久留米市    None  13222  東久留米市  0.165428
# 44    None   武蔵村山市    None  13223  武蔵村山市  0.187664
# 45    None     多摩市    None  13224    多摩市  0.158817
# 46    None     稲城市    None  13225    稲城市  0.192658
# 47    None     羽村市    None  13227    羽村市  0.170118
# 48    None   あきる野市    None  13228  あきる野市  0.170780
# 49    None    西東京市    None  13229   西東京市  0.165410
# 50    西多摩郡     瑞穂町    None  13303    瑞穂町  0.160056

# %%
gdf_tokyo_population_clipped.plot(column='young', cmap='OrRd', legend=True, figsize=(20,4))
# Out:
# <Axes: >
