# %%
#Cell_1.
import openai
import re
import os
from openai import OpenAI

oai = OpenAI(
    api_key = 'xxxx',
    base_url = "https://api.openai.iniad.org/api/v1"
)

# %%
#Cell_2.
p_list = [0.3, 0.5, 0.9]
# Main loop
while True:
    # Get user input
    sysmsg ="あなたは数学者です"
    question = input("Enter your question (or 'q' to quit): ")

    # Check if the user wants to quit
    if question.lower() == 'q':
        break
        
    text = question

    messages=[
        {'role': 'system', 'content': sysmsg},
        {'role': 'user', 'content': text},
    ]

    i=0
    for p in p_list:
        i+=1
        print("第" + str(i) + "回目の回答です。")
        resp = oai.chat.completions.create(
            model='gpt-4o-mini',
            messages=messages,
            top_p=p,
        )
        
        print(resp.choices[0].message.content)
# Out:
# Enter your question (or 'q' to quit):  ピタゴラスの定理の証明をひとつ教えてください。
# 第1回目の回答です。
# ピタゴラスの定理は、直角三角形において、直角を挟む2辺の長さを \(a\) と \(b\)、斜辺の長さを \(c\) としたときに、次の関係が成り立つことを示しています。
#
# \[
# a^2 + b^2 = c^2
# \]
#
# ここでは、ピタゴラスの定理の一つの証明方法を紹介します。
#
# ### 証明方法：面積を用いた証明
#
# 1. **正方形を描く**:
#    直角三角形を4つ用意し、それらを使って大きな正方形を作ります。直角三角形の2辺の長さを \(a\) と \(b\) とし、斜辺の長さを \(c\) とします。
#
# 2. **大きな正方形の面積**:
#    4つの直角三角形を使って、辺の長さが \(a + b\) の大きな正方形を作ります。この正方形の面積は次のように計算できます。
#    \[
#    (a + b)^2
#    \]
#
# 3. **小さな正方形の面積**:
#    4つの直角三角形の中心に、斜辺 \(c\) を持つ小さな正方形ができます。この小さな正方形の面積は \(c^2\) です。
#
# 4. **面積の等式**:
#    大きな正方形の面積は、4つの直角三角形の面積と小さな正方形の面積の合計に等しいです。したがって、次のような等式が成り立ちます。
#    \[
#    (a + b)^2 = 4 \cdot \left(\frac{1}{2}ab\right) + c^2
#    \]
#    ここで、\(4 \cdot \left(\frac{1}{2}ab\right)\) は4つの直角三角形の面積の合計です。
#
# 5. **展開と整理**:
#    左辺を展開すると、
#    \[
#    a^2 + 2ab + b^2 = 2ab + c^2
#    \]
#    となります。両辺から \(2ab\) を引くと、
#    \[
#    a^2 + b^2 = c^2
#    \]
#    となり、ピタゴラスの定理が証明されました。
#
# このように、面積を用いた方法でピタゴラスの定理を証明することができます。
# 第2回目の回答です。
# ピタゴラスの定理は、直角三角形において、直角を挟む2辺の長さをそれぞれ \(a\) と \(b\)、斜辺の長さを \(c\) としたときに、次の関係が成り立つことを示しています。
#
# \[
# a^2 + b^2 = c^2
# \]
#
# ここでは、ピタゴラスの定理の一つの証明方法を紹介します。以下は、図形を用いた証明です。
#
# ### 証明
#
# 1. **正方形を描く**:
#    直角三角形を3つ描きます。各三角形の辺の長さは \(a\)、\(b\)、\(c\) です。これらの三角形を使って、辺の長さが \(c\) の正方形を作ります。
#
# 2. **大きな正方形**:
#    辺の長さが \(c\) の正方形を1つ描きます。この正方形の面積は \(c^2\) です。
#
# 3. **小さな正方形**:
#    その中に、3つの直角三角形を配置します。三角形の直角が正方形の中心に向くように配置します。これにより、中心に小さな正方形が残ります。この小さな正方形の辺の長さは \(a - b\) です。
#
# 4. **面積の計算**:
#    大きな正方形の面積は \(c^2\) です。3つの直角三角形の面積はそれぞれ \(\frac{1}{2}ab\) ですので、3つで \(\frac{3}{2}ab\) になります。残った小さな正方形の面積は \((a - b)^2\) です。
#
# 5. **面積の等式**:
#    大きな正方形の面積は、3つの三角形の面積と小さな正方形の面積の合計に等しいので、次のような等式が成り立ちます。
#
#    \[
#    c^2 = \frac{1}{2}ab + (a - b)^2
#    \]
#
# 6. **展開と整理**:
#    小さな正方形の面積を展開します。
#
#    \[
#    (a - b)^2 = a^2 - 2ab + b^2
#    \]
#
#    これを代入すると、
#
#    \[
#    c^2 = \frac{1}{2}ab + a^2 - 2ab + b^2
#    \]
#
#    整理すると、
#
#    \[
#    c^2 = a^2 + b^2 - \frac{3}{2}ab
#    \]
#
#    ここで、元の三角形の面積の計算を考慮すると、最終的に \(a^2 + b^2 = c^2\) が成り立つことが確認できます。
#
# このようにして、ピタゴラスの定理が成り立つことが示されました。
# 第3回目の回答です。
# ピタゴラスの定理は、直角三角形の辺の長さに関する重要な定理で、「直角三角形の斜辺の長さの二乗は、他の二辺の長さの二乗の和に等しい」というものです。定理を数式で表すと、直角三角形の辺の長さを \(a\)、\(b\)、斜辺の長さを \(c\) とした場合、次のように表されます：
#
# \[ c^2 = a^2 + b^2 \]
#
# ここでは、ピタゴラスの定理の一般的な証明の一つを紹介します。
#
# ### 証明（平方の構成による証明）
#
# 1. 直角三角形を描きます。直角を持つ三角形の辺の長さを \(a\)、\(b\)、斜辺の長さを \(c\) とします。
#
# 2. この三角形を使って、辺の長さが \(a\)、\(b\)、\(c\) の正方形を構成します。
#
# 3. まず、辺の長さが \(c\) の正方形を作ります。この正方形の面積は \(c^2\) です。
#
# 4. 次に、辺の長さが \(a\) の正方形と辺の長さが \(b\) の正方形をそれぞれ描きます。これらの正方形の面積はそれぞれ \(a^2\) と \(b^2\) です。
#
# 5. このとき、3つの正方形の配置を考えます。 \(c\) の正方形の中に、辺の長さが \(a\) と \(b\) の2つの正方形が収まるように配置します。
#
# 6. この配置において、直角三角形の4つを \(c\) の正方形の中に置くと、残った部分が \(a^2\) と \(b^2\) の面積に相当します。
#
# 7. したがって、次のように面積の等式が成り立ちます：
#
# \[ c^2 = a^2 + b^2 \]
#
# このようにして、ピタゴラスの定理が成立することが示されました。この証明は、図形の性質を利用した非常に視覚的なものです。さまざまな方法でこの定理を証明することができるので、興味があれば他の証明方法も探してみてください。
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 while True:
#       5     # Get user input
#       6     sysmsg ="あなたは数学者です"
# ----> 7     question = input("Enter your question (or 'q' to quit): ")
#       9     # Check if the user wants to quit
#      10     if question.lower() == 'q':
#
# File ~\anaconda3\envs\ds2024\lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\anaconda3\envs\ds2024\lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
