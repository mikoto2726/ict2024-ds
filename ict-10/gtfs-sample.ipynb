# %% [markdown]
# # データ・サイエンス	データ・サイエンス社会応用論 / ICT社会応用演習Ⅳ
# ## 10. GTFSデータを見てみよう

# %% [markdown]
# ### 1. 下準備
# #### 1-a) ライブラリのインポート

# %%
import requests
import zipfile
import os
from datetime import datetime
import pandas as pd
import geopandas as gpd

# %% [markdown]
# #### 1-b) 定数の定義

# %%
GTFS_URL = 'https://api-public.odpt.org/api/v4/files/Toei/data/ToeiBus-GTFS.zip'
ZIP_PATH = 'tmp.zip'
TMPDIR_PATH = 'tmp/'

# %% [markdown]
# #### 1-c) データのダウンロードと展開

# %%
response = requests.get(GTFS_URL)

if response.status_code == 200:
  with open(ZIP_PATH, 'wb') as f:
    f.write(response.content)

if not os.path.exists(TMPDIR_PATH):
  os.makedirs(TMPDIR_PATH)

with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
  zip_ref.extractall(TMPDIR_PATH)

# %% [markdown]
# ### 2. バス停の確認
# #### 2-a) stops.txt の読み込み

# %%
df_stops = pd.read_csv(TMPDIR_PATH + 'stops.txt')
df_stops
# Out:
#       stop_id  stop_code       stop_name stop_desc   stop_lat    stop_lon  \
# 0     0001-01        NaN        愛育クリニック前       NaN  35.653697  139.726017
# 1     0001-02        NaN        愛育クリニック前       NaN  35.654095  139.726541
# 2     0003-01        NaN           青戸車庫前       NaN  35.744787  139.843847
# 3     0003-02        NaN           青戸車庫前       NaN  35.745259  139.844403
# 4     0003-03        NaN           青戸車庫前       NaN  35.743838  139.843350
# ...       ...        ...             ...       ...        ...         ...
# 3717  2627-01        NaN      晴海五丁目ターミナル       NaN  35.652299  139.773363
# 3718  2627-02        NaN      晴海五丁目ターミナル       NaN  35.652160  139.773195
# 3719  2628-02        NaN         晴海ふ頭公園北       NaN  35.648823  139.771797
# 3720  2629-01        NaN         晴海ふ頭公園南       NaN  35.648287  139.772342
# 3721  3334-01        NaN  日本女子大前（豊明小学校前）       NaN  35.716309  139.719117
#
#       zone_id                                           stop_url  \
# 0     0001-01  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 1     0001-02  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 2     0003-01  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 3     0003-02  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 4     0003-03  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# ...       ...                                                ...
# 3717  2627-01  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 3718  2627-02  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 3719  2628-02  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 3720  2629-01  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 3721  3334-01  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
#
#       location_type  parent_station  stop_timezone  wheelchair_boarding  \
# 0                 0             NaN            NaN                  NaN
# 1                 0             NaN            NaN                  NaN
# 2                 0             NaN            NaN                  NaN
# 3                 0             NaN            NaN                  NaN
# 4                 0             NaN            NaN                  NaN
# ...             ...             ...            ...                  ...
# 3717              0             NaN            NaN                  NaN
# 3718              0             NaN            NaN                  NaN
# 3719              0             NaN            NaN                  NaN
# 3720              0             NaN            NaN                  NaN
# 3721              0             NaN            NaN                  NaN
#
#       platform_code
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3717            NaN
# 3718            NaN
# 3719            NaN
# 3720            NaN
# 3721            NaN
#
# [3722 rows x 13 columns]

# %%
df_stops[df_stops['stop_name'].str.contains('王子駅')]
# Out:
#      stop_id  stop_code stop_name                          stop_desc  \
# 386  0196-01        NaN      王子駅前  ＪＲ京浜東北線 王子:東京メトロ南北線 王子:都電荒川線 王子駅前
# 387  0196-02        NaN      王子駅前  都電荒川線 王子駅前:東京メトロ南北線 王子:ＪＲ京浜東北線 王子
# 388  0196-03        NaN      王子駅前  都電荒川線 王子駅前:ＪＲ京浜東北線 王子:東京メトロ南北線 王子
# 389  0196-04        NaN      王子駅前  東京メトロ南北線 王子:ＪＲ京浜東北線 王子:都電荒川線 王子駅前
# 390  0196-05        NaN      王子駅前  ＪＲ京浜東北線 王子:都電荒川線 王子駅前:東京メトロ南北線 王子
# 391  0196-06        NaN      王子駅前  ＪＲ京浜東北線 王子:東京メトロ南北線 王子:都電荒川線 王子駅前
# 392  0196-09        NaN      王子駅前  ＪＲ京浜東北線 王子:東京メトロ南北線 王子:都電荒川線 王子駅前
# 393  0196-10        NaN      王子駅前  都電荒川線 王子駅前:ＪＲ京浜東北線 王子:東京メトロ南北線 王子
# 394  0196-11        NaN      王子駅前  都電荒川線 王子駅前:ＪＲ京浜東北線 王子:東京メトロ南北線 王子
# 395  0196-12        NaN      王子駅前  ＪＲ京浜東北線 王子:東京メトロ南北線 王子:都電荒川線 王子駅前
# 396  0196-13        NaN      王子駅前  都電荒川線 王子駅前:東京メトロ南北線 王子:ＪＲ京浜東北線 王子
# 397  0196-14        NaN      王子駅前  東京メトロ南北線 王子:都電荒川線 王子駅前:ＪＲ京浜東北線 王子
# 398  0196-16        NaN      王子駅前  ＪＲ京浜東北線 王子:都電荒川線 王子駅前:東京メトロ南北線 王子
#
#       stop_lat    stop_lon  zone_id  \
# 386  35.753867  139.737230  0196-01
# 387  35.753727  139.737349  0196-02
# 388  35.753907  139.737343  0196-03
# 389  35.753792  139.737428  0196-04
# 390  35.753644  139.737562  0196-05
# 391  35.754082  139.737718  0196-06
# 392  35.753893  139.738436  0196-09
# 393  35.754102  139.738592  0196-10
# 394  35.754195  139.738676  0196-11
# 395  35.754343  139.738815  0196-12
# 396  35.753901  139.738715  0196-13
# 397  35.753705  139.738579  0196-14
# 398  35.753438  139.737688  0196-16
#
#                                               stop_url  location_type  \
# 386  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 387  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 388  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 389  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 390  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 391  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 392  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 393  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 394  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 395  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 396  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 397  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 398  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
#
#      parent_station  stop_timezone  wheelchair_boarding  platform_code
# 386             NaN            NaN                  NaN            1.0
# 387             NaN            NaN                  NaN            2.0
# 388             NaN            NaN                  NaN            3.0
# 389             NaN            NaN                  NaN            4.0
# 390             NaN            NaN                  NaN            5.0
# 391             NaN            NaN                  NaN            8.0
# 392             NaN            NaN                  NaN            9.0
# 393             NaN            NaN                  NaN           10.0
# 394             NaN            NaN                  NaN           11.0
# 395             NaN            NaN                  NaN           12.0
# 396             NaN            NaN                  NaN           13.0
# 397             NaN            NaN                  NaN           14.0
# 398             NaN            NaN                  NaN            NaN

# %% [markdown]
# #### 2-b) GeoPandasでの読み込み

# %%
gdf_stops = gpd.GeoDataFrame(df_stops, geometry=gpd.points_from_xy(df_stops['stop_lon'], df_stops['stop_lat'], crs=4326))
gdf_stops
# Out:
#       stop_id  stop_code       stop_name stop_desc   stop_lat    stop_lon  \
# 0     0001-01        NaN        愛育クリニック前       NaN  35.653697  139.726017
# 1     0001-02        NaN        愛育クリニック前       NaN  35.654095  139.726541
# 2     0003-01        NaN           青戸車庫前       NaN  35.744787  139.843847
# 3     0003-02        NaN           青戸車庫前       NaN  35.745259  139.844403
# 4     0003-03        NaN           青戸車庫前       NaN  35.743838  139.843350
# ...       ...        ...             ...       ...        ...         ...
# 3717  2627-01        NaN      晴海五丁目ターミナル       NaN  35.652299  139.773363
# 3718  2627-02        NaN      晴海五丁目ターミナル       NaN  35.652160  139.773195
# 3719  2628-02        NaN         晴海ふ頭公園北       NaN  35.648823  139.771797
# 3720  2629-01        NaN         晴海ふ頭公園南       NaN  35.648287  139.772342
# 3721  3334-01        NaN  日本女子大前（豊明小学校前）       NaN  35.716309  139.719117
#
#       zone_id                                           stop_url  \
# 0     0001-01  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 1     0001-02  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 2     0003-01  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 3     0003-02  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 4     0003-03  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# ...       ...                                                ...
# 3717  2627-01  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 3718  2627-02  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 3719  2628-02  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 3720  2629-01  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
# 3721  3334-01  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...
#
#       location_type  parent_station  stop_timezone  wheelchair_boarding  \
# 0                 0             NaN            NaN                  NaN
# 1                 0             NaN            NaN                  NaN
# 2                 0             NaN            NaN                  NaN
# 3                 0             NaN            NaN                  NaN
# 4                 0             NaN            NaN                  NaN
# ...             ...             ...            ...                  ...
# 3717              0             NaN            NaN                  NaN
# 3718              0             NaN            NaN                  NaN
# 3719              0             NaN            NaN                  NaN
# 3720              0             NaN            NaN                  NaN
# 3721              0             NaN            NaN                  NaN
#
#       platform_code                    geometry
# 0               NaN  POINT (139.72602 35.65370)
# 1               NaN  POINT (139.72654 35.65409)
# 2               NaN  POINT (139.84385 35.74479)
# 3               NaN  POINT (139.84440 35.74526)
# 4               NaN  POINT (139.84335 35.74384)
# ...             ...                         ...
# 3717            NaN  POINT (139.77336 35.65230)
# 3718            NaN  POINT (139.77319 35.65216)
# 3719            NaN  POINT (139.77180 35.64882)
# 3720            NaN  POINT (139.77234 35.64829)
# 3721            NaN  POINT (139.71912 35.71631)
#
# [3722 rows x 14 columns]

# %%
gdf_stops.explore(marker_type='circle')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d71af01ebad12542091d1f6e359b452 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d71af01ebad12542091d1f6e359b452&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d71af01ebad12542091d1f6e359b452 = L.map(
#                 &quot;map_7d71af01ebad12542091d1f6e359b452&quot;,
#                 {
#                     center: [35.7093945, 139.5438],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7d71af01ebad12542091d1f6e359b452);
#
#
#
#
#
#             var tile_layer_d94d1cf1c3f95fb9c8d7850a09a4cabf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7d71af01ebad12542091d1f6e359b452);
#
#
#             map_7d71af01ebad12542091d1f6e359b452.fitBounds(
#                 [[35.579078, 139.1836], [35.839711, 139.904]],
#                 {}
#             );
#
#
#         function geo_json_bd742483dfa9ba9363c89c7372abe664_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_bd742483dfa9ba9363c89c7372abe664_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_bd742483dfa9ba9363c89c7372abe664_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_bd742483dfa9ba9363c89c7372abe664_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.circle(latlng, opts)
#         }
#
#         function geo_json_bd742483dfa9ba9363c89c7372abe664_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_bd742483dfa9ba9363c89c7372abe664.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_bd742483dfa9ba9363c89c7372abe664_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_bd742483dfa9ba9363c89c7372abe664 = L.geoJson(null, {
#                 onEachFeature: geo_json_bd742483dfa9ba9363c89c7372abe664_onEachFeature,
#
#                 style: geo_json_bd742483dfa9ba9363c89c7372abe664_styler,
#                 pointToLayer: geo_json_bd742483dfa9ba9363c89c7372abe664_pointToLayer
#         });
#
#         function geo_json_bd742483dfa9ba9363c89c7372abe664_add (data) {
#             geo_json_bd742483dfa9ba9363c89c7372abe664
#                 .addData(data)
#                 .addTo(map_7d71af01ebad12542091d1f6e359b452);
#         }
#             geo_json_bd742483dfa9ba9363c89c7372abe664_add({&quot;bbox&quot;: [139.1836, 35.579078, 139.904, 35.839711], &quot;features&quot;: [{&quot;bbox&quot;: [139.726017, 35.653697, 139.726017, 35.653697], &quot;geometry&quot;: {&quot;coordinates&quot;: [139.726017, 35.653697], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;location_type&quot;: 0, &quot;parent_station&quot;: null, &quot;platform_code&quot;: null, &quot;stop_code&quot;: null, &quot;stop_desc&quot;: null, &quot;stop_id&quot;: &quot;0001-01&quot;, &quot;stop_lat&quot;: 35.653697, &quot;stop_lon&quot;: 139.726017, &quot;stop_name&quot;: &quot;\u611b\u80b2\u30af\u30ea\u30cb\u30c3\u30af\u524d&quot;, &quot;stop_timezone&quot;: nul

# %% [markdown]
# ### 3. バス路線の確認
# #### 3-a) routes.txt の読み込み

# %%
df_routes = pd.read_csv(TMPDIR_PATH + 'routes.txt')
df_routes
# Out:
#      route_id      agency_id route_short_name  route_long_name  route_desc  \
# 0           2  8000020130001        波０１（ＮＭ０１）              NaN         NaN
# 1           3  8000020130001              市０１              NaN         NaN
# 2           6  8000020130001         都０１（Ｔ０１）              NaN         NaN
# 3           8  8000020130001             ＲＨ０１              NaN         NaN
# 4          10  8000020130001             ＣＨ０１              NaN         NaN
# ..        ...            ...              ...              ...         ...
# 159       286  8000020130001             梅７７甲              NaN         NaN
# 160       287  8000020130001             梅７７乙              NaN         NaN
# 161       288  8000020130001             梅７７丙              NaN         NaN
# 162       289  8000020130001             梅７７丁              NaN         NaN
# 163       291  8000020130001              梅０１              NaN         NaN
#
#      route_type                                          route_url  \
# 0             3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 1             3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 2             3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 3             3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 4             3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# ..          ...                                                ...
# 159           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 160           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 161           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 162           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 163           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
#
#     route_color route_text_color  jp_parent_route_id
# 0        F1B34E           350800                 NaN
# 1        B779B7           FAF6FB                 NaN
# 2        00A9E8           FFFFFF                 NaN
# 3        BB7AAA           FFFFFF                 NaN
# 4        E90087           FFF0FF                 NaN
# ..          ...              ...                 ...
# 159      77BC2D           FFFFFF                 NaN
# 160      8649A7           FFFFFF                 NaN
# 161      B08B5B           FFFFFF                 NaN
# 162      EB6C78           FFFFFF                 NaN
# 163      7B6FAE           FFFFFF                 NaN
#
# [164 rows x 10 columns]

# %% [markdown]
# #### 3-b) trips.txt の読み込み

# %%
df_trips = pd.read_csv(TMPDIR_PATH + 'trips.txt')
df_trips
# Out:
#        route_id service_id              trip_id trip_headsign  \
# 0             3     01-105  00106-1-01-105-0913          豊洲市場
# 1             3     01-105  00106-1-01-105-0930          豊洲市場
# 2             3     01-105  00106-1-01-105-0947          豊洲市場
# 3             3     01-105  00106-1-01-105-1010          豊洲市場
# 4             3     01-105  00106-1-01-105-1042          豊洲市場
# ...         ...        ...                  ...           ...
# 61610       192     81-301  74601-2-81-301-1724         東陽町駅前
# 61611       192     81-301  74601-2-81-301-1800         東陽町駅前
# 61612       192     81-301  74601-2-81-301-1840         東陽町駅前
# 61613       192     81-301  74601-2-81-301-1920         東陽町駅前
# 61614       192     81-301  74601-2-81-301-2000         東陽町駅前
#
#        trip_short_name  direction_id  block_id shape_id  \
# 0                  NaN           1.0       NaN  00106-1
# 1                  NaN           1.0       NaN  00106-1
# 2                  NaN           1.0       NaN  00106-1
# 3                  NaN           1.0       NaN  00106-1
# 4                  NaN           1.0       NaN  00106-1
# ...                ...           ...       ...      ...
# 61610              NaN           0.0       NaN  74601-2
# 61611              NaN           0.0       NaN  74601-2
# 61612              NaN           0.0       NaN  74601-2
# 61613              NaN           0.0       NaN  74601-2
# 61614              NaN           0.0       NaN  74601-2
#
#        wheelchair_accessible  bikes_allowed  jp_trip_desc  \
# 0                          1              0           NaN
# 1                          1              0           NaN
# 2                          1              0           NaN
# 3                          1              0           NaN
# 4                          1              0           NaN
# ...                      ...            ...           ...
# 61610                      1              0           NaN
# 61611                      1              0           NaN
# 61612                      1              0           NaN
# 61613                      1              0           NaN
# 61614                      1              0           NaN
#
#        jp_trip_desc_symbol  jp_office_id
# 0                      NaN             1
# 1                      NaN             1
# 2                      NaN             1
# 3                      NaN             1
# 4                      NaN             1
# ...                    ...           ...
# 61610                  NaN            81
# 61611                  NaN            81
# 61612                  NaN            81
# 61613                  NaN            81
# 61614                  NaN            81
#
# [61615 rows x 13 columns]

# %% [markdown]
# #### 3-c) stop_times.txt の読み込み

# %%
df_stop_times = pd.read_csv(TMPDIR_PATH + 'stop_times.txt')
df_stop_times
# Out:
#                      trip_id arrival_time departure_time  stop_id  \
# 0        00106-1-01-105-0913     09:13:00       09:13:00  0737-01
# 1        00106-1-01-105-0913     09:14:00       09:14:00  1239-01
# 2        00106-1-01-105-0913     09:16:00       09:16:00  2024-01
# 3        00106-1-01-105-0913     09:18:00       09:18:00  2579-01
# 4        00106-1-01-105-0913     09:21:00       09:21:00  0946-02
# ...                      ...          ...            ...      ...
# 1186006  74601-2-81-301-2000     20:32:00       20:32:00  0594-01
# 1186007  74601-2-81-301-2000     20:35:00       20:35:00  2003-02
# 1186008  74601-2-81-301-2000     20:36:00       20:36:00  2587-02
# 1186009  74601-2-81-301-2000     20:37:00       20:37:00  2592-02
# 1186010  74601-2-81-301-2000     20:43:00       20:43:00  0989-08
#
#          stop_sequence stop_headsign  pickup_type  drop_off_type  \
# 0                    1          豊洲市場          NaN            NaN
# 1                    2          豊洲市場          NaN            NaN
# 2                    3          豊洲市場          NaN            NaN
# 3                    4          豊洲市場          NaN            NaN
# 4                    5          豊洲市場          NaN            NaN
# ...                ...           ...          ...            ...
# 1186006             15         東陽町駅前          NaN            NaN
# 1186007             16         東陽町駅前          NaN            NaN
# 1186008             17         東陽町駅前          NaN            NaN
# 1186009             18         東陽町駅前          NaN            NaN
# 1186010             19         東陽町駅前          NaN            NaN
#
#          shape_dist_traveled  timepoint
# 0                        NaN          1
# 1                        NaN          1
# 2                        NaN          1
# 3                        NaN          1
# 4                        NaN          1
# ...                      ...        ...
# 1186006                  NaN          1
# 1186007                  NaN          1
# 1186008                  NaN          1
# 1186009                  NaN          1
# 1186010                  NaN          1
#
# [1186011 rows x 10 columns]

# %% [markdown]
# #### 3-d) マージ

# %%
df_merged = df_routes.merge(df_trips).merge(df_stop_times).merge(df_stops)
df_merged
# Out:
#          route_id      agency_id route_short_name  route_long_name  \
# 0               2  8000020130001        波０１（ＮＭ０１）              NaN
# 1               2  8000020130001        波０１（ＮＭ０１）              NaN
# 2               2  8000020130001        波０１（ＮＭ０１）              NaN
# 3               2  8000020130001        波０１（ＮＭ０１）              NaN
# 4               2  8000020130001        波０１（ＮＭ０１）              NaN
# ...           ...            ...              ...              ...
# 1186006       291  8000020130001              梅０１              NaN
# 1186007       291  8000020130001              梅０１              NaN
# 1186008       291  8000020130001              梅０１              NaN
# 1186009       291  8000020130001              梅０１              NaN
# 1186010       291  8000020130001              梅０１              NaN
#
#          route_desc  route_type  \
# 0               NaN           3
# 1               NaN           3
# 2               NaN           3
# 3               NaN           3
# 4               NaN           3
# ...             ...         ...
# 1186006         NaN           3
# 1186007         NaN           3
# 1186008         NaN           3
# 1186009         NaN           3
# 1186010         NaN           3
#
#                                                  route_url route_color  \
# 0        https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...      F1B34E
# 1        https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...      F1B34E
# 2        https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...      F1B34E
# 3        https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...      F1B34E
# 4        https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...      F1B34E
# ...                                                    ...         ...
# 1186006  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...      7B6FAE
# 1186007  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...      7B6FAE
# 1186008  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...      7B6FAE
# 1186009  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...      7B6FAE
# 1186010  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...      7B6FAE
#
#         route_text_color  jp_parent_route_id  ...            stop_desc  \
# 0                 350800                 NaN  ...        りんかい線 東京テレポート
# 1                 350800                 NaN  ...  ゆりかもめ 東京国際クルーズターミナル
# 2                 350800                 NaN  ...                  NaN
# 3                 350800                 NaN  ...                  NaN
# 4                 350800                 NaN  ...       ゆりかもめ テレコムセンター
# ...                  ...                 ...  ...                  ...
# 1186006           FFFFFF                 NaN  ...                  NaN
# 1186007           FFFFFF                 NaN  ...                  NaN
# 1186008           FFFFFF                 NaN  ...                  NaN
# 1186009           FFFFFF                 NaN  ...                  NaN
# 1186010           FFFFFF                 NaN  ...             ＪＲ青梅線 青梅
#
#           stop_lat    stop_lon  zone_id  \
# 0        35.627171  139.779406  2326-05
# 1        35.621057  139.774762  0302-03
# 2        35.618961  139.775240  2546-01
# 3        35.617548  139.776382  2407-04
# 4        35.617403  139.778878  2327-01
# ...            ...         ...      ...
# 1186006  35.785713  139.249676  1441-02
# 1186007  35.786220  139.251875  0255-02
# 1186008  35.787518  139.254224  0876-02
# 1186009  35.789953  139.255373  1080-01
# 1186010  35.790169  139.257960  0202-01
#
#                                                   stop_url  location_type  \
# 0        https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 1        https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 2        https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 3        https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 4        https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# ...                                                    ...            ...
# 1186006  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 1186007  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 1186008  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 1186009  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
# 1186010  https://tobus.jp/blsys/navi?LCD=&VCD=cresultrs...              0
#
#         parent_station  stop_timezone  wheelchair_boarding  platform_code
# 0                  NaN            NaN                  NaN            3.0
# 1                  NaN            NaN                  NaN            NaN
# 2                  NaN            NaN                  NaN            NaN
# 3                  NaN            NaN                  NaN            4.0
# 4                  NaN            NaN                  NaN            1.0
# ...                ...            ...                  ...            ...
# 1186006            NaN            NaN                  NaN            NaN
# 1186007            NaN            NaN                  NaN            NaN
# 1186008            NaN            NaN                  NaN            NaN
# 1186009            NaN            NaN                  NaN            NaN
# 1186010            NaN            NaN                  NaN            3.0
#
# [1186011 rows x 43 columns]

# %% [markdown]
# #### 4. 運行日の確認
# #### 4-a) calendar.txt の読み込み

# %%
df_calendar = pd.read_csv(TMPDIR_PATH + 'calendar.txt')
df_calendar
# Out:
#    service_id  monday  tuesday  wednesday  thursday  friday  saturday  sunday  \
# 0      01-100       0        0          0         0       0         0       1
# 1      01-160       0        0          0         0       0         1       0
# 2      01-170       1        1          1         1       1         0       0
# 3      06-100       0        0          0         0       0         0       1
# 4      06-160       0        0          0         0       0         1       0
# 5      06-170       1        1          1         1       1         0       0
# 6      09-100       0        0          0         0       0         0       1
# 7      09-160       0        0          0         0       0         1       0
# 8      09-170       1        1          1         1       1         0       0
# 9      13-100       0        0          0         0       0         0       1
# 10     13-160       0        0          0         0       0         1       0
# 11     13-170       1        1          1         1       1         0       0
# 12     21-100       0        0          0         0       0         0       1
# 13     21-160       0        0          0         0       0         1       0
# 14     21-170       1        1          1         1       1         0       0
# 15     25-100       0        0          0         0       0         0       1
# 16     25-160       0        0          0         0       0         1       0
# 17     25-170       1        1          1         1       1         0       0
# 18     29-100       0        0          0         0       0         0       1
# 19     29-160       0        0          0         0       0         1       0
# 20     29-170       1        1          1         1       1         0       0
# 21     33-100       0        0          0         0       0         0       1
# 22     33-160       0        0          0         0       0         1       0
# 23     33-170       1        1          1         1       1         0       0
# 24     37-100       0        0          0         0       0         0       1
# 25     37-160       0        0          0         0       0         1       0
# 26     37-170       1        1          1         1       1         0       0
# 27     41-100       0        0          0         0       0         0       1
# 28     41-160       0        0          0         0       0         1       0
# 29     41-170       1        1          1         1       1         0       0
# 30     45-100       0        0          0         0       0         0       1
# 31     45-160       0        0          0         0       0         1       0
# 32     45-170       1        1          1         1       1         0       0
# 33     49-100       0        0          0         0       0         0       1
# 34     49-160       0        0          0         0       0         1       0
# 35     49-170       1        1          1         1       1         0       0
# 36     53-100       0        0          0         0       0         0       1
# 37     53-160       0        0          0         0       0         1       0
# 38     53-170       1        1          1         1       1         0       0
# 39     57-100       0        0          0         0       0         0       1
# 40     57-160       0        0          0         0       0         1       0
# 41     57-170       1        1          1         1       1         0       0
# 42     61-100       0        0          0         0       0         0       1
# 43     61-160       0        0          0         0       0         1       0
# 44     61-170       1        1          1         1       1         0       0
# 45     65-100       0        0          0         0       0         0       1
# 46     65-160       0        0          0         0       0         1       0
# 47     65-170       1        1          1         1       1         0       0
# 48     69-100       0        0          0         0       0         0       1
# 49     69-160       0        0          0         0       0         1       0
# 50     69-170       1        1          1         1       1         0       0
# 51     77-100       0        0          0         0       0         0       1
# 52     77-160       0        0          0         0       0         1       0
# 53     77-170       1        1          1         1       1         0       0
# 54     81-100       0        0          0         0       0         0       1
# 55     81-160       0        0          0         0       0         1       0
# 56     81-170       1        1          1         1       1         0       0
# 57     85-100       0        0          0         0       0         0       1
# 58     85-160       0        0          0         0       0         1       0
# 59     85-170       1        1          1         1       1         0       0
#
#     start_date  end_date
# 0     20241211  20271210
# 1     20241211  20271210
# 2     20241211  20271210
# 3     20241211  20271210
# 4     20241211  20271210
# 5     20241211  20271210
# 6     20241211  20271210
# 7     20241211  20271210
# 8     20241211  20271210
# 9     20241211  20271210
# 10    20241211  20271210
# 11    20241211  20271210
# 12    20241211  20271210
# 13    20241211  20271210
# 14    20241211  20271210
# 15    20241211  20271210
# 16    20241211  20271210
# 17    20241211  20271210
# 18    20241211  20271210
# 19    20241211  20271210
# 20    20241211  20271210
# 21    20241211  20271210
# 22    20241211  20271210
# 23    20241211  20271210
# 24    20241211  20271210
# 25    20241211  20271210
# 26    20241211  20271210
# 27    20241211  20271210
# 28    20241211  20271210
# 29    20241211  20271210
# 30    20241211  20271210
# 31    20241211  20271210
# 32    20241211  20271210
# 33    20241211  20271210
# 34    20241211  20271210
# 35    20241211  20271210
# 36    20241211  20271210
# 37    20241211  20271210
# 38    20241211  20271210
# 39    20241211  20271210
# 40    20241211  20271210
# 41    20241211  20271210
# 42    20241211  20271210
# 43    20241211  20271210
# 44    20241211  20271210
# 45    20241211  20271210
# 46    20241211  20271210
# 47    20241211  20271210
# 48    20241211  20271210
# 49    20241211  20271210
# 50    20241211  20271210
# 51    20241211  20271210
# 52    20241211  20271210
# 53    20241211  20271210
# 54    20241211  20271210
# 55    20241211  20271210
# 56    20241211  20271210
# 57    20241211  20271210
# 58    20241211  20271210
# 59    20241211  20271210

# %% [markdown]
# #### 4-b) calendar_dates.txt の読み込み

# %%
df_calendar_dates = pd.read_csv(TMPDIR_PATH + 'calendar_dates.txt')
df_calendar_dates
# Out:
#     service_id      date  exception_type
# 0       01-179  20241211               1
# 1       01-170  20241211               2
# 2       81-179  20241211               1
# 3       81-170  20241211               2
# 4       09-172  20241213               1
# ..         ...       ...             ...
# 313     81-170  20250122               2
# 314     81-179  20250129               1
# 315     81-170  20250129               2
# 316     81-179  20250205               1
# 317     81-170  20250205               2
#
# [318 rows x 3 columns]

# %% [markdown]
# ### 5. 木曜日のデータの確認
# #### 5-a) 木曜日の運行便の確認

# %%
services = set(df_calendar[df_calendar['thursday'] == 1]['service_id'])
services
# Out:
# {'01-170',
#  '06-170',
#  '09-170',
#  '13-170',
#  '21-170',
#  '25-170',
#  '29-170',
#  '33-170',
#  '37-170',
#  '41-170',
#  '45-170',
#  '49-170',
#  '53-170',
#  '57-170',
#  '61-170',
#  '65-170',
#  '69-170',
#  '77-170',
#  '81-170',
#  '85-170'}

# %%
df_route_trips = df_routes.merge(df_trips)
df_route_trips_today = df_route_trips[df_route_trips['service_id'].isin(services)]
df_route_trips_today
# Out:
#        route_id      agency_id route_short_name  route_long_name  route_desc  \
# 81            2  8000020130001        波０１（ＮＭ０１）              NaN         NaN
# 82            2  8000020130001        波０１（ＮＭ０１）              NaN         NaN
# 83            2  8000020130001        波０１（ＮＭ０１）              NaN         NaN
# 84            2  8000020130001        波０１（ＮＭ０１）              NaN         NaN
# 85            2  8000020130001        波０１（ＮＭ０１）              NaN         NaN
# ...         ...            ...              ...              ...         ...
# 61586       289  8000020130001             梅７７丁              NaN         NaN
# 61595       289  8000020130001             梅７７丁              NaN         NaN
# 61596       289  8000020130001             梅７７丁              NaN         NaN
# 61597       289  8000020130001             梅７７丁              NaN         NaN
# 61598       289  8000020130001             梅７７丁              NaN         NaN
#
#        route_type                                          route_url  \
# 81              3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 82              3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 83              3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 84              3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 85              3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# ...           ...                                                ...
# 61586           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 61595           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 61596           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 61597           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 61598           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
#
#       route_color route_text_color  jp_parent_route_id  ... trip_headsign  \
# 81         F1B34E           350800                 NaN  ...         中央防波堤
# 82         F1B34E           350800                 NaN  ...         中央防波堤
# 83         F1B34E           350800                 NaN  ...         中央防波堤
# 84         F1B34E           350800                 NaN  ...         中央防波堤
# 85         F1B34E           350800                 NaN  ...         中央防波堤
# ...           ...              ...                 ...  ...           ...
# 61586      EB6C78           FFFFFF                 NaN  ...         河辺駅南口
# 61595      EB6C78           FFFFFF                 NaN  ...          青梅駅前
# 61596      EB6C78           FFFFFF                 NaN  ...          青梅駅前
# 61597      EB6C78           FFFFFF                 NaN  ...          青梅駅前
# 61598      EB6C78           FFFFFF                 NaN  ...          青梅駅前
#
#       trip_short_name direction_id  block_id  shape_id  wheelchair_accessible  \
# 81                NaN          1.0       NaN   04601-1                      1
# 82                NaN          1.0       NaN   04601-1                      1
# 83                NaN          1.0       NaN   04601-1                      1
# 84                NaN          1.0       NaN   04601-1                      1
# 85                NaN          1.0       NaN   04601-1                      1
# ...               ...          ...       ...       ...                    ...
# 61586             NaN          1.0       NaN   28901-1                      1
# 61595             NaN          0.0       NaN   28901-2                      1
# 61596             NaN          0.0       NaN   28901-2                      1
# 61597             NaN          0.0       NaN   28901-2                      1
# 61598             NaN          0.0       NaN   28901-2                      1
#
#       bikes_allowed  jp_trip_desc  jp_trip_desc_symbol  jp_office_id
# 81                0           NaN                  NaN            85
# 82                0           NaN                  NaN            85
# 83                0           NaN                  NaN            85
# 84                0           NaN                  NaN            85
# 85                0           NaN                  NaN            85
# ...             ...           ...                  ...           ...
# 61586             0           NaN                  NaN            25
# 61595             0           NaN                  NaN            25
# 61596             0           NaN                  NaN            25
# 61597             0           NaN                  NaN            25
# 61598             0           NaN                  NaN            25
#
# [16024 rows x 22 columns]

# %%
df_route_trips_today[df_route_trips_today['route_short_name'] == '王５７']
# Out:
#        route_id      agency_id route_short_name  route_long_name  route_desc  \
# 40234       119  8000020130001              王５７              NaN         NaN
# 40235       119  8000020130001              王５７              NaN         NaN
# 40236       119  8000020130001              王５７              NaN         NaN
# 40237       119  8000020130001              王５７              NaN         NaN
# 40238       119  8000020130001              王５７              NaN         NaN
# ...         ...            ...              ...              ...         ...
# 41081       119  8000020130001              王５７              NaN         NaN
# 41082       119  8000020130001              王５７              NaN         NaN
# 41083       119  8000020130001              王５７              NaN         NaN
# 41084       119  8000020130001              王５７              NaN         NaN
# 41130       119  8000020130001              王５７              NaN         NaN
#
#        route_type                                          route_url  \
# 40234           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 40235           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 40236           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 40237           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 40238           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# ...           ...                                                ...
# 41081           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 41082           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 41083           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 41084           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 41130           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
#
#       route_color route_text_color  jp_parent_route_id  ... trip_headsign  \
# 40234      267B6B           FFFFFF                 NaN  ...       豊島五丁目団地
# 40235      267B6B           FFFFFF                 NaN  ...       豊島五丁目団地
# 40236      267B6B           FFFFFF                 NaN  ...       豊島五丁目団地
# 40237      267B6B           FFFFFF                 NaN  ...       豊島五丁目団地
# 40238      267B6B           FFFFFF                 NaN  ...       豊島五丁目団地
# ...           ...              ...                 ...  ...           ...
# 41081      267B6B           FFFFFF                 NaN  ...          王子駅前
# 41082      267B6B           FFFFFF                 NaN  ...          王子駅前
# 41083      267B6B           FFFFFF                 NaN  ...          王子駅前
# 41084      267B6B           FFFFFF                 NaN  ...          王子駅前
# 41130      267B6B           FFFFFF                 NaN  ...       豊島五丁目団地
#
#       trip_short_name direction_id  block_id  shape_id  wheelchair_accessible  \
# 40234             NaN          1.0       NaN   40301-1                      1
# 40235             NaN          1.0       NaN   40301-1                      1
# 40236             NaN          1.0       NaN   40301-1                      1
# 40237             NaN          1.0       NaN   40301-1                      1
# 40238             NaN          1.0       NaN   40301-1                      1
# ...               ...          ...       ...       ...                    ...
# 41081             NaN          0.0       NaN   40303-2                      1
# 41082             NaN          0.0       NaN   40303-2                      1
# 41083             NaN          0.0       NaN   40303-2                      1
# 41084             NaN          0.0       NaN   40303-2                      1
# 41130             NaN          1.0       NaN   40304-1                      1
#
#       bikes_allowed  jp_trip_desc  jp_trip_desc_symbol  jp_office_id
# 40234             0           NaN                  NaN            49
# 40235             0           NaN                  NaN            49
# 40236             0           NaN                  NaN            49
# 40237             0           NaN                  NaN            49
# 40238             0           NaN                  NaN            49
# ...             ...           ...                  ...           ...
# 41081             0           NaN                  NaN            49
# 41082             0           NaN                  NaN            49
# 41083             0           NaN                  NaN            49
# 41084             0           NaN                  NaN            49
# 41130             0           NaN                  NaN            49
#
# [345 rows x 22 columns]

# %% [markdown]
# ##### 5-b) 発着時刻の確認

# %%
df_merged_today = df_route_trips_today.merge(df_stop_times)
df_merged_today
# Out:
#         route_id      agency_id route_short_name  route_long_name  route_desc  \
# 0              2  8000020130001        波０１（ＮＭ０１）              NaN         NaN
# 1              2  8000020130001        波０１（ＮＭ０１）              NaN         NaN
# 2              2  8000020130001        波０１（ＮＭ０１）              NaN         NaN
# 3              2  8000020130001        波０１（ＮＭ０１）              NaN         NaN
# 4              2  8000020130001        波０１（ＮＭ０１）              NaN         NaN
# ...          ...            ...              ...              ...         ...
# 308409       289  8000020130001             梅７７丁              NaN         NaN
# 308410       289  8000020130001             梅７７丁              NaN         NaN
# 308411       289  8000020130001             梅７７丁              NaN         NaN
# 308412       289  8000020130001             梅７７丁              NaN         NaN
# 308413       289  8000020130001             梅７７丁              NaN         NaN
#
#         route_type                                          route_url  \
# 0                3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 1                3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 2                3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 3                3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 4                3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# ...            ...                                                ...
# 308409           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 308410           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 308411           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 308412           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 308413           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
#
#        route_color route_text_color  jp_parent_route_id  ... jp_office_id  \
# 0           F1B34E           350800                 NaN  ...           85
# 1           F1B34E           350800                 NaN  ...           85
# 2           F1B34E           350800                 NaN  ...           85
# 3           F1B34E           350800                 NaN  ...           85
# 4           F1B34E           350800                 NaN  ...           85
# ...            ...              ...                 ...  ...          ...
# 308409      EB6C78           FFFFFF                 NaN  ...           25
# 308410      EB6C78           FFFFFF                 NaN  ...           25
# 308411      EB6C78           FFFFFF                 NaN  ...           25
# 308412      EB6C78           FFFFFF                 NaN  ...           25
# 308413      EB6C78           FFFFFF                 NaN  ...           25
#
#        arrival_time departure_time  stop_id  stop_sequence  stop_headsign  \
# 0          06:40:00       06:40:00  2326-05              1          中央防波堤
# 1          06:41:00       06:41:00  0302-03              2          中央防波堤
# 2          06:42:00       06:42:00  2546-01              3          中央防波堤
# 3          06:42:00       06:42:00  2407-04              4          中央防波堤
# 4          06:46:00       06:46:00  2327-01              5          中央防波堤
# ...             ...            ...      ...            ...            ...
# 308409     18:00:00       18:00:00  1199-02              7           青梅駅前
# 308410     18:00:00       18:00:00  1172-02              8           青梅駅前
# 308411     18:01:00       18:01:00  1173-02              9           青梅駅前
# 308412     18:02:00       18:02:00  0788-02             10           青梅駅前
# 308413     18:05:00       18:05:00  0202-01             11           青梅駅前
#
#        pickup_type  drop_off_type  shape_dist_traveled  timepoint
# 0              NaN            NaN                  NaN          1
# 1              NaN            NaN                  NaN          1
# 2              NaN            NaN                  NaN          1
# 3              NaN            NaN                  NaN          1
# 4              NaN            NaN                  NaN          1
# ...            ...            ...                  ...        ...
# 308409         NaN            NaN                  NaN          1
# 308410         NaN            NaN                  NaN          1
# 308411         NaN            NaN                  NaN          1
# 308412         NaN            NaN                  NaN          1
# 308413         NaN            NaN                  NaN          1
#
# [308414 rows x 31 columns]

# %%
df_merged_today[df_merged_today['stop_id'] == '0196-01'].sort_values('departure_time')
# Out:
#         route_id      agency_id route_short_name  route_long_name  route_desc  \
# 177582       108  8000020130001              王４５              NaN         NaN
# 163749       100  8000020130001              王４１              NaN         NaN
# 177607       108  8000020130001              王４５              NaN         NaN
# 163761       100  8000020130001              王４１              NaN         NaN
# 177632       108  8000020130001              王４５              NaN         NaN
# ...          ...            ...              ...              ...         ...
# 164541       100  8000020130001              王４１              NaN         NaN
# 164553       100  8000020130001              王４１              NaN         NaN
# 164565       100  8000020130001              王４１              NaN         NaN
# 164577       100  8000020130001              王４１              NaN         NaN
# 165359       100  8000020130001              王４１              NaN         NaN
#
#         route_type                                          route_url  \
# 177582           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 163749           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 177607           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 163761           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 177632           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# ...            ...                                                ...
# 164541           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 164553           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 164565           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 164577           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
# 165359           3  https://tobus.jp/blsys/navi?VCD=cresultapr&ECD...
#
#        route_color route_text_color  jp_parent_route_id  ... jp_office_id  \
# 177582      F8C01D           250900                 NaN  ...           49
# 163749      00A9E2           FFFFFF                 NaN  ...           49
# 177607      F8C01D           250900                 NaN  ...           49
# 163761      00A9E2           FFFFFF                 NaN  ...           49
# 177632      F8C01D           250900                 NaN  ...           49
# ...            ...              ...                 ...  ...          ...
# 164541      00A9E2           FFFFFF                 NaN  ...           49
# 164553      00A9E2           FFFFFF                 NaN  ...           49
# 164565      00A9E2           FFFFFF                 NaN  ...           49
# 164577      00A9E2           FFFFFF                 NaN  ...           49
# 165359      00A9E2           FFFFFF                 NaN  ...           49
#
#        arrival_time departure_time  stop_id  stop_sequence  stop_headsign  \
# 177582     06:22:00       06:22:00  0196-01              1          北千住駅前
# 163749     06:35:00       06:35:00  0196-01              1          新田一丁目
# 177607     06:40:00       06:40:00  0196-01              1          北千住駅前
# 163761     06:48:00       06:48:00  0196-01              1          新田一丁目
# 177632     06:57:00       06:57:00  0196-01              1          北千住駅前
# ...             ...            ...      ...            ...            ...
# 164541     21:47:00       21:47:00  0196-01              1          新田一丁目
# 164553     22:02:00       22:02:00  0196-01              1          新田一丁目
# 164565     22:16:00       22:16:00  0196-01              1          新田一丁目
# 164577     22:30:00       22:30:00  0196-01              1          新田一丁目
# 165359     22:41:00       22:41:00  0196-01              1          新田二丁目
#
#        pickup_type  drop_off_type  shape_dist_traveled  timepoint
# 177582         NaN            NaN                  NaN          1
# 163749         NaN            NaN                  NaN          1
# 177607         NaN            NaN                  NaN          1
# 163761         NaN            NaN                  NaN          1
# 177632         NaN            NaN                  NaN          1
# ...            ...            ...                  ...        ...
# 164541         NaN            NaN                  NaN          1
# 164553         NaN            NaN                  NaN          1
# 164565         NaN            NaN                  NaN          1
# 164577         NaN            NaN                  NaN          1
# 165359         NaN            NaN                  NaN          1
#
# [96 rows x 31 columns]
