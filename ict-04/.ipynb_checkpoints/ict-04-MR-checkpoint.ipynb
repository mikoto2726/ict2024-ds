# %%
#Cell_1.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.preprocessing import scale
from sklearn.metrics import mean_squared_error


plt.rcParams['font.family'] = 'Yu Mincho' # for Japanese in graph (Win)

# %%
#Cell_2.
csv_in="8316_2018.csv"
df=pd.read_csv(csv_in,skiprows=1,header=0,delimiter=',',encoding="shift-jis")
print(df.shape) #確認
print(df.head()) #確認
print(type(df['日付'][0]))
df['日付']=pd.to_datetime(df['日付'])
print(type(df['日付'][0]))
# Out:
# (105, 7)
#            日付    始値    高値    安値    終値       出来高  終値調整値
# 0  2018-01-04  4949  5015  4946  5013   9066700   5013
# 1  2018-01-05  5071  5134  5067  5095  10985300   5095
# 2  2018-01-09  5190  5203  5078  5090   7822700   5090
# 3  2018-01-10  5182  5215  5168  5177   9731100   5177
# 4  2018-01-11  5230  5242  5178  5228   8621500   5228
# <class 'str'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
#Cell_3.
df_d=df.copy()
df_d['日付']-=df_d['日付'][0]
print(type(df_d['日付'][0]))
df_d['日付']/=np.timedelta64(1,'D')
print(type(df_d['日付'][0]))
print(df_d.head())
# Out:
# <class 'pandas._libs.tslibs.timedeltas.Timedelta'>
# <class 'numpy.float64'>
#     日付    始値    高値    安値    終値       出来高  終値調整値
# 0  0.0  4949  5015  4946  5013   9066700   5013
# 1  1.0  5071  5134  5067  5095  10985300   5095
# 2  5.0  5190  5203  5078  5090   7822700   5090
# 3  6.0  5182  5215  5168  5177   9731100   5177
# 4  7.0  5230  5242  5178  5228   8621500   5228

# %%
#Cell_4.
df_d['week']=0
print(df_d.shape)
display(df_d.head())
# Out:
# (105, 8)
#     日付    始値    高値    安値    終値       出来高  終値調整値  week
# 0  0.0  4949  5015  4946  5013   9066700   5013     0
# 1  1.0  5071  5134  5067  5095  10985300   5095     0
# 2  5.0  5190  5203  5078  5090   7822700   5090     0
# 3  6.0  5182  5215  5168  5177   9731100   5177     0
# 4  7.0  5230  5242  5178  5228   8621500   5228     0

# %%
#Cell_5.
df_d['week'] = df_d['日付']//7 + 1

# %%
#Cell_6.
display(df_d.head())
display(df_d.tail())
# Out:
#     日付    始値    高値    安値    終値       出来高  終値調整値  week
# 0  0.0  4949  5015  4946  5013   9066700   5013   1.0
# 1  1.0  5071  5134  5067  5095  10985300   5095   1.0
# 2  5.0  5190  5203  5078  5090   7822700   5090   1.0
# 3  6.0  5182  5215  5168  5177   9731100   5177   1.0
# 4  7.0  5230  5242  5178  5228   8621500   5228   2.0
#         日付    始値    高値    安値    終値      出来高  終値調整値  week
# 100  152.0  4606  4613  4552  4576  4904600   4576  22.0
# 101  153.0  4576  4598  4564  4581  3883500   4581  22.0
# 102  154.0  4651  4665  4597  4616  5849100   4616  23.0
# 103  155.0  4555  4598  4542  4550  8140900   4550  23.0
# 104  158.0  4510  4550  4495  4542  4905700   4542  23.0

# %%
#Cell_7.
#Extract 2018 and onward.
interest = pd.read_csv('d1-5-5.csv',skiprows=525,encoding='cp932')
display(interest.head())
# Out:
#    Unnamed: 0  1.5  0  -0.06  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0        18.0  1.5  0  -0.04         NaN         NaN         NaN         NaN
# 1         NaN  1.5  0  -0.03         NaN         NaN         NaN         NaN
# 2         NaN  1.5  0  -0.04         NaN         NaN         NaN         NaN
# 3         NaN  1.5  0  -0.04         NaN         NaN         NaN         NaN
# 4         NaN  1.5  0  -0.04         NaN         NaN         NaN         NaN
#
#    Unnamed: 8  Unnamed: 9  ...  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0         NaN         NaN  ...          NaN          NaN          NaN
# 1         NaN         NaN  ...          NaN          NaN          NaN
# 2         NaN         NaN  ...          NaN          NaN          NaN
# 3         NaN         NaN  ...          NaN          NaN          NaN
# 4         NaN         NaN  ...          NaN          NaN          NaN
#
#    Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25  Unnamed: 26  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 27  Unnamed: 28
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
# [5 rows x 29 columns]

# %%
#Cell_8.
interest=interest.iloc[:,0:4]
interest.columns=['week','US','EUR','JP']
display(interest.head())
print(interest.info())
for i in range(23):
    interest.loc[i,'week']=i+1
display(interest.head(23))
# Out:
#    week   US  EUR    JP
# 0  18.0  1.5    0 -0.04
# 1   NaN  1.5    0 -0.03
# 2   NaN  1.5    0 -0.04
# 3   NaN  1.5    0 -0.04
# 4   NaN  1.5    0 -0.04
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   week    2 non-null      float64
#  1   US      77 non-null     float64
#  2   EUR     77 non-null     int64
#  3   JP      77 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 2.5 KB
# None
#     week    US  EUR    JP
# 0    1.0  1.50    0 -0.04
# 1    2.0  1.50    0 -0.03
# 2    3.0  1.50    0 -0.04
# 3    4.0  1.50    0 -0.04
# 4    5.0  1.50    0 -0.04
# 5    6.0  1.50    0 -0.03
# 6    7.0  1.50    0 -0.04
# 7    8.0  1.50    0 -0.05
# 8    9.0  1.50    0 -0.05
# 9   10.0  1.50    0 -0.06
# 10  11.0  1.50    0 -0.06
# 11  12.0  1.75    0 -0.06
# 12  13.0  1.75    0 -0.07
# 13  14.0  1.75    0 -0.06
# 14  15.0  1.75    0 -0.04
# 15  16.0  1.75    0 -0.07
# 16  17.0  1.75    0 -0.07
# 17  18.0  1.75    0 -0.08
# 18  19.0  1.75    0 -0.03
# 19  20.0  1.75    0 -0.06
# 20  21.0  1.75    0 -0.07
# 21  22.0  1.75    0 -0.07
# 22  23.0  1.75    0 -0.07

# %%
#Cell_9.
interest2 = interest.iloc[0:23,:]
display(interest2)
# Out:
#     week    US  EUR    JP
# 0    1.0  1.50    0 -0.04
# 1    2.0  1.50    0 -0.03
# 2    3.0  1.50    0 -0.04
# 3    4.0  1.50    0 -0.04
# 4    5.0  1.50    0 -0.04
# 5    6.0  1.50    0 -0.03
# 6    7.0  1.50    0 -0.04
# 7    8.0  1.50    0 -0.05
# 8    9.0  1.50    0 -0.05
# 9   10.0  1.50    0 -0.06
# 10  11.0  1.50    0 -0.06
# 11  12.0  1.75    0 -0.06
# 12  13.0  1.75    0 -0.07
# 13  14.0  1.75    0 -0.06
# 14  15.0  1.75    0 -0.04
# 15  16.0  1.75    0 -0.07
# 16  17.0  1.75    0 -0.07
# 17  18.0  1.75    0 -0.08
# 18  19.0  1.75    0 -0.03
# 19  20.0  1.75    0 -0.06
# 20  21.0  1.75    0 -0.07
# 21  22.0  1.75    0 -0.07
# 22  23.0  1.75    0 -0.07

# %%
#Cell_10.
df2= pd.merge(df_d,interest2,on='week',how='left')
display(df2.head())
display(df2.tail())
# Out:
#     日付    始値    高値    安値    終値       出来高  終値調整値  week   US  EUR    JP
# 0  0.0  4949  5015  4946  5013   9066700   5013   1.0  1.5    0 -0.04
# 1  1.0  5071  5134  5067  5095  10985300   5095   1.0  1.5    0 -0.04
# 2  5.0  5190  5203  5078  5090   7822700   5090   1.0  1.5    0 -0.04
# 3  6.0  5182  5215  5168  5177   9731100   5177   1.0  1.5    0 -0.04
# 4  7.0  5230  5242  5178  5228   8621500   5228   2.0  1.5    0 -0.03
#         日付    始値    高値    安値    終値      出来高  終値調整値  week    US  EUR    JP
# 100  152.0  4606  4613  4552  4576  4904600   4576  22.0  1.75    0 -0.07
# 101  153.0  4576  4598  4564  4581  3883500   4581  22.0  1.75    0 -0.07
# 102  154.0  4651  4665  4597  4616  5849100   4616  23.0  1.75    0 -0.07
# 103  155.0  4555  4598  4542  4550  8140900   4550  23.0  1.75    0 -0.07
# 104  158.0  4510  4550  4495  4542  4905700   4542  23.0  1.75    0 -0.07

# %%
#Cell_11.
plt.plot(df2['日付'],df2['US'])
plt.plot(df2['日付'],df2['EUR'])
plt.plot(df2['日付'],df2['JP'])
plt.show()

# %%
#Cell_12.
plt.plot(df2['日付'],df2['終値'])
plt.show()

# %%
#Cell_13.
X = df2[['日付','出来高','US','JP']]
Y = df2[['終値']]

# %%
#Cell_14.
X_c=sm.add_constant(X)
model=sm.OLS(Y,X_c)

# %%
#Cell_15.
results=model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     終値   R-squared:                       0.575
# Model:                            OLS   Adj. R-squared:                  0.558
# Method:                 Least Squares   F-statistic:                     33.87
# Date:                Tue, 15 Oct 2024   Prob (F-statistic):           7.52e-18
# Time:                        10:40:04   Log-Likelihood:                -685.32
# No. Observations:                 105   AIC:                             1381.
# Df Residuals:                     100   BIC:                             1394.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5272.7538    380.441     13.860      0.000    4517.970    6027.537
# 日付            -2.4097      0.815     -2.958      0.004      -4.026      -0.794
# 出来高         1.638e-05    8.3e-06      1.975      0.051   -7.67e-08    3.28e-05
# US          -190.3031    264.191     -0.720      0.473    -714.451     333.845
# JP          3630.6120   1578.198      2.300      0.023     499.512    6761.712
# ==============================================================================
# Omnibus:                        8.441   Durbin-Watson:                   0.184
# Prob(Omnibus):                  0.015   Jarque-Bera (JB):                5.408
# Skew:                           0.400   Prob(JB):                       0.0669
# Kurtosis:                       2.228   Cond. No.                     7.01e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.01e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#Cell_16.
X_dumm=X.copy()
X_scaled_ar = scale(X_dumm)
y_scaled_ar = scale(Y)

# %%
#Cell_17.
model = sm.OLS(y_scaled_ar, X_scaled_ar)
results_scaled = model.fit()
print(results_scaled.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.575
# Model:                            OLS   Adj. R-squared (uncentered):              0.559
# Method:                 Least Squares   F-statistic:                              34.21
# Date:                Tue, 15 Oct 2024   Prob (F-statistic):                    4.95e-18
# Time:                        10:40:04   Log-Likelihood:                         -104.02
# No. Observations:                 105   AIC:                                      216.0
# Df Residuals:                     101   BIC:                                      226.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.4343      0.146     -2.973      0.004      -0.724      -0.145
# x2             0.1466      0.074      1.985      0.050    6.23e-05       0.293
# x3            -0.0938      0.130     -0.724      0.471      -0.351       0.163
# x4             0.2106      0.091      2.312      0.023       0.030       0.391
# ==============================================================================
# Omnibus:                        8.441   Durbin-Watson:                   0.184
# Prob(Omnibus):                  0.015   Jarque-Bera (JB):                5.408
# Skew:                           0.400   Prob(JB):                       0.0669
# Kurtosis:                       2.228   Cond. No.                         4.72
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Cell_18.
X_test = pd.DataFrame([[1,180, 9*(10**6), 2.0, 0.001],
                       [1,365, 9*(10**6), 2.0, 0.1],
                        ],
                        columns=X_c.columns)  # example
print('X for prediction:')
display(X_test)
# Out:
# X for prediction:
#    const   日付      出来高   US     JP
# 0      1  180  9000000  2.0  0.001
# 1      1  365  9000000  2.0  0.100

# %%
#Cell_19.
#X_test_c = sm.add_constant(X_test)
y_test = results.predict(X_test)
print('Predicted y:')
print(y_test)
# Out:
# Predicted y:
# 0    4609.485671
# 1    4523.130253
# dtype: float64
