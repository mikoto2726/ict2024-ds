# %% [markdown]
# # データ・サイエンス	データ・サイエンス社会応用論 / ICT社会応用演習Ⅳ
# ## 9-2. 交通事故統計情報の分析（東京都内日次集計）

# %% [markdown]
# ### 1. 下準備
# #### 1-a) ライブラリのインポート

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import jpholiday
import japanize_matplotlib

# %% [markdown]
# #### 1-b) 交通事故統計情報の読み込み

# %%
df_accident1 = pd.read_csv('data/accident/honhyo_2019.csv', encoding='SHIFT-JIS')
df_accident2 = pd.read_csv('data/accident/honhyo_2020.csv', encoding='SHIFT-JIS')
df_accident3 = pd.read_csv('data/accident/honhyo_2021.csv', encoding='SHIFT-JIS')
df_accident = pd.concat([df_accident1, df_accident2, df_accident3])
df_accident['年月日'] = pd.to_datetime({
    'year' : df_accident['発生日時　　年'], 'month' : df_accident['発生日時　　月'], 
    'day' : df_accident['発生日時　　日']
})
df_accident
# Out:
#         資料区分  都道府県コード  警察署等コード  本票番号  事故内容  死者数  負傷者数  路線コード  上下線  地点コード  ...  \
# 0          1       10       59     1     2    0     1  40030    2      0  ...
# 1          1       10       59     2     2    0     2  40020    2      0  ...
# 2          1       10       59     3     2    0     1  50020    1      0  ...
# 3          1       10       59     4     2    0     1  40020    2      0  ...
# 4          1       10       59     5     2    0     1  40140    2      0  ...
# ...      ...      ...      ...   ...   ...  ...   ...    ...  ...    ...  ...
# 305191     1       97      114   166     2    0     4  33410    0      0  ...
# 305192     1       97      114   167     2    0     1  33410    0      0  ...
# 305193     1       97      114   168     2    0     1  10070    0      0  ...
# 305194     1       97      114   169     2    0     1  33410    0      0  ...
# 305195     1       97      114   170     2    0     1   3310    2     22  ...
#
#         エアバッグの装備（当事者B）  サイドエアバッグの装備（当事者A）  サイドエアバッグの装備（当事者B）  人身損傷程度（当事者A）  \
# 0                    2                  2                  2             4
# 1                    2                  2                  2             4
# 2                    2                  2                  2             4
# 3                    1                  2                  2             4
# 4                    2                  2                  2             4
# ...                ...                ...                ...           ...
# 305191               1                  2                  2             2
# 305192               2                  2                  2             4
# 305193               2                  2                  2             4
# 305194               0                  2                  0             4
# 305195               0                  2                  0             4
#
#         人身損傷程度（当事者B）  地点　緯度（北緯）   地点　経度（東経）  曜日(発生年月日)  祝日(発生年月日)        年月日
# 0                  4  431412959  1414947029          6          3 2018-12-28
# 1                  4  425706029  1413039991          1          3 2019-01-06
# 2                  4  424115557  1414158530          3          3 2018-12-18
# 3                  2  425647051  1413100440          7          3 2019-01-05
# 4                  2  425606992  1420518034          2          2 2018-12-31
# ...              ...        ...         ...        ...        ...        ...
# 305191             2  261031432  1273909676          6          3 2021-12-10
# 305192             2  260918133  1274003673          4          3 2021-12-15
# 305193             2  261022159  1274124558          4          3 2021-12-22
# 305194             2  260955144  1273944244          6          3 2021-12-24
# 305195             2  261152551  1273939654          2          3 2021-07-26
#
# [995611 rows x 59 columns]

# %% [markdown]
# #### 1-c) 東京都内の2019年1月1日以降のデータの抽出

# %%
df_accident_tokyo1 = df_accident[df_accident['都道府県コード'] == 54]
df_accident_tokyo1 = df_accident_tokyo1[df_accident_tokyo1['年月日'] >= datetime(2019, 12, 1)]
df_accident_tokyo1 = df_accident_tokyo1[df_accident_tokyo1['年月日'] <= datetime(2019, 12, 31)]

df_accident_tokyo1
# Out:
#         資料区分  都道府県コード  警察署等コード  本票番号  事故内容  死者数  負傷者数  路線コード  上下線  地点コード  ...  \
# 364207     1       54       59   652     2    0     1  42720    2      0  ...
# 364208     1       54       59   653     2    0     1  44010    1      0  ...
# 364209     1       54       59   654     2    0     1  44010    1      0  ...
# 364210     1       54       59   655     2    0     2  51110    1      0  ...
# 364211     1       54       59   656     2    0     1  50010    1      0  ...
# ...      ...      ...      ...   ...   ...  ...   ...    ...  ...    ...  ...
# 114423     1       54      393   224     2    0     1     10    1   3064  ...
# 159712     1       54      256   303     2    0     1  10790    0     77  ...
# 209766     1       54      263   845     2    0     1    220    2    286  ...
# 88062      1       54      262    80     2    0     1  20760    0     24  ...
# 207020     1       54      131   527     2    0     1  30660    0     42  ...
#
#         エアバッグの装備（当事者B）  サイドエアバッグの装備（当事者A）  サイドエアバッグの装備（当事者B）  人身損傷程度（当事者A）  \
# 364207               0                  2                  0             4
# 364208               2                  2                  2             4
# 364209               2                  2                  2             4
# 364210               2                  2                  2             4
# 364211               2                  2                  2             4
# ...                ...                ...                ...           ...
# 114423               0                  2                  0             4
# 159712               0                  2                  0             4
# 209766               2                  2                  2             4
# 88062                2                  2                  2             4
# 207020               2                  2                  2             4
#
#         人身損傷程度（当事者B）  地点　緯度（北緯）   地点　経度（東経）  曜日(発生年月日)  祝日(発生年月日)        年月日
# 364207             0  350414202  1370649048          2          3 2019-12-02
# 364208             4  351724615  1364648815          4          3 2019-12-04
# 364209             2  351759181  1364633592          5          3 2019-12-05
# 364210             2  350856490  1365502355          6          3 2019-12-06
# 364211             4  350238355  1365555794          6          3 2019-12-06
# ...              ...        ...         ...        ...        ...        ...
# 114423             2  345017819  1371934049          3          2 2019-12-31
# 159712             2  351634847  1365620074          6          3 2019-12-06
# 209766             2  352038206  1364744562          5          3 2019-12-26
# 88062              2  351940974  1365606853          4          3 2019-12-18
# 207020             2  351159311  1365927442          6          3 2019-12-13
#
# [2691 rows x 59 columns]

# %%
df_accident_tokyo2 = df_accident[df_accident['都道府県コード'] == 54]
df_accident_tokyo2 = df_accident_tokyo2[df_accident_tokyo2['年月日'] >= datetime(2019, 1, 1)]
df_accident_tokyo2 = df_accident_tokyo2[df_accident_tokyo2['年月日'] <= datetime(2019, 12, 31)]
df_accident_tokyo2 = df_accident_tokyo2[(df_accident_tokyo2["当事者種別（当事者A）"] == 51) | (df_accident_tokyo2["当事者種別（当事者B）"] == 51)]

df_accident_tokyo2
# Out:
#         資料区分  都道府県コード  警察署等コード  本票番号  事故内容  死者数  負傷者数  路線コード  上下線  地点コード  ...  \
# 16339      1       54      101     8     2    0     1  21150    0     43  ...
# 16350      1       54      101    20     2    0     1  10490    0     88  ...
# 16355      1       54      101    27     2    0     1  30000    0      0  ...
# 16363      1       54      101    35     2    0     1  10490    0     57  ...
# 16368      1       54      101    40     2    0     1  30450    0     11  ...
# ...      ...      ...      ...   ...   ...  ...   ...    ...  ...    ...  ...
# 94699      1       54      384   152     2    0     1  35000    0      0  ...
# 113741     1       54      256   196     2    0     1  99000    0      0  ...
# 134943     1       54      142   137     2    0     1  30000    0      0  ...
# 159712     1       54      256   303     2    0     1  10790    0     77  ...
# 265696     1       54      278   539     2    0     1  35000    0      0  ...
#
#         エアバッグの装備（当事者B）  サイドエアバッグの装備（当事者A）  サイドエアバッグの装備（当事者B）  人身損傷程度（当事者A）  \
# 16339                0                  2                  0             4
# 16350                0                  2                  0             4
# 16355                0                  0                  0             2
# 16363                0                  2                  0             4
# 16368                0                  2                  0             4
# ...                ...                ...                ...           ...
# 94699                0                  0                  0             4
# 113741               0                  2                  0             4
# 134943               0                  0                  0             4
# 159712               0                  2                  0             4
# 265696               0                  0                  0             2
#
#         人身損傷程度（当事者B）  地点　緯度（北緯）   地点　経度（東経）  曜日(発生年月日)  祝日(発生年月日)        年月日
# 16339              2  351109739  1365814850          3          1 2019-01-01
# 16350              2  350941427  1365810180          6          3 2019-01-11
# 16355              0  351038724  1365638639          6          3 2019-01-18
# 16363              2  351008730  1365613990          3          3 2019-01-22
# 16368              2  350939689  1365613263          3          3 2019-01-15
# ...              ...        ...         ...        ...        ...        ...
# 94699              2  344722491  1370111661          4          3 2019-11-06
# 113741             2  351720837  1365524900          7          3 2019-10-19
# 134943             2  351124607  1365928378          5          3 2019-11-21
# 159712             2  351634847  1365620074          6          3 2019-12-06
# 265696             0  350032704  1365719091          4          3 2019-11-27
#
# [7063 rows x 59 columns]

# %%
df_accident_tokyo = df_accident[df_accident['都道府県コード'] == 54]
df_accident_tokyo = df_accident_tokyo[df_accident_tokyo['年月日'] >= datetime(2019, 1, 1)]
df_accident_tokyo
# Out:
#         資料区分  都道府県コード  警察署等コード  本票番号  事故内容  死者数  負傷者数  路線コード  上下線  地点コード  ...  \
# 16288      1       54       59     1     2    0     1  42710    1      0  ...
# 16289      1       54       59     2     2    0     4  42720    2      0  ...
# 16290      1       54       59     3     2    0     2  44110    1      0  ...
# 16291      1       54       59     4     2    0     3  44010    1      0  ...
# 16292      1       54       59     5     2    0     1  44020    2      0  ...
# ...      ...      ...      ...   ...   ...  ...   ...    ...  ...    ...  ...
# 292585     1       54      396   141     2    0     1  35000    0      0  ...
# 292586     1       54      396   142     2    0     1  35000    0      0  ...
# 292587     1       54      396   143     2    0     1   2590    0    329  ...
# 292588     1       54      396   144     2    0     1  23120    0      0  ...
# 292589     1       54      396   145     2    0     1  35000    0      0  ...
#
#         エアバッグの装備（当事者B）  サイドエアバッグの装備（当事者A）  サイドエアバッグの装備（当事者B）  人身損傷程度（当事者A）  \
# 16288                2                  2                  2             4
# 16289                2                  2                  2             4
# 16290                2                  2                  2             2
# 16291                2                  2                  2             4
# 16292                0                  2                  0             4
# ...                ...                ...                ...           ...
# 292585               0                  1                  0             4
# 292586               2                  2                  2             4
# 292587               2                  2                  2             4
# 292588               2                  2                  2             4
# 292589               2                  2                  2             2
#
#         人身損傷程度（当事者B）  地点　緯度（北緯）   地点　経度（東経）  曜日(発生年月日)  祝日(発生年月日)        年月日
# 16288              2  345423106  1371457542          4          3 2019-01-02
# 16289              2  345652015  1371150810          4          3 2019-01-02
# 16290              4  351232142  1365902160          5          3 2019-01-03
# 16291              2  351730716  1364647009          5          3 2019-01-03
# 16292              0  351700251  1364649459          7          3 2019-01-05
# ...              ...        ...         ...        ...        ...        ...
# 292585             0  343829247  1371653481          1          3 2021-12-19
# 292586             2  344248268  1371651661          4          3 2021-12-08
# 292587             2  344023821  1371803750          6          3 2021-12-24
# 292588             2  343958196  1371733031          7          3 2021-12-18
# 292589             4  343957349  1371552153          2          3 2021-12-27
#
# [79351 rows x 59 columns]

# %% [markdown]
# #### 1-d) 日毎の集計

# %%
df_accident_tokyo_daily = df_accident_tokyo.groupby(['年月日'], as_index=False)[['死者数', '負傷者数']].sum()
df_accident_tokyo_daily
# Out:
#             年月日  死者数  負傷者数
# 0    2019-01-01    0    44
# 1    2019-01-02    0    73
# 2    2019-01-03    0    84
# 3    2019-01-04    0   113
# 4    2019-01-05    0    57
# ...         ...  ...   ...
# 1091 2021-12-27    0    86
# 1092 2021-12-28    2    80
# 1093 2021-12-29    0    47
# 1094 2021-12-30    0    34
# 1095 2021-12-31    0    33
#
# [1096 rows x 3 columns]

# %% [markdown]
# #### 1-e) 気象データの読み込み

# %%
df_weather = pd.read_csv('data/weather/weather_aichi.csv', encoding='SHIFT-JIS', header=2)
df_weather = df_weather.drop([0,1]).reset_index(drop=True)
df_weather['年月日'] = pd.to_datetime(df_weather['年月日'])
df_weather
# Out:
#             年月日  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  降雪量合計(cm)  \
# 0    2019-01-01      9.7     -1.4         0.0            0        0.0
# 1    2019-01-02     10.5      3.4         0.0            0        0.0
# 2    2019-01-03      9.9      1.7         0.0            0        0.0
# 3    2019-01-04     10.3     -0.1         0.0            1        0.0
# 4    2019-01-05     10.3      4.3         0.0            0        0.0
# ...         ...      ...      ...         ...          ...        ...
# 1091 2021-12-27      2.7     -1.2         2.5            0        2.0
# 1092 2021-12-28      7.9      0.8         0.0            0        0.0
# 1093 2021-12-29      8.8     -0.1         0.0            0        0.0
# 1094 2021-12-30     11.0      2.1         0.0            0        0.0
# 1095 2021-12-31      5.0     -0.7         3.5            0        1.0
#
#      降雪量合計(cm).1  最深積雪(cm) 最深積雪(cm).1  日照時間(時間) 日照時間(時間).1  平均風速(m/s)  \
# 0              1       0.0          1       8.9          0        1.9
# 1              1       0.0          1       8.9          0        4.3
# 2              1       0.0          1       9.4          0        4.3
# 3              1       0.0          1       9.3          0        2.1
# 4              1       0.0          1       2.0          0        2.8
# ...          ...       ...        ...       ...        ...        ...
# 1091           0       2.0          0       1.6          0        2.2
# 1092           1       0.0          1       8.7          0        3.5
# 1093           1       0.0          1       1.7          0        1.7
# 1094           1       0.0          1       4.7          0        3.9
# 1095           0       1.0          0       2.8          0        4.2
#
#      天気概況(昼：06時〜18時) 天気概況(夜：18時〜翌日06時)
# 0                  晴           曇時々晴一時雨
# 1                  晴             晴後一時雨
# 2                  晴                快晴
# 3                  晴               曇後雨
# 4             曇一時雨後晴                 晴
# ...              ...               ...
# 1091       雪時々曇一時みぞれ         晴時々曇一時みぞれ
# 1092               晴             薄曇時々晴
# 1093               曇           曇時々晴一時雨
# 1094            晴時々曇           曇時々雨一時雪
# 1095         雪時々曇一時晴           晴時々曇一時雪
#
# [1096 rows x 14 columns]

# %% [markdown]
# #### 1-f) 事故データと気象データの結合

# %%
df_accident_weather = pd.merge(df_accident_tokyo_daily, df_weather, on='年月日', how='right').fillna(0)
df_accident_weather
# Out:
#             年月日  死者数  負傷者数  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  \
# 0    2019-01-01    0    44      9.7     -1.4         0.0            0
# 1    2019-01-02    0    73     10.5      3.4         0.0            0
# 2    2019-01-03    0    84      9.9      1.7         0.0            0
# 3    2019-01-04    0   113     10.3     -0.1         0.0            1
# 4    2019-01-05    0    57     10.3      4.3         0.0            0
# ...         ...  ...   ...      ...      ...         ...          ...
# 1091 2021-12-27    0    86      2.7     -1.2         2.5            0
# 1092 2021-12-28    2    80      7.9      0.8         0.0            0
# 1093 2021-12-29    0    47      8.8     -0.1         0.0            0
# 1094 2021-12-30    0    34     11.0      2.1         0.0            0
# 1095 2021-12-31    0    33      5.0     -0.7         3.5            0
#
#       降雪量合計(cm) 降雪量合計(cm).1  最深積雪(cm) 最深積雪(cm).1  日照時間(時間) 日照時間(時間).1  \
# 0           0.0           1       0.0          1       8.9          0
# 1           0.0           1       0.0          1       8.9          0
# 2           0.0           1       0.0          1       9.4          0
# 3           0.0           1       0.0          1       9.3          0
# 4           0.0           1       0.0          1       2.0          0
# ...         ...         ...       ...        ...       ...        ...
# 1091        2.0           0       2.0          0       1.6          0
# 1092        0.0           1       0.0          1       8.7          0
# 1093        0.0           1       0.0          1       1.7          0
# 1094        0.0           1       0.0          1       4.7          0
# 1095        1.0           0       1.0          0       2.8          0
#
#       平均風速(m/s) 天気概況(昼：06時〜18時) 天気概況(夜：18時〜翌日06時)
# 0           1.9               晴           曇時々晴一時雨
# 1           4.3               晴             晴後一時雨
# 2           4.3               晴                快晴
# 3           2.1               晴               曇後雨
# 4           2.8          曇一時雨後晴                 晴
# ...         ...             ...               ...
# 1091        2.2       雪時々曇一時みぞれ         晴時々曇一時みぞれ
# 1092        3.5               晴             薄曇時々晴
# 1093        1.7               曇           曇時々晴一時雨
# 1094        3.9            晴時々曇           曇時々雨一時雪
# 1095        4.2         雪時々曇一時晴           晴時々曇一時雪
#
# [1096 rows x 16 columns]

# %% [markdown]
# #### 1-g) 曜日と祝日の追加

# %%
df_accident_weather['曜日'] = df_accident_weather['年月日'].dt.weekday
df_accident_weather['祝日'] = df_accident_weather['年月日'].dt.date.map(jpholiday.is_holiday).astype(int)
df_accident_weather
# Out:
#             年月日  死者数  負傷者数  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  \
# 0    2019-01-01    0    44      9.7     -1.4         0.0            0
# 1    2019-01-02    0    73     10.5      3.4         0.0            0
# 2    2019-01-03    0    84      9.9      1.7         0.0            0
# 3    2019-01-04    0   113     10.3     -0.1         0.0            1
# 4    2019-01-05    0    57     10.3      4.3         0.0            0
# ...         ...  ...   ...      ...      ...         ...          ...
# 1091 2021-12-27    0    86      2.7     -1.2         2.5            0
# 1092 2021-12-28    2    80      7.9      0.8         0.0            0
# 1093 2021-12-29    0    47      8.8     -0.1         0.0            0
# 1094 2021-12-30    0    34     11.0      2.1         0.0            0
# 1095 2021-12-31    0    33      5.0     -0.7         3.5            0
#
#       降雪量合計(cm) 降雪量合計(cm).1  最深積雪(cm) 最深積雪(cm).1  日照時間(時間) 日照時間(時間).1  \
# 0           0.0           1       0.0          1       8.9          0
# 1           0.0           1       0.0          1       8.9          0
# 2           0.0           1       0.0          1       9.4          0
# 3           0.0           1       0.0          1       9.3          0
# 4           0.0           1       0.0          1       2.0          0
# ...         ...         ...       ...        ...       ...        ...
# 1091        2.0           0       2.0          0       1.6          0
# 1092        0.0           1       0.0          1       8.7          0
# 1093        0.0           1       0.0          1       1.7          0
# 1094        0.0           1       0.0          1       4.7          0
# 1095        1.0           0       1.0          0       2.8          0
#
#       平均風速(m/s) 天気概況(昼：06時〜18時) 天気概況(夜：18時〜翌日06時)  曜日  祝日
# 0           1.9               晴           曇時々晴一時雨   1   1
# 1           4.3               晴             晴後一時雨   2   0
# 2           4.3               晴                快晴   3   0
# 3           2.1               晴               曇後雨   4   0
# 4           2.8          曇一時雨後晴                 晴   5   0
# ...         ...             ...               ...  ..  ..
# 1091        2.2       雪時々曇一時みぞれ         晴時々曇一時みぞれ   0   0
# 1092        3.5               晴             薄曇時々晴   1   0
# 1093        1.7               曇           曇時々晴一時雨   2   0
# 1094        3.9            晴時々曇           曇時々雨一時雪   3   0
# 1095        4.2         雪時々曇一時晴           晴時々曇一時雪   4   0
#
# [1096 rows x 18 columns]

# %% [markdown]
# ### 2. 負傷者数の可視化
# #### 2-a) 負傷者数と死者数の推移の可視化

# %%
df_accident_weather.plot(x='年月日', y=['負傷者数', '死者数'], figsize=(20,4))
plt.show()

# %% [markdown]
# #### 2-b) 曜日と負傷者数の関係の可視化

# %%
df_accident_weather.groupby('曜日')['負傷者数'].describe()
# Out:
#     count        mean        std   min    25%    50%     75%    max
# 曜日
# 0   156.0   89.480769  21.280150  20.0  74.75   89.0  102.25  156.0
# 1   157.0   88.878981  21.127619  42.0  76.00   90.0  104.00  146.0
# 2   157.0   88.044586  21.503233  31.0  74.00   89.0  101.00  142.0
# 3   157.0   89.777070  20.594560  34.0  76.00   92.0  104.00  138.0
# 4   157.0  100.312102  23.600536  31.0  86.00  100.0  116.00  160.0
# 5   156.0   81.153846  19.427335  41.0  66.75   81.0   93.50  131.0
# 6   156.0   66.070513  18.981523  27.0  51.75   66.0   77.00  119.0

# %%
df_accident_weather.boxplot('負傷者数', '曜日')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2-c) 過去1週間の移動平均の算出

# %%
df_accident_weather['負傷者数_移動平均'] = df_accident_weather['負傷者数'].rolling(7).mean()
df_accident_weather['死者数_移動平均'] = df_accident_weather['死者数'].rolling(7).mean()
df_accident_weather
# Out:
#             年月日  死者数  負傷者数  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  \
# 0    2019-01-01    0    44      9.7     -1.4         0.0            0
# 1    2019-01-02    0    73     10.5      3.4         0.0            0
# 2    2019-01-03    0    84      9.9      1.7         0.0            0
# 3    2019-01-04    0   113     10.3     -0.1         0.0            1
# 4    2019-01-05    0    57     10.3      4.3         0.0            0
# ...         ...  ...   ...      ...      ...         ...          ...
# 1091 2021-12-27    0    86      2.7     -1.2         2.5            0
# 1092 2021-12-28    2    80      7.9      0.8         0.0            0
# 1093 2021-12-29    0    47      8.8     -0.1         0.0            0
# 1094 2021-12-30    0    34     11.0      2.1         0.0            0
# 1095 2021-12-31    0    33      5.0     -0.7         3.5            0
#
#       降雪量合計(cm) 降雪量合計(cm).1  最深積雪(cm) 最深積雪(cm).1  日照時間(時間) 日照時間(時間).1  \
# 0           0.0           1       0.0          1       8.9          0
# 1           0.0           1       0.0          1       8.9          0
# 2           0.0           1       0.0          1       9.4          0
# 3           0.0           1       0.0          1       9.3          0
# 4           0.0           1       0.0          1       2.0          0
# ...         ...         ...       ...        ...       ...        ...
# 1091        2.0           0       2.0          0       1.6          0
# 1092        0.0           1       0.0          1       8.7          0
# 1093        0.0           1       0.0          1       1.7          0
# 1094        0.0           1       0.0          1       4.7          0
# 1095        1.0           0       1.0          0       2.8          0
#
#       平均風速(m/s) 天気概況(昼：06時〜18時) 天気概況(夜：18時〜翌日06時)  曜日  祝日  負傷者数_移動平均  死者数_移動平均
# 0           1.9               晴           曇時々晴一時雨   1   1        NaN       NaN
# 1           4.3               晴             晴後一時雨   2   0        NaN       NaN
# 2           4.3               晴                快晴   3   0        NaN       NaN
# 3           2.1               晴               曇後雨   4   0        NaN       NaN
# 4           2.8          曇一時雨後晴                 晴   5   0        NaN       NaN
# ...         ...             ...               ...  ..  ..        ...       ...
# 1091        2.2       雪時々曇一時みぞれ         晴時々曇一時みぞれ   0   0  71.714286  0.142857
# 1092        3.5               晴             薄曇時々晴   1   0  72.285714  0.428571
# 1093        1.7               曇           曇時々晴一時雨   2   0  69.714286  0.428571
# 1094        3.9            晴時々曇           曇時々雨一時雪   3   0  60.285714  0.428571
# 1095        4.2         雪時々曇一時晴           晴時々曇一時雪   4   0  52.714286  0.428571
#
# [1096 rows x 20 columns]

# %% [markdown]
# #### 2-d) 負傷者数および死者数の移動平均の推移の可視化

# %%
df_accident_weather.plot(x='年月日', y=['負傷者数_移動平均', '死者数_移動平均'], figsize=(20,4))
plt.show()

# %% [markdown]
# #### 2-e) 前年比の算出

# %%
df_accident_weather['前年'] = df_accident_weather['年月日'] - timedelta(days=365)
df_accident_weather
# Out:
#             年月日  死者数  負傷者数  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  \
# 0    2019-01-01    0    44      9.7     -1.4         0.0            0
# 1    2019-01-02    0    73     10.5      3.4         0.0            0
# 2    2019-01-03    0    84      9.9      1.7         0.0            0
# 3    2019-01-04    0   113     10.3     -0.1         0.0            1
# 4    2019-01-05    0    57     10.3      4.3         0.0            0
# ...         ...  ...   ...      ...      ...         ...          ...
# 1091 2021-12-27    0    86      2.7     -1.2         2.5            0
# 1092 2021-12-28    2    80      7.9      0.8         0.0            0
# 1093 2021-12-29    0    47      8.8     -0.1         0.0            0
# 1094 2021-12-30    0    34     11.0      2.1         0.0            0
# 1095 2021-12-31    0    33      5.0     -0.7         3.5            0
#
#       降雪量合計(cm) 降雪量合計(cm).1  最深積雪(cm)  ... 日照時間(時間)  日照時間(時間).1 平均風速(m/s)  \
# 0           0.0           1       0.0  ...      8.9           0       1.9
# 1           0.0           1       0.0  ...      8.9           0       4.3
# 2           0.0           1       0.0  ...      9.4           0       4.3
# 3           0.0           1       0.0  ...      9.3           0       2.1
# 4           0.0           1       0.0  ...      2.0           0       2.8
# ...         ...         ...       ...  ...      ...         ...       ...
# 1091        2.0           0       2.0  ...      1.6           0       2.2
# 1092        0.0           1       0.0  ...      8.7           0       3.5
# 1093        0.0           1       0.0  ...      1.7           0       1.7
# 1094        0.0           1       0.0  ...      4.7           0       3.9
# 1095        1.0           0       1.0  ...      2.8           0       4.2
#
#       天気概況(昼：06時〜18時) 天気概況(夜：18時〜翌日06時) 曜日  祝日  負傷者数_移動平均  死者数_移動平均         前年
# 0                   晴           曇時々晴一時雨  1   1        NaN       NaN 2018-01-01
# 1                   晴             晴後一時雨  2   0        NaN       NaN 2018-01-02
# 2                   晴                快晴  3   0        NaN       NaN 2018-01-03
# 3                   晴               曇後雨  4   0        NaN       NaN 2018-01-04
# 4              曇一時雨後晴                 晴  5   0        NaN       NaN 2018-01-05
# ...               ...               ... ..  ..        ...       ...        ...
# 1091        雪時々曇一時みぞれ         晴時々曇一時みぞれ  0   0  71.714286  0.142857 2020-12-27
# 1092                晴             薄曇時々晴  1   0  72.285714  0.428571 2020-12-28
# 1093                曇           曇時々晴一時雨  2   0  69.714286  0.428571 2020-12-29
# 1094             晴時々曇           曇時々雨一時雪  3   0  60.285714  0.428571 2020-12-30
# 1095          雪時々曇一時晴           晴時々曇一時雪  4   0  52.714286  0.428571 2020-12-31
#
# [1096 rows x 21 columns]

# %%
df_tmp = df_accident_weather[['年月日', '負傷者数_移動平均']].rename(columns={
    '年月日' : '前年', '負傷者数_移動平均' : '前年_負傷者数_移動平均'
})
df_tmp
# Out:
#              前年  前年_負傷者数_移動平均
# 0    2019-01-01           NaN
# 1    2019-01-02           NaN
# 2    2019-01-03           NaN
# 3    2019-01-04           NaN
# 4    2019-01-05           NaN
# ...         ...           ...
# 1091 2021-12-27     71.714286
# 1092 2021-12-28     72.285714
# 1093 2021-12-29     69.714286
# 1094 2021-12-30     60.285714
# 1095 2021-12-31     52.714286
#
# [1096 rows x 2 columns]

# %%
df_accident_weather_compare = pd.merge(df_accident_weather, df_tmp, on='前年')
df_accident_weather_compare['負傷者数_前年比'] = df_accident_weather_compare['負傷者数_移動平均'] / df_accident_weather_compare['前年_負傷者数_移動平均']

df_accident_weather_compare
# Out:
#            年月日  死者数  負傷者数  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  \
# 0   2020-01-01    1    37      9.3      0.7         0.0            0
# 1   2020-01-02    0    72     11.9      4.0         0.0            0
# 2   2020-01-03    0    75     11.9      4.4         0.0            0
# 3   2020-01-04    0    90     11.5      4.6         0.0            0
# 4   2020-01-05    1    51      9.5      3.3         0.0            1
# ..         ...  ...   ...      ...      ...         ...          ...
# 726 2021-12-27    0    86      2.7     -1.2         2.5            0
# 727 2021-12-28    2    80      7.9      0.8         0.0            0
# 728 2021-12-29    0    47      8.8     -0.1         0.0            0
# 729 2021-12-30    0    34     11.0      2.1         0.0            0
# 730 2021-12-31    0    33      5.0     -0.7         3.5            0
#
#      降雪量合計(cm) 降雪量合計(cm).1  最深積雪(cm)  ... 平均風速(m/s)  天気概況(昼：06時〜18時)  \
# 0          0.0           1       0.0  ...       3.3             曇時々晴
# 1          0.0           1       0.0  ...       2.6             曇時々晴
# 2          0.0           1       0.0  ...       2.6             曇時々晴
# 3          0.0           1       0.0  ...       3.2             曇時々晴
# 4          0.0           1       0.0  ...       5.2                晴
# ..         ...         ...       ...  ...       ...              ...
# 726        2.0           0       2.0  ...       2.2        雪時々曇一時みぞれ
# 727        0.0           1       0.0  ...       3.5                晴
# 728        0.0           1       0.0  ...       1.7                曇
# 729        0.0           1       0.0  ...       3.9             晴時々曇
# 730        1.0           0       1.0  ...       4.2          雪時々曇一時晴
#
#     天気概況(夜：18時〜翌日06時)  曜日 祝日  負傷者数_移動平均  死者数_移動平均         前年  前年_負傷者数_移動平均  \
# 0                曇時々晴   2  1  76.000000  0.428571 2019-01-01           NaN
# 1                曇時々晴   3  0  71.285714  0.428571 2019-01-02           NaN
# 2                曇時々晴   4  0  65.428571  0.428571 2019-01-03           NaN
# 3                晴一時雨   5  0  65.714286  0.285714 2019-01-04           NaN
# 4                  快晴   6  0  61.285714  0.428571 2019-01-05           NaN
# ..                ...  .. ..        ...       ...        ...           ...
# 726         晴時々曇一時みぞれ   0  0  71.714286  0.142857 2020-12-27     94.142857
# 727             薄曇時々晴   1  0  72.285714  0.428571 2020-12-28     95.571429
# 728           曇時々晴一時雨   2  0  69.714286  0.428571 2020-12-29     93.142857
# 729           曇時々雨一時雪   3  0  60.285714  0.428571 2020-12-30     87.285714
# 730           晴時々曇一時雪   4  0  52.714286  0.428571 2020-12-31     76.000000
#
#      負傷者数_前年比
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 726  0.761760
# 727  0.756353
# 728  0.748466
# 729  0.690671
# 730  0.693609
#
# [731 rows x 23 columns]

# %% [markdown]
# #### 2-f) 前々年比の算出

# %%
df_accident_weather_compare['前々年'] = df_accident_weather_compare['年月日'] - timedelta(days=365 + 366)

df_tmp2 = df_accident_weather[['年月日', '負傷者数_移動平均']].rename(columns={
    '年月日' : '前々年', '負傷者数_移動平均' : '前々年_負傷者数_移動平均'
})

df_accident_weather_compare = pd.merge(df_accident_weather_compare, df_tmp2, on='前々年', how='left')
df_accident_weather_compare['負傷者数_前々年比'] = df_accident_weather_compare['負傷者数_移動平均'] / df_accident_weather_compare['前々年_負傷者数_移動平均']

df_accident_weather_compare
# Out:
#            年月日  死者数  負傷者数  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  \
# 0   2020-01-01    1    37      9.3      0.7         0.0            0
# 1   2020-01-02    0    72     11.9      4.0         0.0            0
# 2   2020-01-03    0    75     11.9      4.4         0.0            0
# 3   2020-01-04    0    90     11.5      4.6         0.0            0
# 4   2020-01-05    1    51      9.5      3.3         0.0            1
# ..         ...  ...   ...      ...      ...         ...          ...
# 726 2021-12-27    0    86      2.7     -1.2         2.5            0
# 727 2021-12-28    2    80      7.9      0.8         0.0            0
# 728 2021-12-29    0    47      8.8     -0.1         0.0            0
# 729 2021-12-30    0    34     11.0      2.1         0.0            0
# 730 2021-12-31    0    33      5.0     -0.7         3.5            0
#
#      降雪量合計(cm) 降雪量合計(cm).1  最深積雪(cm)  ... 曜日  祝日  負傷者数_移動平均  死者数_移動平均  \
# 0          0.0           1       0.0  ...  2   1  76.000000  0.428571
# 1          0.0           1       0.0  ...  3   0  71.285714  0.428571
# 2          0.0           1       0.0  ...  4   0  65.428571  0.428571
# 3          0.0           1       0.0  ...  5   0  65.714286  0.285714
# 4          0.0           1       0.0  ...  6   0  61.285714  0.428571
# ..         ...         ...       ...  ... ..  ..        ...       ...
# 726        2.0           0       2.0  ...  0   0  71.714286  0.142857
# 727        0.0           1       0.0  ...  1   0  72.285714  0.428571
# 728        0.0           1       0.0  ...  2   0  69.714286  0.428571
# 729        0.0           1       0.0  ...  3   0  60.285714  0.428571
# 730        1.0           0       1.0  ...  4   0  52.714286  0.428571
#
#             前年 前年_負傷者数_移動平均  負傷者数_前年比        前々年  前々年_負傷者数_移動平均  負傷者数_前々年比
# 0   2019-01-01          NaN       NaN 2017-12-31            NaN        NaN
# 1   2019-01-02          NaN       NaN 2018-01-01            NaN        NaN
# 2   2019-01-03          NaN       NaN 2018-01-02            NaN        NaN
# 3   2019-01-04          NaN       NaN 2018-01-03            NaN        NaN
# 4   2019-01-05          NaN       NaN 2018-01-04            NaN        NaN
# ..         ...          ...       ...        ...            ...        ...
# 726 2020-12-27    94.142857  0.761760 2019-12-27     123.285714   0.581692
# 727 2020-12-28    95.571429  0.756353 2019-12-28     118.857143   0.608173
# 728 2020-12-29    93.142857  0.748466 2019-12-29     117.285714   0.594397
# 729 2020-12-30    87.285714  0.690671 2019-12-30     103.571429   0.582069
# 730 2020-12-31    76.000000  0.693609 2019-12-31      89.142857   0.591346
#
# [731 rows x 26 columns]

# %% [markdown]
# #### 2-g) 負傷者数の前年・前々年比の推移（移動平均）

# %%
df_accident_weather_compare.plot(x='年月日', y=['負傷者数_前年比', '負傷者数_前々年比'], figsize=(20,4))
plt.show()

# %% [markdown]
# ### 3. 気象データと組み合わせた分析
# #### 3-a) データの絞り込み

# %%
df_accident_weather_2019 = df_accident_weather[df_accident_weather['年月日'] <= datetime(2019, 12, 31)]
df_accident_weather_2019
# Out:
#            年月日  死者数  負傷者数  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  \
# 0   2019-01-01    0    44      9.7     -1.4         0.0            0
# 1   2019-01-02    0    73     10.5      3.4         0.0            0
# 2   2019-01-03    0    84      9.9      1.7         0.0            0
# 3   2019-01-04    0   113     10.3     -0.1         0.0            1
# 4   2019-01-05    0    57     10.3      4.3         0.0            0
# ..         ...  ...   ...      ...      ...         ...          ...
# 360 2019-12-27    0   116     12.3      4.9         8.0            0
# 361 2019-12-28    1    88     10.8      2.5         0.0            1
# 362 2019-12-29    0    82     12.4      1.2         0.0            1
# 363 2019-12-30    1    60      8.8      5.8        11.5            0
# 364 2019-12-31    0    44     12.7      2.7         0.0            1
#
#      降雪量合計(cm) 降雪量合計(cm).1  最深積雪(cm)  ... 日照時間(時間)  日照時間(時間).1 平均風速(m/s)  \
# 0          0.0           1       0.0  ...      8.9           0       1.9
# 1          0.0           1       0.0  ...      8.9           0       4.3
# 2          0.0           1       0.0  ...      9.4           0       4.3
# 3          0.0           1       0.0  ...      9.3           0       2.1
# 4          0.0           1       0.0  ...      2.0           0       2.8
# ..         ...         ...       ...  ...      ...         ...       ...
# 360        0.0           1       0.0  ...      7.2           0       5.9
# 361        0.0           1       0.0  ...      9.3           0       3.2
# 362        0.0           1       0.0  ...      6.8           0       1.5
# 363        0.0           1       0.0  ...      0.0           0       1.9
# 364        0.0           1       0.0  ...      4.2           0       4.8
#
#      天気概況(昼：06時〜18時) 天気概況(夜：18時〜翌日06時) 曜日  祝日   負傷者数_移動平均  死者数_移動平均         前年
# 0                  晴           曇時々晴一時雨  1   1         NaN       NaN 2018-01-01
# 1                  晴             晴後一時雨  2   0         NaN       NaN 2018-01-02
# 2                  晴                快晴  3   0         NaN       NaN 2018-01-03
# 3                  晴               曇後雨  4   0         NaN       NaN 2018-01-04
# 4             曇一時雨後晴                 晴  5   0         NaN       NaN 2018-01-05
# ..               ...               ... ..  ..         ...       ...        ...
# 360                晴                 晴  4   0  123.285714  0.428571 2018-12-27
# 361               快晴                快晴  5   0  118.857143  0.571429 2018-12-28
# 362              晴後曇             曇後時々雨  6   0  117.285714  0.428571 2018-12-29
# 363             雨一時曇                 曇  0   0  103.571429  0.428571 2018-12-30
# 364              曇後晴                快晴  1   0   89.142857  0.285714 2018-12-31
#
# [365 rows x 21 columns]

# %% [markdown]
# #### 3-b) 降水量と負傷者数の関係

# %%
df_accident_weather_2019.plot.scatter('降水量の合計(mm)', '負傷者数')
plt.show()

# %%
df_accident_weather_2019[['降水量の合計(mm)', '負傷者数']].corr()
# Out:
#             降水量の合計(mm)     負傷者数
# 降水量の合計(mm)     1.00000  0.11567
# 負傷者数           0.11567  1.00000

# %% [markdown]
# #### 3-c) 降雨がない時の統計量の確認

# %%
df_accident_weather_norain = df_accident_weather_2019[df_accident_weather_2019['降水量の合計(mm)'] == 0]['負傷者数']
df_accident_weather_norain.describe()
# Out:
# count    246.000000
# mean      99.703252
# std       19.374224
# min       37.000000
# 25%       88.250000
# 50%      101.000000
# 75%      113.000000
# max      148.000000
# Name: 負傷者数, dtype: float64

# %% [markdown]
# #### 3-d) 降雨がある時の統計量の確認

# %%
df_accident_weather_rain = df_accident_weather_2019[df_accident_weather_2019['降水量の合計(mm)'] > 0]['負傷者数']
df_accident_weather_rain.describe()
# Out:
# count    119.000000
# mean     103.890756
# std       22.953080
# min       41.000000
# 25%       90.000000
# 50%      104.000000
# 75%      119.000000
# max      160.000000
# Name: 負傷者数, dtype: float64

# %%
df_accident_tokyo = df_accident[df_accident['都道府県コード'] == 13]
df_accident_tokyo = df_accident_tokyo[df_accident_tokyo['年月日'] >= datetime(2019, 12, 1)]
df_accident_tokyo = df_accident_tokyo[df_accident_tokyo['年月日'] <= datetime(2019, 12, 31)]

df_accident_tokyo
# Out:
#         資料区分  都道府県コード  警察署等コード  本票番号  事故内容  死者数  負傷者数  路線コード  上下線  地点コード  ...  \
# 346883     1       13      401   213     2    0     1  39990    0      0  ...
# 346891     1       13      401   221     2    0     1    380    0     41  ...
# 346892     1       13      401   222     2    0     1  39990    0      0  ...
# 346894     1       13      401   224     2    0     1    440    0     36  ...
# 346896     1       13      401   226     2    0     1  11270    0      0  ...
# ...      ...      ...      ...   ...   ...  ...   ...    ...  ...    ...  ...
# 28382      1       13      408    24     2    0     1  99000    0      0  ...
# 28386      1       13      408    28     2    0     1  38880    0      0  ...
# 28402      1       13      408    44     2    0     1  39990    0      0  ...
# 28403      1       13      408    45     2    0     1  39990    0      0  ...
# 55939      1       13      408    65     2    0     1  21520    0      0  ...
#
#         エアバッグの装備（当事者B）  サイドエアバッグの装備（当事者A）  サイドエアバッグの装備（当事者B）  人身損傷程度（当事者A）  \
# 346883               0                  2                  0             4
# 346891               2                  2                  2             4
# 346892               2                  2                  2             4
# 346894               0                  2                  0             4
# 346896               2                  2                  1             4
# ...                ...                ...                ...           ...
# 28382                0                  2                  0             4
# 28386                2                  2                  2             4
# 28402                0                  2                  0             2
# 28403                2                  2                  2             4
# 55939                0                  1                  0             4
#
#         人身損傷程度（当事者B）  地点　緯度（北緯）   地点　経度（東経）  曜日(発生年月日)  祝日(発生年月日)        年月日
# 346883             2  425922342  1442213513          5          3 2019-12-05
# 346891             2  430030955  1442144042          2          3 2019-12-09
# 346892             2  430025731  1442324049          2          3 2019-12-09
# 346894             2  430033230  1442425166          1          3 2019-12-15
# 346896             4  430104936  1442150561          1          3 2019-12-08
# ...              ...        ...         ...        ...        ...        ...
# 28382              2  425328167  1431202891          2          3 2019-12-30
# 28386              2  425429760  1430254929          3          3 2019-12-24
# 28402              0  425320758  1431201731          7          3 2019-12-28
# 28403              2  425528984  1431110848          3          3 2019-12-17
# 55939              0  425809906  1431107731          1          3 2019-12-22
#
# [64 rows x 59 columns]
