# %% [markdown]
# # データ・サイエンス	データ・サイエンス社会応用論 / ICT社会応用演習Ⅳ
# ## 9-2. 交通事故統計情報の分析（東京都内日次集計）

# %% [markdown]
# ### 1. 下準備
# #### 1-a) ライブラリのインポート

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import jpholiday
import japanize_matplotlib

# %% [markdown]
# #### 1-b) 交通事故統計情報の読み込み

# %%
df_accident1 = pd.read_csv('data/accident/honhyo_2019.csv', encoding='SHIFT-JIS')
df_accident2 = pd.read_csv('data/accident/honhyo_2020.csv', encoding='SHIFT-JIS')
df_accident3 = pd.read_csv('data/accident/honhyo_2021.csv', encoding='SHIFT-JIS')
df_accident = pd.concat([df_accident1, df_accident2, df_accident3])
df_accident['年月日'] = pd.to_datetime({
    'year' : df_accident['発生日時　　年'], 'month' : df_accident['発生日時　　月'], 
    'day' : df_accident['発生日時　　日']
})
df_accident
# Out:
#         資料区分  都道府県コード  警察署等コード  本票番号  事故内容  死者数  負傷者数  路線コード  上下線  地点コード  ...  \
# 0          1       10       59     1     2    0     1  40030    2      0  ...
# 1          1       10       59     2     2    0     2  40020    2      0  ...
# 2          1       10       59     3     2    0     1  50020    1      0  ...
# 3          1       10       59     4     2    0     1  40020    2      0  ...
# 4          1       10       59     5     2    0     1  40140    2      0  ...
# ...      ...      ...      ...   ...   ...  ...   ...    ...  ...    ...  ...
# 305191     1       97      114   166     2    0     4  33410    0      0  ...
# 305192     1       97      114   167     2    0     1  33410    0      0  ...
# 305193     1       97      114   168     2    0     1  10070    0      0  ...
# 305194     1       97      114   169     2    0     1  33410    0      0  ...
# 305195     1       97      114   170     2    0     1   3310    2     22  ...
#
#         エアバッグの装備（当事者B）  サイドエアバッグの装備（当事者A）  サイドエアバッグの装備（当事者B）  人身損傷程度（当事者A）  \
# 0                    2                  2                  2             4
# 1                    2                  2                  2             4
# 2                    2                  2                  2             4
# 3                    1                  2                  2             4
# 4                    2                  2                  2             4
# ...                ...                ...                ...           ...
# 305191               1                  2                  2             2
# 305192               2                  2                  2             4
# 305193               2                  2                  2             4
# 305194               0                  2                  0             4
# 305195               0                  2                  0             4
#
#         人身損傷程度（当事者B）  地点　緯度（北緯）   地点　経度（東経）  曜日(発生年月日)  祝日(発生年月日)        年月日
# 0                  4  431412959  1414947029          6          3 2018-12-28
# 1                  4  425706029  1413039991          1          3 2019-01-06
# 2                  4  424115557  1414158530          3          3 2018-12-18
# 3                  2  425647051  1413100440          7          3 2019-01-05
# 4                  2  425606992  1420518034          2          2 2018-12-31
# ...              ...        ...         ...        ...        ...        ...
# 305191             2  261031432  1273909676          6          3 2021-12-10
# 305192             2  260918133  1274003673          4          3 2021-12-15
# 305193             2  261022159  1274124558          4          3 2021-12-22
# 305194             2  260955144  1273944244          6          3 2021-12-24
# 305195             2  261152551  1273939654          2          3 2021-07-26
#
# [995611 rows x 59 columns]

# %% [markdown]
# #### 1-c) 東京都内の2019年1月1日以降のデータの抽出

# %%
df_accident_tokyo1 = df_accident[df_accident['都道府県コード'] == 30]
df_accident_tokyo1 = df_accident_tokyo1[df_accident_tokyo1['年月日'] >= datetime(2019, 12, 1)]
df_accident_tokyo1 = df_accident_tokyo1[df_accident_tokyo1['年月日'] <= datetime(2019, 12, 31)]

df_accident_tokyo1
# Out:
#         資料区分  都道府県コード  警察署等コード  本票番号  事故内容  死者数  負傷者数  路線コード  上下線  地点コード  ...  \
# 348854     1       30       69   683     2    0     3  50290    1      0  ...
# 348856     1       30       69   685     2    0     1  50140    2      0  ...
# 348862     1       30       69   691     2    0     2  42720    2      0  ...
# 348863     1       30       69   692     2    0     1  50300    2      0  ...
# 348868     1       30       69   697     2    0     2  50150    1      0  ...
# ...      ...      ...      ...   ...   ...  ...   ...    ...  ...    ...  ...
# 199117     1       30      877   170     2    0     1  20740    0      0  ...
# 223197     1       30       69   431     2    0     1  50050    1      0  ...
# 224619     1       30      670   171     2    0     1  30000    0      0  ...
# 252331     1       30      435   120     2    0     1  30000    0      0  ...
# 282470     1       30      880   328     2    0     1  95000    0      0  ...
#
#         エアバッグの装備（当事者B）  サイドエアバッグの装備（当事者A）  サイドエアバッグの装備（当事者B）  人身損傷程度（当事者A）  \
# 348854               2                  2                  2             4
# 348856               2                  2                  2             4
# 348862               2                  2                  2             4
# 348863               2                  2                  2             4
# 348868               2                  2                  2             4
# ...                ...                ...                ...           ...
# 199117               2                  2                  2             4
# 223197               2                  1                  2             4
# 224619               0                  0                  0             2
# 252331               0                  2                  0             4
# 282470               2                  2                  2             4
#
#         人身損傷程度（当事者B）  地点　緯度（北緯）   地点　経度（東経）  曜日(発生年月日)  祝日(発生年月日)        年月日
# 348854             2  354131967  1394055474          7          3 2019-12-07
# 348856             2  354036463  1394031249          3          3 2019-12-03
# 348862             4  353015420  1392851221          7          3 2019-12-14
# 348863             2  354552574  1394548223          7          3 2019-12-14
# 348868             2  354614229  1394141939          2          3 2019-12-02
# ...              ...        ...         ...        ...        ...        ...
# 199117             2  354038685  1391751647          2          3 2019-12-23
# 223197             2  353534971  1394424740          1          3 2019-12-01
# 224619             0  354820760  1394843917          7          3 2019-12-14
# 252331             2  354217202  1394233070          5          3 2019-12-19
# 282470             2  354731924  1391710558          6          3 2019-12-27
#
# [2527 rows x 59 columns]

# %%
df_accident_tokyo2 = df_accident[df_accident['都道府県コード'] == 30]
df_accident_tokyo2 = df_accident_tokyo2[df_accident_tokyo2['年月日'] >= datetime(2019, 1, 1)]
df_accident_tokyo2 = df_accident_tokyo2[df_accident_tokyo2['年月日'] <= datetime(2019, 12, 31)]
df_accident_tokyo2 = df_accident_tokyo2[(df_accident_tokyo2["当事者種別（当事者A）"] == 51) | (df_accident_tokyo2["当事者種別（当事者B）"] == 51)]

df_accident_tokyo2
# Out:
#         資料区分  都道府県コード  警察署等コード  本票番号  事故内容  死者数  負傷者数  路線コード  上下線  地点コード  ...  \
# 2708       1       30      101    14     2    0     1  10110    0      0  ...
# 2721       1       30      102    13     2    0     1  30000    0      0  ...
# 2723       1       30      102    15     2    0     1  30000    0      0  ...
# 2728       1       30      103     3     2    0     1  20070    0      0  ...
# 2729       1       30      103     4     2    0     1  95000    0      0  ...
# ...      ...      ...      ...   ...   ...  ...   ...    ...  ...    ...  ...
# 174374     1       30      877   144     2    0     1  20730    0      0  ...
# 199270     1       30      882   272     2    0     1  30000    0      0  ...
# 224619     1       30      670   171     2    0     1  30000    0      0  ...
# 225145     1       30      883   395     2    0     1  30000    0      0  ...
# 253843     1       30      888   225     2    0     1  30000    0      0  ...
#
#         エアバッグの装備（当事者B）  サイドエアバッグの装備（当事者A）  サイドエアバッグの装備（当事者B）  人身損傷程度（当事者A）  \
# 2708                 0                  0                  0             2
# 2721                 0                  2                  0             4
# 2723                 0                  2                  0             4
# 2728                 0                  2                  0             4
# 2729                 0                  2                  0             4
# ...                ...                ...                ...           ...
# 174374               0                  0                  0             4
# 199270               0                  2                  0             4
# 224619               0                  0                  0             2
# 225145               0                  0                  0             4
# 253843               0                  2                  0             4
#
#         人身損傷程度（当事者B）  地点　緯度（北緯）   地点　経度（東経）  曜日(発生年月日)  祝日(発生年月日)        年月日
# 2708               0  354043064  1394525047          1          3 2019-01-27
# 2721               2  354153133  1394520482          5          3 2019-01-24
# 2723               2  354138220  1394539900          4          3 2019-01-30
# 2728               2  354150931  1394616237          5          3 2019-01-10
# 2729               2  354200970  1394644008          6          3 2019-01-11
# ...              ...        ...         ...        ...        ...        ...
# 174374             2  353950606  1391818750          6          3 2019-01-04
# 199270             2  354521794  1391901696          2          3 2019-11-25
# 224619             0  354820760  1394843917          7          3 2019-12-14
# 225145             2  353954197  1392038055          3          3 2019-10-08
# 253843             2  354048930  1392856706          7          3 2019-09-21
#
# [11471 rows x 59 columns]

# %%
df_accident_tokyo = df_accident[df_accident['都道府県コード'] == 30]
df_accident_tokyo = df_accident_tokyo[df_accident_tokyo['年月日'] >= datetime(2019, 1, 1)]
df_accident_tokyo
# Out:
#         資料区分  都道府県コード  警察署等コード  本票番号  事故内容  死者数  負傷者数  路線コード  上下線  地点コード  ...  \
# 2634       1       30       69     1     1    1     0  50230    1      0  ...
# 2664       1       30       69    31     2    0     4  42710    1      0  ...
# 2666       1       30       69    33     2    0     4  50140    2      0  ...
# 2667       1       30       69    34     2    0     6  50150    1      0  ...
# 2668       1       30       69    35     2    0     2  42720    2      0  ...
# ...      ...      ...      ...   ...   ...  ...   ...    ...  ...    ...  ...
# 278536     1       30      896     1     2    0     1  20000    0      0  ...
# 278537     1       30      896     2     2    0     1  30000    0      0  ...
# 278538     1       30      899    17     2    0     1  30000    0      0  ...
# 278539     1       30      899    18     2    0     2  30000    0      0  ...
# 278540     1       30      899    19     2    0     2  30000    0      0  ...
#
#         エアバッグの装備（当事者B）  サイドエアバッグの装備（当事者A）  サイドエアバッグの装備（当事者B）  人身損傷程度（当事者A）  \
# 2634                 1                  2                  2             4
# 2664                 2                  2                  2             2
# 2666                 2                  2                  2             4
# 2667                 2                  2                  2             4
# 2668                 2                  2                  2             4
# ...                ...                ...                ...           ...
# 278536               0                  2                  0             2
# 278537               0                  2                  0             4
# 278538               0                  2                  0             2
# 278539               0                  2                  0             2
# 278540               2                  2                  2             4
#
#         人身損傷程度（当事者B）  地点　緯度（北緯）   地点　経度（東経）  曜日(発生年月日)  祝日(発生年月日)        年月日
# 2634               1  353942627  1394821836          5          3 2019-01-03
# 2664               4  353730552  1393608760          3          1 2019-01-01
# 2666               2  354006471  1393806616          3          1 2019-01-01
# 2667               2  354129346  1394529542          5          3 2019-01-03
# 2668               4  353017828  1392853612          7          3 2019-01-12
# ...              ...        ...         ...        ...        ...        ...
# 278536             0  344058095  1392550060          6          3 2021-12-24
# 278537             2  344600797  1392116172          3          3 2021-12-28
# 278538             0  330737268  1394728005          1          3 2021-12-05
# 278539             0  330742616  1394811278          7          3 2021-12-11
# 278540             4  330719819  1394751385          6          3 2021-12-24
#
# [82943 rows x 59 columns]

# %% [markdown]
# #### 1-d) 日毎の集計

# %%
df_accident_tokyo_daily = df_accident_tokyo.groupby(['年月日'], as_index=False)[['死者数', '負傷者数']].sum()
df_accident_tokyo_daily
# Out:
#             年月日  死者数  負傷者数
# 0    2019-01-01    0    59
# 1    2019-01-02    1    55
# 2    2019-01-03    1    55
# 3    2019-01-04    0    67
# 4    2019-01-05    0    76
# ...         ...  ...   ...
# 1091 2021-12-27    0    95
# 1092 2021-12-28    1    81
# 1093 2021-12-29    1    50
# 1094 2021-12-30    1    53
# 1095 2021-12-31    1    31
#
# [1096 rows x 3 columns]

# %% [markdown]
# #### 1-e) 気象データの読み込み

# %%
df_weather = pd.read_csv('data/weather/weather_tokyo.csv', encoding='SHIFT-JIS', header=2)
df_weather = df_weather.drop([0,1]).reset_index(drop=True)
df_weather['年月日'] = pd.to_datetime(df_weather['年月日'])
df_weather
# Out:
#             年月日  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  降雪量合計(cm)  \
# 0    2019-01-01     10.7      0.9         0.0            1        0.0
# 1    2019-01-02     10.9      2.2         0.0            1        0.0
# 2    2019-01-03     10.9     -0.3         0.0            1        0.0
# 3    2019-01-04      9.8      0.2         0.0            1        0.0
# 4    2019-01-05     14.0      0.9         0.0            1        0.0
# ...         ...      ...      ...         ...          ...        ...
# 1091 2021-12-27      8.1     -2.2         0.0            1        0.0
# 1092 2021-12-28      9.5     -1.6         0.0            1        0.0
# 1093 2021-12-29      8.9      0.9         0.0            1        0.0
# 1094 2021-12-30     14.5      0.6         0.0            0        0.0
# 1095 2021-12-31      6.0      0.1         0.0            1        0.0
#
#      降雪量合計(cm).1  最深積雪(cm) 最深積雪(cm).1  日照時間(時間) 日照時間(時間).1  平均風速(m/s)  \
# 0              1       0.0          1       8.9          0        2.3
# 1              1       0.0          1       8.7          0        2.9
# 2              1       0.0          1       8.9          0        3.1
# 3              1       0.0          1       8.9          0        2.0
# 4              1       0.0          1       8.9          0        2.1
# ...          ...       ...        ...       ...        ...        ...
# 1091           1       0.0          1       8.5          0        2.0
# 1092           1       0.0          1       8.8          0        2.4
# 1093           1       0.0          1       7.8          0        1.6
# 1094           1       0.0          1       7.5          0        2.0
# 1095           1       0.0          1       3.7          0        3.0
#
#      天気概況(昼：06時〜18時) 天気概況(夜：18時〜翌日06時)
# 0                  晴                快晴
# 1                 快晴                快晴
# 2                 快晴                快晴
# 3                 快晴                 晴
# 4                 快晴             晴後一時曇
# ...              ...               ...
# 1091              快晴                快晴
# 1092              快晴               晴後曇
# 1093           晴時々薄曇              晴一時曇
# 1094            晴一時曇                 晴
# 1095            晴時々曇                快晴
#
# [1096 rows x 14 columns]

# %% [markdown]
# #### 1-f) 事故データと気象データの結合

# %%
df_accident_weather = pd.merge(df_accident_tokyo_daily, df_weather, on='年月日', how='right').fillna(0)
df_accident_weather
# Out:
#             年月日  死者数  負傷者数  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  \
# 0    2019-01-01    0    59     10.7      0.9         0.0            1
# 1    2019-01-02    1    55     10.9      2.2         0.0            1
# 2    2019-01-03    1    55     10.9     -0.3         0.0            1
# 3    2019-01-04    0    67      9.8      0.2         0.0            1
# 4    2019-01-05    0    76     14.0      0.9         0.0            1
# ...         ...  ...   ...      ...      ...         ...          ...
# 1091 2021-12-27    0    95      8.1     -2.2         0.0            1
# 1092 2021-12-28    1    81      9.5     -1.6         0.0            1
# 1093 2021-12-29    1    50      8.9      0.9         0.0            1
# 1094 2021-12-30    1    53     14.5      0.6         0.0            0
# 1095 2021-12-31    1    31      6.0      0.1         0.0            1
#
#       降雪量合計(cm) 降雪量合計(cm).1  最深積雪(cm) 最深積雪(cm).1  日照時間(時間) 日照時間(時間).1  \
# 0           0.0           1       0.0          1       8.9          0
# 1           0.0           1       0.0          1       8.7          0
# 2           0.0           1       0.0          1       8.9          0
# 3           0.0           1       0.0          1       8.9          0
# 4           0.0           1       0.0          1       8.9          0
# ...         ...         ...       ...        ...       ...        ...
# 1091        0.0           1       0.0          1       8.5          0
# 1092        0.0           1       0.0          1       8.8          0
# 1093        0.0           1       0.0          1       7.8          0
# 1094        0.0           1       0.0          1       7.5          0
# 1095        0.0           1       0.0          1       3.7          0
#
#       平均風速(m/s) 天気概況(昼：06時〜18時) 天気概況(夜：18時〜翌日06時)
# 0           2.3               晴                快晴
# 1           2.9              快晴                快晴
# 2           3.1              快晴                快晴
# 3           2.0              快晴                 晴
# 4           2.1              快晴             晴後一時曇
# ...         ...             ...               ...
# 1091        2.0              快晴                快晴
# 1092        2.4              快晴               晴後曇
# 1093        1.6           晴時々薄曇              晴一時曇
# 1094        2.0            晴一時曇                 晴
# 1095        3.0            晴時々曇                快晴
#
# [1096 rows x 16 columns]

# %% [markdown]
# #### 1-g) 曜日と祝日の追加

# %%
df_accident_weather['曜日'] = df_accident_weather['年月日'].dt.weekday
df_accident_weather['祝日'] = df_accident_weather['年月日'].dt.date.map(jpholiday.is_holiday).astype(int)
df_accident_weather
# Out:
#             年月日  死者数  負傷者数  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  \
# 0    2019-01-01    0    59     10.7      0.9         0.0            1
# 1    2019-01-02    1    55     10.9      2.2         0.0            1
# 2    2019-01-03    1    55     10.9     -0.3         0.0            1
# 3    2019-01-04    0    67      9.8      0.2         0.0            1
# 4    2019-01-05    0    76     14.0      0.9         0.0            1
# ...         ...  ...   ...      ...      ...         ...          ...
# 1091 2021-12-27    0    95      8.1     -2.2         0.0            1
# 1092 2021-12-28    1    81      9.5     -1.6         0.0            1
# 1093 2021-12-29    1    50      8.9      0.9         0.0            1
# 1094 2021-12-30    1    53     14.5      0.6         0.0            0
# 1095 2021-12-31    1    31      6.0      0.1         0.0            1
#
#       降雪量合計(cm) 降雪量合計(cm).1  最深積雪(cm) 最深積雪(cm).1  日照時間(時間) 日照時間(時間).1  \
# 0           0.0           1       0.0          1       8.9          0
# 1           0.0           1       0.0          1       8.7          0
# 2           0.0           1       0.0          1       8.9          0
# 3           0.0           1       0.0          1       8.9          0
# 4           0.0           1       0.0          1       8.9          0
# ...         ...         ...       ...        ...       ...        ...
# 1091        0.0           1       0.0          1       8.5          0
# 1092        0.0           1       0.0          1       8.8          0
# 1093        0.0           1       0.0          1       7.8          0
# 1094        0.0           1       0.0          1       7.5          0
# 1095        0.0           1       0.0          1       3.7          0
#
#       平均風速(m/s) 天気概況(昼：06時〜18時) 天気概況(夜：18時〜翌日06時)  曜日  祝日
# 0           2.3               晴                快晴   1   1
# 1           2.9              快晴                快晴   2   0
# 2           3.1              快晴                快晴   3   0
# 3           2.0              快晴                 晴   4   0
# 4           2.1              快晴             晴後一時曇   5   0
# ...         ...             ...               ...  ..  ..
# 1091        2.0              快晴                快晴   0   0
# 1092        2.4              快晴               晴後曇   1   0
# 1093        1.6           晴時々薄曇              晴一時曇   2   0
# 1094        2.0            晴一時曇                 晴   3   0
# 1095        3.0            晴時々曇                快晴   4   0
#
# [1096 rows x 18 columns]

# %% [markdown]
# ### 2. 負傷者数の可視化
# #### 2-a) 負傷者数と死者数の推移の可視化

# %%
df_accident_weather.plot(x='年月日', y=['負傷者数', '死者数'], figsize=(20,4))
plt.show()

# %% [markdown]
# #### 2-b) 曜日と負傷者数の関係の可視化

# %%
df_accident_weather.groupby('曜日')['負傷者数'].describe()
# Out:
#     count       mean        std   min    25%   50%    75%    max
# 曜日
# 0   156.0  88.096154  20.345334  29.0  74.75  90.0  103.0  139.0
# 1   157.0  87.770701  20.581256  31.0  76.00  89.0  101.0  142.0
# 2   157.0  87.388535  21.333028  19.0  76.00  87.0  100.0  168.0
# 3   157.0  89.732484  18.871489  35.0  79.00  91.0  103.0  136.0
# 4   157.0  97.222930  21.556901  31.0  85.00  98.0  111.0  164.0
# 5   156.0  83.942308  20.070920  19.0  71.75  83.0   98.0  131.0
# 6   156.0  63.205128  14.147024  22.0  53.00  64.0   72.0   96.0

# %%
df_accident_weather.boxplot('負傷者数', '曜日')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2-c) 過去1週間の移動平均の算出

# %%
df_accident_weather['負傷者数_移動平均'] = df_accident_weather['負傷者数'].rolling(7).mean()
df_accident_weather['死者数_移動平均'] = df_accident_weather['死者数'].rolling(7).mean()
df_accident_weather
# Out:
#             年月日  死者数  負傷者数  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  \
# 0    2019-01-01    0    59     10.7      0.9         0.0            1
# 1    2019-01-02    1    55     10.9      2.2         0.0            1
# 2    2019-01-03    1    55     10.9     -0.3         0.0            1
# 3    2019-01-04    0    67      9.8      0.2         0.0            1
# 4    2019-01-05    0    76     14.0      0.9         0.0            1
# ...         ...  ...   ...      ...      ...         ...          ...
# 1091 2021-12-27    0    95      8.1     -2.2         0.0            1
# 1092 2021-12-28    1    81      9.5     -1.6         0.0            1
# 1093 2021-12-29    1    50      8.9      0.9         0.0            1
# 1094 2021-12-30    1    53     14.5      0.6         0.0            0
# 1095 2021-12-31    1    31      6.0      0.1         0.0            1
#
#       降雪量合計(cm) 降雪量合計(cm).1  最深積雪(cm) 最深積雪(cm).1  日照時間(時間) 日照時間(時間).1  \
# 0           0.0           1       0.0          1       8.9          0
# 1           0.0           1       0.0          1       8.7          0
# 2           0.0           1       0.0          1       8.9          0
# 3           0.0           1       0.0          1       8.9          0
# 4           0.0           1       0.0          1       8.9          0
# ...         ...         ...       ...        ...       ...        ...
# 1091        0.0           1       0.0          1       8.5          0
# 1092        0.0           1       0.0          1       8.8          0
# 1093        0.0           1       0.0          1       7.8          0
# 1094        0.0           1       0.0          1       7.5          0
# 1095        0.0           1       0.0          1       3.7          0
#
#       平均風速(m/s) 天気概況(昼：06時〜18時) 天気概況(夜：18時〜翌日06時)  曜日  祝日  負傷者数_移動平均  死者数_移動平均
# 0           2.3               晴                快晴   1   1        NaN       NaN
# 1           2.9              快晴                快晴   2   0        NaN       NaN
# 2           3.1              快晴                快晴   3   0        NaN       NaN
# 3           2.0              快晴                 晴   4   0        NaN       NaN
# 4           2.1              快晴             晴後一時曇   5   0        NaN       NaN
# ...         ...             ...               ...  ..  ..        ...       ...
# 1091        2.0              快晴                快晴   0   0  83.428571  0.285714
# 1092        2.4              快晴               晴後曇   1   0  84.000000  0.428571
# 1093        1.6           晴時々薄曇              晴一時曇   2   0  77.857143  0.428571
# 1094        2.0            晴一時曇                 晴   3   0  71.714286  0.428571
# 1095        3.0            晴時々曇                快晴   4   0  63.000000  0.571429
#
# [1096 rows x 20 columns]

# %% [markdown]
# #### 2-d) 負傷者数および死者数の移動平均の推移の可視化

# %%
df_accident_weather.plot(x='年月日', y=['負傷者数_移動平均', '死者数_移動平均'], figsize=(20,4))
plt.show()

# %% [markdown]
# #### 2-e) 前年比の算出

# %%
df_accident_weather['前年'] = df_accident_weather['年月日'] - timedelta(days=365)
df_accident_weather
# Out:
#             年月日  死者数  負傷者数  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  \
# 0    2019-01-01    0    59     10.7      0.9         0.0            1
# 1    2019-01-02    1    55     10.9      2.2         0.0            1
# 2    2019-01-03    1    55     10.9     -0.3         0.0            1
# 3    2019-01-04    0    67      9.8      0.2         0.0            1
# 4    2019-01-05    0    76     14.0      0.9         0.0            1
# ...         ...  ...   ...      ...      ...         ...          ...
# 1091 2021-12-27    0    95      8.1     -2.2         0.0            1
# 1092 2021-12-28    1    81      9.5     -1.6         0.0            1
# 1093 2021-12-29    1    50      8.9      0.9         0.0            1
# 1094 2021-12-30    1    53     14.5      0.6         0.0            0
# 1095 2021-12-31    1    31      6.0      0.1         0.0            1
#
#       降雪量合計(cm) 降雪量合計(cm).1  最深積雪(cm)  ... 日照時間(時間)  日照時間(時間).1 平均風速(m/s)  \
# 0           0.0           1       0.0  ...      8.9           0       2.3
# 1           0.0           1       0.0  ...      8.7           0       2.9
# 2           0.0           1       0.0  ...      8.9           0       3.1
# 3           0.0           1       0.0  ...      8.9           0       2.0
# 4           0.0           1       0.0  ...      8.9           0       2.1
# ...         ...         ...       ...  ...      ...         ...       ...
# 1091        0.0           1       0.0  ...      8.5           0       2.0
# 1092        0.0           1       0.0  ...      8.8           0       2.4
# 1093        0.0           1       0.0  ...      7.8           0       1.6
# 1094        0.0           1       0.0  ...      7.5           0       2.0
# 1095        0.0           1       0.0  ...      3.7           0       3.0
#
#       天気概況(昼：06時〜18時) 天気概況(夜：18時〜翌日06時) 曜日  祝日  負傷者数_移動平均  死者数_移動平均         前年
# 0                   晴                快晴  1   1        NaN       NaN 2018-01-01
# 1                  快晴                快晴  2   0        NaN       NaN 2018-01-02
# 2                  快晴                快晴  3   0        NaN       NaN 2018-01-03
# 3                  快晴                 晴  4   0        NaN       NaN 2018-01-04
# 4                  快晴             晴後一時曇  5   0        NaN       NaN 2018-01-05
# ...               ...               ... ..  ..        ...       ...        ...
# 1091               快晴                快晴  0   0  83.428571  0.285714 2020-12-27
# 1092               快晴               晴後曇  1   0  84.000000  0.428571 2020-12-28
# 1093            晴時々薄曇              晴一時曇  2   0  77.857143  0.428571 2020-12-29
# 1094             晴一時曇                 晴  3   0  71.714286  0.428571 2020-12-30
# 1095             晴時々曇                快晴  4   0  63.000000  0.571429 2020-12-31
#
# [1096 rows x 21 columns]

# %%
df_tmp = df_accident_weather[['年月日', '負傷者数_移動平均']].rename(columns={
    '年月日' : '前年', '負傷者数_移動平均' : '前年_負傷者数_移動平均'
})
df_tmp
# Out:
#              前年  前年_負傷者数_移動平均
# 0    2019-01-01           NaN
# 1    2019-01-02           NaN
# 2    2019-01-03           NaN
# 3    2019-01-04           NaN
# 4    2019-01-05           NaN
# ...         ...           ...
# 1091 2021-12-27     83.428571
# 1092 2021-12-28     84.000000
# 1093 2021-12-29     77.857143
# 1094 2021-12-30     71.714286
# 1095 2021-12-31     63.000000
#
# [1096 rows x 2 columns]

# %%
df_accident_weather_compare = pd.merge(df_accident_weather, df_tmp, on='前年')
df_accident_weather_compare['負傷者数_前年比'] = df_accident_weather_compare['負傷者数_移動平均'] / df_accident_weather_compare['前年_負傷者数_移動平均']

df_accident_weather_compare
# Out:
#            年月日  死者数  負傷者数  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  \
# 0   2020-01-01    0    40     10.2      3.2         0.0            1
# 1   2020-01-02    1    35     11.3      1.9         0.0            1
# 2   2020-01-03    1    49     12.0      1.4         0.0            1
# 3   2020-01-04    0    52     12.2      3.6         0.0            0
# 4   2020-01-05    1    55     10.2      0.6         1.0            0
# ..         ...  ...   ...      ...      ...         ...          ...
# 726 2021-12-27    0    95      8.1     -2.2         0.0            1
# 727 2021-12-28    1    81      9.5     -1.6         0.0            1
# 728 2021-12-29    1    50      8.9      0.9         0.0            1
# 729 2021-12-30    1    53     14.5      0.6         0.0            0
# 730 2021-12-31    1    31      6.0      0.1         0.0            1
#
#      降雪量合計(cm) 降雪量合計(cm).1  最深積雪(cm)  ... 平均風速(m/s)  天気概況(昼：06時〜18時)  \
# 0          0.0           1       0.0  ...       2.6                晴
# 1          0.0           1       0.0  ...       1.8             晴一時曇
# 2          0.0           1       0.0  ...       1.4               快晴
# 3          0.0           1       0.0  ...       2.3             曇時々晴
# 4          0.0           1       0.0  ...       3.0               快晴
# ..         ...         ...       ...  ...       ...              ...
# 726        0.0           1       0.0  ...       2.0               快晴
# 727        0.0           1       0.0  ...       2.4               快晴
# 728        0.0           1       0.0  ...       1.6            晴時々薄曇
# 729        0.0           1       0.0  ...       2.0             晴一時曇
# 730        0.0           1       0.0  ...       3.0             晴時々曇
#
#     天気概況(夜：18時〜翌日06時)  曜日 祝日  負傷者数_移動平均  死者数_移動平均         前年  前年_負傷者数_移動平均  \
# 0                  快晴   2  1  76.571429  0.571429 2019-01-01           NaN
# 1                   晴   3  0  69.571429  0.571429 2019-01-02           NaN
# 2                  快晴   4  0  58.285714  0.428571 2019-01-03           NaN
# 3         晴一時雨、みぞれを伴う   5  0  51.285714  0.285714 2019-01-04           NaN
# 4                  快晴   6  0  47.142857  0.428571 2019-01-05           NaN
# ..                ...  .. ..        ...       ...        ...           ...
# 726                快晴   0  0  83.428571  0.285714 2020-12-27    103.857143
# 727               晴後曇   1  0  84.000000  0.428571 2020-12-28     95.285714
# 728              晴一時曇   2  0  77.857143  0.428571 2020-12-29     89.285714
# 729                 晴   3  0  71.714286  0.428571 2020-12-30     81.285714
# 730                快晴   4  0  63.000000  0.571429 2020-12-31     73.714286
#
#      負傷者数_前年比
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 726  0.803301
# 727  0.881559
# 728  0.872000
# 729  0.882250
# 730  0.854651
#
# [731 rows x 23 columns]

# %% [markdown]
# #### 2-f) 前々年比の算出

# %%
df_accident_weather_compare['前々年'] = df_accident_weather_compare['年月日'] - timedelta(days=365 + 366)

df_tmp2 = df_accident_weather[['年月日', '負傷者数_移動平均']].rename(columns={
    '年月日' : '前々年', '負傷者数_移動平均' : '前々年_負傷者数_移動平均'
})

df_accident_weather_compare = pd.merge(df_accident_weather_compare, df_tmp2, on='前々年', how='left')
df_accident_weather_compare['負傷者数_前々年比'] = df_accident_weather_compare['負傷者数_移動平均'] / df_accident_weather_compare['前々年_負傷者数_移動平均']

df_accident_weather_compare
# Out:
#            年月日  死者数  負傷者数  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  \
# 0   2020-01-01    0    40     10.2      3.2         0.0            1
# 1   2020-01-02    1    35     11.3      1.9         0.0            1
# 2   2020-01-03    1    49     12.0      1.4         0.0            1
# 3   2020-01-04    0    52     12.2      3.6         0.0            0
# 4   2020-01-05    1    55     10.2      0.6         1.0            0
# ..         ...  ...   ...      ...      ...         ...          ...
# 726 2021-12-27    0    95      8.1     -2.2         0.0            1
# 727 2021-12-28    1    81      9.5     -1.6         0.0            1
# 728 2021-12-29    1    50      8.9      0.9         0.0            1
# 729 2021-12-30    1    53     14.5      0.6         0.0            0
# 730 2021-12-31    1    31      6.0      0.1         0.0            1
#
#      降雪量合計(cm) 降雪量合計(cm).1  最深積雪(cm)  ... 曜日  祝日  負傷者数_移動平均  死者数_移動平均  \
# 0          0.0           1       0.0  ...  2   1  76.571429  0.571429
# 1          0.0           1       0.0  ...  3   0  69.571429  0.571429
# 2          0.0           1       0.0  ...  4   0  58.285714  0.428571
# 3          0.0           1       0.0  ...  5   0  51.285714  0.285714
# 4          0.0           1       0.0  ...  6   0  47.142857  0.428571
# ..         ...         ...       ...  ... ..  ..        ...       ...
# 726        0.0           1       0.0  ...  0   0  83.428571  0.285714
# 727        0.0           1       0.0  ...  1   0  84.000000  0.428571
# 728        0.0           1       0.0  ...  2   0  77.857143  0.428571
# 729        0.0           1       0.0  ...  3   0  71.714286  0.428571
# 730        0.0           1       0.0  ...  4   0  63.000000  0.571429
#
#             前年 前年_負傷者数_移動平均  負傷者数_前年比        前々年  前々年_負傷者数_移動平均  負傷者数_前々年比
# 0   2019-01-01          NaN       NaN 2017-12-31            NaN        NaN
# 1   2019-01-02          NaN       NaN 2018-01-01            NaN        NaN
# 2   2019-01-03          NaN       NaN 2018-01-02            NaN        NaN
# 3   2019-01-04          NaN       NaN 2018-01-03            NaN        NaN
# 4   2019-01-05          NaN       NaN 2018-01-04            NaN        NaN
# ..         ...          ...       ...        ...            ...        ...
# 726 2020-12-27   103.857143  0.803301 2019-12-27      92.142857   0.905426
# 727 2020-12-28    95.285714  0.881559 2019-12-28      93.428571   0.899083
# 728 2020-12-29    89.285714  0.872000 2019-12-29      94.428571   0.824508
# 729 2020-12-30    81.285714  0.882250 2019-12-30      88.285714   0.812298
# 730 2020-12-31    73.714286  0.854651 2019-12-31      82.285714   0.765625
#
# [731 rows x 26 columns]

# %% [markdown]
# #### 2-g) 負傷者数の前年・前々年比の推移（移動平均）

# %%
df_accident_weather_compare.plot(x='年月日', y=['負傷者数_前年比', '負傷者数_前々年比'], figsize=(20,4))
plt.show()

# %% [markdown]
# ### 3. 気象データと組み合わせた分析
# #### 3-a) データの絞り込み

# %%
df_accident_weather_2019 = df_accident_weather[df_accident_weather['年月日'] <= datetime(2019, 12, 31)]
df_accident_weather_2019
# Out:
#            年月日  死者数  負傷者数  最高気温(℃)  最低気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  \
# 0   2019-01-01    0    59     10.7      0.9         0.0            1
# 1   2019-01-02    1    55     10.9      2.2         0.0            1
# 2   2019-01-03    1    55     10.9     -0.3         0.0            1
# 3   2019-01-04    0    67      9.8      0.2         0.0            1
# 4   2019-01-05    0    76     14.0      0.9         0.0            1
# ..         ...  ...   ...      ...      ...         ...          ...
# 360 2019-12-27    2   128     13.7      4.5         0.5            0
# 361 2019-12-28    1   101     10.9      3.8         0.0            1
# 362 2019-12-29    0    84     10.9      2.2         0.0            1
# 363 2019-12-30    0    54      8.8      5.1         0.5            0
# 364 2019-12-31    0    45     16.5      3.7         0.0            1
#
#      降雪量合計(cm) 降雪量合計(cm).1  最深積雪(cm)  ... 日照時間(時間)  日照時間(時間).1 平均風速(m/s)  \
# 0          0.0           1       0.0  ...      8.9           0       2.3
# 1          0.0           1       0.0  ...      8.7           0       2.9
# 2          0.0           1       0.0  ...      8.9           0       3.1
# 3          0.0           1       0.0  ...      8.9           0       2.0
# 4          0.0           1       0.0  ...      8.9           0       2.1
# ..         ...         ...       ...  ...      ...         ...       ...
# 360        0.0           1       0.0  ...      6.5           0       4.0
# 361        0.0           1       0.0  ...      8.8           0       3.5
# 362        0.0           1       0.0  ...      8.3           0       1.9
# 363        0.0           1       0.0  ...      0.0           0       1.8
# 364        0.0           1       0.0  ...      8.6           0       3.6
#
#      天気概況(昼：06時〜18時) 天気概況(夜：18時〜翌日06時) 曜日  祝日  負傷者数_移動平均  死者数_移動平均         前年
# 0                  晴                快晴  1   1        NaN       NaN 2018-01-01
# 1                 快晴                快晴  2   0        NaN       NaN 2018-01-02
# 2                 快晴                快晴  3   0        NaN       NaN 2018-01-03
# 3                 快晴                 晴  4   0        NaN       NaN 2018-01-04
# 4                 快晴             晴後一時曇  5   0        NaN       NaN 2018-01-05
# ..               ...               ... ..  ..        ...       ...        ...
# 360                晴                快晴  4   0  92.142857  0.571429 2018-12-27
# 361               快晴              晴一時曇  5   0  93.428571  0.714286 2018-12-28
# 362            晴後一時曇                 曇  6   0  94.428571  0.714286 2018-12-29
# 363             雨時々曇                 曇  0   0  88.285714  0.714286 2018-12-30
# 364                晴             晴後一時曇  1   0  82.285714  0.571429 2018-12-31
#
# [365 rows x 21 columns]

# %% [markdown]
# #### 3-b) 降水量と負傷者数の関係

# %%
df_accident_weather_2019.plot.scatter('降水量の合計(mm)', '負傷者数')
plt.show()

# %%
df_accident_weather_2019[['降水量の合計(mm)', '負傷者数']].corr()
# Out:
#             降水量の合計(mm)     負傷者数
# 降水量の合計(mm)     1.00000 -0.18951
# 負傷者数          -0.18951  1.00000

# %% [markdown]
# #### 3-c) 降雨がない時の統計量の確認

# %%
df_accident_weather_norain = df_accident_weather_2019[df_accident_weather_2019['降水量の合計(mm)'] == 0]['負傷者数']
df_accident_weather_norain.describe()
# Out:
# count    234.000000
# mean      97.252137
# std       21.421793
# min       43.000000
# 25%       83.000000
# 50%       99.000000
# 75%      111.000000
# max      168.000000
# Name: 負傷者数, dtype: float64

# %% [markdown]
# #### 3-d) 降雨がある時の統計量の確認

# %%
df_accident_weather_rain = df_accident_weather_2019[df_accident_weather_2019['降水量の合計(mm)'] > 0]['負傷者数']
df_accident_weather_rain.describe()
# Out:
# count    131.000000
# mean      91.160305
# std       20.748241
# min       19.000000
# 25%       77.500000
# 50%       93.000000
# 75%      106.000000
# max      142.000000
# Name: 負傷者数, dtype: float64

# %%
df_accident_tokyo = df_accident[df_accident['都道府県コード'] == 13]
df_accident_tokyo = df_accident_tokyo[df_accident_tokyo['年月日'] >= datetime(2019, 12, 1)]
df_accident_tokyo = df_accident_tokyo[df_accident_tokyo['年月日'] <= datetime(2019, 12, 31)]

df_accident_tokyo
# Out:
#         資料区分  都道府県コード  警察署等コード  本票番号  事故内容  死者数  負傷者数  路線コード  上下線  地点コード  ...  \
# 346883     1       13      401   213     2    0     1  39990    0      0  ...
# 346891     1       13      401   221     2    0     1    380    0     41  ...
# 346892     1       13      401   222     2    0     1  39990    0      0  ...
# 346894     1       13      401   224     2    0     1    440    0     36  ...
# 346896     1       13      401   226     2    0     1  11270    0      0  ...
# ...      ...      ...      ...   ...   ...  ...   ...    ...  ...    ...  ...
# 28382      1       13      408    24     2    0     1  99000    0      0  ...
# 28386      1       13      408    28     2    0     1  38880    0      0  ...
# 28402      1       13      408    44     2    0     1  39990    0      0  ...
# 28403      1       13      408    45     2    0     1  39990    0      0  ...
# 55939      1       13      408    65     2    0     1  21520    0      0  ...
#
#         エアバッグの装備（当事者B）  サイドエアバッグの装備（当事者A）  サイドエアバッグの装備（当事者B）  人身損傷程度（当事者A）  \
# 346883               0                  2                  0             4
# 346891               2                  2                  2             4
# 346892               2                  2                  2             4
# 346894               0                  2                  0             4
# 346896               2                  2                  1             4
# ...                ...                ...                ...           ...
# 28382                0                  2                  0             4
# 28386                2                  2                  2             4
# 28402                0                  2                  0             2
# 28403                2                  2                  2             4
# 55939                0                  1                  0             4
#
#         人身損傷程度（当事者B）  地点　緯度（北緯）   地点　経度（東経）  曜日(発生年月日)  祝日(発生年月日)        年月日
# 346883             2  425922342  1442213513          5          3 2019-12-05
# 346891             2  430030955  1442144042          2          3 2019-12-09
# 346892             2  430025731  1442324049          2          3 2019-12-09
# 346894             2  430033230  1442425166          1          3 2019-12-15
# 346896             4  430104936  1442150561          1          3 2019-12-08
# ...              ...        ...         ...        ...        ...        ...
# 28382              2  425328167  1431202891          2          3 2019-12-30
# 28386              2  425429760  1430254929          3          3 2019-12-24
# 28402              0  425320758  1431201731          7          3 2019-12-28
# 28403              2  425528984  1431110848          3          3 2019-12-17
# 55939              0  425809906  1431107731          1          3 2019-12-22
#
# [64 rows x 59 columns]
