# %% [raw]
# データ・サイエンス データ・サイエンス社会応用論 / ICT社会応用演習Ⅳ
# 第11回課題1-1

# %%
import requests
import zipfile
import os
from google.transit import gtfs_realtime_pb2
import pandas as pd
import geopandas as gpd

# %%
AOMORI_BUS_TRIPUPDATE_URL = 'https://api-public.odpt.org/api/v4/gtfs/realtime/odpt_AomoriCity_AllLines_trip_update'

# %%
response = requests.get(AOMORI_BUS_TRIPUPDATE_URL)

if response.status_code == 200:
    pb_data = response.content

# %%
feed = gtfs_realtime_pb2.FeedMessage()
feed.ParseFromString(pb_data)
# Out:
# 2330

# %%
data = []
for entity in feed.entity:
    if not entity.HasField('trip_update'):
        continue
    
    trip_update = entity.trip_update

    for stop_time_update in trip_update.stop_time_update:    
        data.append({
            'trip_id': trip_update.trip.trip_id,
            'stop_sequence': stop_time_update.stop_sequence,
            'delay': stop_time_update.departure.delay
        })

df_trip_update = pd.DataFrame(data)
df_trip_update
# Out:
#               trip_id  stop_sequence  delay
# 0   平日_15時53分_系統48151             26    232
# 1   平日_16時25分_系統35162              4    162
# 2   平日_16時05分_系統19041             20    149
# 3    平日_16時22分_系統1052              5     74
# 4   平日_16時30分_系統80031              1     14
# 5   平日_15時30分_系統17021             23   1372
# 6   平日_15時45分_系統15032             22   1012
# 7   平日_15時33分_系統12141             27   1192
# 8   平日_16時10分_系統36221             10    292
# 9   平日_15時57分_系統28042             15    472
# 10  平日_16時04分_系統37031             11    652
# 11  平日_15時40分_系統12142             30    652
# 12  平日_16時31分_系統22032              2      0
# 13  平日_16時00分_系統56022             19     34
# 14  平日_15時35分_系統80031             21    772
# 15  平日_15時15分_系統14022             36   1012
# 16  平日_16時25分_系統22021              3     98
# 17  平日_16時03分_系統39052             16    412
# 18  平日_15時50分_系統41081             20    412
# 19  平日_16時13分_系統39141              8    472
# 20  平日_15時55分_系統80041             14    292
# 21  平日_16時01分_系統39051             12    712
# 22   平日_16時11分_系統8031              5    712
# 23  平日_16時20分_系統12141              6     80
# 24  平日_16時20分_系統21081             11    106
# 25  平日_15時53分_系統47031             22    532
# 26  平日_15時45分_系統14021             24    292
# 27   平日_16時09分_系統6171             11    292
# 28  平日_16時20分_系統14022              5    194
# 29  平日_15時59分_系統17011             12    652
# 30  平日_16時25分_系統44374              5     98
# 31  平日_16時13分_系統35151              9    292
# 32  平日_16時23分_系統39191              4      0
# 33  平日_16時14分_系統56021             11    105
# 34  平日_16時12分_系統10012             12    232
# 35  平日_16時10分_系統19032             10    472
# 36   平日_15時54分_系統6162             20    712
# 37  平日_15時12分_系統14021             38    952
# 38  平日_16時29分_系統16131              1    112
# 39  平日_15時40分_系統82032             24    292
# 40  平日_16時03分_系統35162             11    952
# 41  平日_15時53分_系統21032             19    652
# 42  平日_16時00分_系統49022             22    232
# 43  平日_14時50分_系統14021             43   1552
# 44  平日_15時52分_系統49021             26    292

# %%
df_trip_update['delay'].describe()
# Out:
# count      45.000000
# mean      451.066667
# std       382.480980
# min         0.000000
# 25%       149.000000
# 50%       292.000000
# 75%       652.000000
# max      1552.000000
# Name: delay, dtype: float64
