# %% [markdown]
# # データ・サイエンス	データ・サイエンス社会応用論 / ICT社会応用演習Ⅳ
# ## 11-3. GTFS Realtime : Vehicle Position

# %% [markdown]
# ### 1. 下準備

# %%
import requests
import zipfile
import os
from google.transit import gtfs_realtime_pb2
import pandas as pd
import geopandas as gpd

# %%
AOMORI_BUS_ALERT_URL = 'https://api-public.odpt.org/api/v4/gtfs/realtime/odpt_AomoriCity_AllLines_alert'
AOMORI_BUS_TRIPUPDATE_URL = 'https://api-public.odpt.org/api/v4/gtfs/realtime/odpt_AomoriCity_AllLines_trip_update'
AOMORI_BUS_VEHICLEPOSITION_URL = 'https://api-public.odpt.org/api/v4/gtfs/realtime/odpt_AomoriCity_AllLines_vehicle'

# %% [markdown]
# ### 2. GTFS Realtime のダウンロード
# #### 2-a) フィードの読み込み

# %%
response = requests.get(AOMORI_BUS_VEHICLEPOSITION_URL)

if response.status_code == 200:
    pb_data = response.content

# %%
feed = gtfs_realtime_pb2.FeedMessage()
feed.ParseFromString(pb_data)
# Out:
# 4823

# %% [markdown]
# #### 2-b) ヘッダとエンティティの表示

# %%
print(feed.header)
# Out:
# gtfs_realtime_version: "1.0"
# incrementality: FULL_DATASET
# timestamp: 1734337700

# %%
for entity in feed.entity:
    print(entity)
# Out:
# id: "VP-1"
# vehicle {
#   trip {
#     trip_id: "平日_16時44分_系統17032"
#   }
#   vehicle {
#     id: "1253"
#     label: "IchigoBUS"
#     license_plate: "1253"
#   }
#   position {
#     latitude: 40.8225441
#     longitude: 140.750259
#   }
#   current_stop_sequence: 22
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337660
# }
#
# id: "VP-2"
# vehicle {
#   trip {
#     trip_id: "平日_17時15分_系統16031"
#   }
#   vehicle {
#     id: "1397"
#     label: "IchigoBUS"
#     license_plate: "1397"
#   }
#   position {
#     latitude: 40.8231163
#     longitude: 140.746918
#   }
#   current_stop_sequence: 5
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337672
# }
#
# id: "VP-3"
# vehicle {
#   trip {
#     trip_id: "平日_16時30分_系統80031"
#   }
#   vehicle {
#     id: "1106"
#     label: "IchigoBUS"
#     license_plate: "1106"
#   }
#   position {
#     latitude: 40.817955
#     longitude: 140.750854
#   }
#   current_stop_sequence: 19
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337644
# }
#
# id: "VP-4"
# vehicle {
#   trip {
#     trip_id: "平日_16時49分_系統39082"
#   }
#   vehicle {
#     id: "1105"
#     label: "IchigoBUS"
#     license_plate: "1105"
#   }
#   position {
#     latitude: 40.8246841
#     longitude: 140.764404
#   }
#   current_stop_sequence: 21
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337655
# }
#
# id: "VP-5"
# vehicle {
#   trip {
#     trip_id: "平日_16時52分_系統20131"
#   }
#   vehicle {
#     id: "1252"
#     label: "IchigoBUS"
#     license_plate: "1252"
#   }
#   position {
#     latitude: 40.7707443
#     longitude: 140.745453
#   }
#   current_stop_sequence: 20
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337687
# }
#
# id: "VP-6"
# vehicle {
#   trip {
#     trip_id: "平日_17時20分_系統24011"
#   }
#   vehicle {
#     id: "0727"
#     label: "IchigoBUS"
#     license_plate: "0727"
#   }
#   position {
#     latitude: 40.8238144
#     longitude: 140.740173
#   }
#   current_stop_sequence: 4
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337692
# }
#
# id: "VP-7"
# vehicle {
#   trip {
#     trip_id: "平日_17時25分_系統15032"
#   }
#   vehicle {
#     id: "1447"
#     label: "IchigoBUS"
#     license_plate: "1447"
#   }
#   position {
#     latitude: 40.8192825
#     longitude: 140.80896
#   }
#   current_stop_sequence: 2
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337678
# }
#
# id: "VP-8"
# vehicle {
#   trip {
#     trip_id: "平日_17時15分_系統28102"
#   }
#   vehicle {
#     id: "1040"
#     label: "IchigoBUS"
#     license_plate: "1040"
#   }
#   position {
#     latitude: 40.8028603
#     longitude: 140.740463
#   }
#   current_stop_sequence: 6
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337683
# }
#
# id: "VP-9"
# vehicle {
#   trip {
#     trip_id: "平日_16時36分_系統21082"
#   }
#   vehicle {
#     id: "0719"
#     label: "IchigoBUS"
#     license_plate: "0719"
#   }
#   position {
#     latitude: 40.8562469
#     longitude: 140.693954
#   }
#   current_stop_sequence: 24
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337666
# }
#
# id: "VP-10"
# vehicle {
#   trip {
#     trip_id: "平日_17時11分_系統6161"
#   }
#   vehicle {
#     id: "0728"
#     label: "IchigoBUS"
#     license_plate: "0728"
#   }
#   position {
#     latitude: 40.8173447
#     longitude: 140.755692
#   }
#   current_stop_sequence: 9
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337679
# }
#
# id: "VP-11"
# vehicle {
#   trip {
#     trip_id: "平日_17時12分_系統22022"
#   }
#   vehicle {
#     id: "1339"
#     label: "IchigoBUS"
#     license_plate: "1339"
#   }
#   position {
#     latitude: 40.7914238
#     longitude: 140.760574
#   }
#   current_stop_sequence: 8
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337687
# }
#
# id: "VP-12"
# vehicle {
#   trip {
#     trip_id: "平日_16時55分_系統42051"
#   }
#   vehicle {
#     id: "0664"
#     label: "IchigoBUS"
#     license_plate: "0664"
#   }
#   position {
#     latitude: 40.8284302
#     longitude: 140.731735
#   }
#   current_stop_sequence: 21
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337692
# }
#
# id: "VP-13"
# vehicle {
#   trip {
#     trip_id: "平日_17時00分_系統21031"
#   }
#   vehicle {
#     id: "1340"
#     label: "IchigoBUS"
#     license_plate: "1340"
#   }
#   position {
#     latitude: 40.8255348
#     longitude: 140.710892
#   }
#   current_stop_sequence: 12
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337663
# }
#
# id: "VP-14"
# vehicle {
#   trip {
#     trip_id: "平日_17時28分_系統12081"
#   }
#   vehicle {
#     id: "1255"
#     label: "IchigoBUS"
#     license_plate: "1255"
#   }
#   position {
#     latitude: 40.8281555
#     longitude: 140.73468
#   }
#   current_stop_sequence: 1
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337627
# }
#
# id: "VP-15"
# vehicle {
#   trip {
#     trip_id: "平日_17時07分_系統47032"
#   }
#   vehicle {
#     id: "1388"
#     label: "IchigoBUS"
#     license_plate: "1388"
#   }
#   position {
#     latitude: 40.8708572
#     longitude: 140.683533
#   }
#   current_stop_sequence: 27
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337690
# }
#
# id: "VP-16"
# vehicle {
#   trip {
#     trip_id: "平日_17時05分_系統41121"
#   }
#   vehicle {
#     id: "1348"
#     label: "IchigoBUS"
#     license_plate: "1348"
#   }
#   position {
#     latitude: 40.8260612
#     longitude: 140.775726
#   }
#   current_stop_sequence: 15
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337674
# }
#
# id: "VP-17"
# vehicle {
#   trip {
#     trip_id: "平日_16時40分_系統14021"
#   }
#   vehicle {
#     id: "1389"
#     label: "IchigoBUS"
#     license_plate: "1389"
#   }
#   position {
#     latitude: 40.7827873
#     longitude: 140.776321
#   }
#   current_stop_sequence: 25
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337688
# }
#
# id: "VP-18"
# vehicle {
#   trip {
#     trip_id: "平日_17時00分_系統80041"
#   }
#   vehicle {
#     id: "1391"
#     label: "IchigoBUS"
#     license_plate: "1391"
#   }
#   position {
#     latitude: 40.8053
#     longitude: 140.751709
#   }
#   current_stop_sequence: 11
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337681
# }
#
# id: "VP-19"
# vehicle {
#   trip {
#     trip_id: "平日_17時25分_系統44374"
#   }
#   vehicle {
#     id: "0729"
#     label: "IchigoBUS"
#     license_plate: "0729"
#   }
#   position {
#     latitude: 40.8156586
#     longitude: 140.687424
#   }
#   current_stop_sequence: 1
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337678
# }
#
# id: "VP-20"
# vehicle {
#   trip {
#     trip_id: "平日_17時05分_系統17002"
#   }
#   vehicle {
#     id: "1446"
#     label: "IchigoBUS"
#     license_plate: "1446"
#   }
#   position {
#     latitude: 40.7904434
#     longitude: 140.761032
#   }
#   current_stop_sequence: 13
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337669
# }
#
# id: "VP-21"
# vehicle {
#   trip {
#     trip_id: "平日_16時41分_系統45021"
#   }
#   vehicle {
#     id: "0663"
#     label: "IchigoBUS"
#     license_plate: "0663"
#   }
#   position {
#     latitude: 40.8234367
#     longitude: 140.741653
#   }
#   current_stop_sequence: 22
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337668
# }
#
# id: "VP-22"
# vehicle {
#   trip {
#     trip_id: "平日_17時15分_系統6162"
#   }
#   vehicle {
#     id: "1347"
#     label: "IchigoBUS"
#     license_plate: "1347"
#   }
#   position {
#     latitude: 40.827137
#     longitude: 140.794983
#   }
#   current_stop_sequence: 11
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337692
# }
#
# id: "VP-23"
# vehicle {
#   trip {
#     trip_id: "平日_17時23分_系統12142"
#   }
#   vehicle {
#     id: "1444"
#     label: "IchigoBUS"
#     license_plate: "1444"
#   }
#   position {
#     latitude: 40.797081
#     longitude: 140.806976
#   }
#   current_stop_sequence: 4
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337678
# }
#
# id: "VP-24"
# vehicle {
#   trip {
#     trip_id: "平日_17時20分_系統16042"
#   }
#   vehicle {
#     id: "1256"
#     label: "IchigoBUS"
#     license_plate: "1256"
#   }
#   position {
#     latitude: 40.7768593
#     longitude: 140.765823
#   }
#   current_stop_sequence: 6
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337679
# }
#
# id: "VP-25"
# vehicle {
#   trip {
#     trip_id: "平日_17時18分_系統21172"
#   }
#   vehicle {
#     id: "1337"
#     label: "IchigoBUS"
#     license_plate: "1337"
#   }
#   position {
#     latitude: 40.8148689
#     longitude: 140.752182
#   }
#   current_stop_sequence: 2
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337681
# }
#
# id: "VP-26"
# vehicle {
#   trip {
#     trip_id: "平日_17時13分_系統39061"
#   }
#   vehicle {
#     id: "1338"
#     label: "IchigoBUS"
#     license_plate: "1338"
#   }
#   position {
#     latitude: 40.8252945
#     longitude: 140.728958
#   }
#   current_stop_sequence: 5
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337672
# }
#
# id: "VP-27"
# vehicle {
#   trip {
#     trip_id: "平日_17時09分_系統45181"
#   }
#   vehicle {
#     id: "1250"
#     label: "IchigoBUS"
#     license_plate: "1250"
#   }
#   position {
#     latitude: 40.8235779
#     longitude: 140.755066
#   }
#   current_stop_sequence: 10
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337689
# }
#
# id: "VP-28"
# vehicle {
#   trip {
#     trip_id: "平日_16時20分_系統14022"
#   }
#   vehicle {
#     id: "1251"
#     label: "IchigoBUS"
#     license_plate: "1251"
#   }
#   position {
#     latitude: 40.8156548
#     longitude: 140.764084
#   }
#   current_stop_sequence: 35
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337682
# }
#
# id: "VP-29"
# vehicle {
#   trip {
#     trip_id: "平日_17時24分_系統56061"
#   }
#   vehicle {
#     id: "1310"
#     label: "IchigoBUS"
#     license_plate: "1310"
#   }
#   position {
#     latitude: 40.838768
#     longitude: 140.803009
#   }
#   current_stop_sequence: 5
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337687
# }
#
# id: "VP-30"
# vehicle {
#   trip {
#     trip_id: "平日_17時18分_系統37032"
#   }
#   vehicle {
#     id: "1309"
#     label: "IchigoBUS"
#     license_plate: "1309"
#   }
#   position {
#     latitude: 40.8081245
#     longitude: 140.736938
#   }
#   current_stop_sequence: 5
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337681
# }
#
# id: "VP-31"
# vehicle {
#   trip {
#     trip_id: "平日_17時27分_系統37031"
#   }
#   vehicle {
#     id: "0892"
#     label: "IchigoBUS"
#     license_plate: "0892"
#   }
#   position {
#     latitude: 40.8283081
#     longitude: 140.73494
#   }
#   current_stop_sequence: 1
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337649
# }
#
# id: "VP-32"
# vehicle {
#   trip {
#     trip_id: "平日_16時40分_系統25052"
#   }
#   vehicle {
#     id: "0890"
#     label: "IchigoBUS"
#     license_plate: "0890"
#   }
#   position {
#     latitude: 40.8231354
#     longitude: 140.743317
#   }
#   current_stop_sequence: 28
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337646
# }
#
# id: "VP-33"
# vehicle {
#   trip {
#     trip_id: "平日_17時20分_系統1021"
#   }
#   vehicle {
#     id: "1312"
#     label: "IchigoBUS"
#     license_plate: "1312"
#   }
#   position {
#     latitude: 40.8329544
#     longitude: 140.791412
#   }
#   current_stop_sequence: 8
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337685
# }
#
# id: "VP-34"
# vehicle {
#   trip {
#     trip_id: "平日_17時08分_系統36201"
#   }
#   vehicle {
#     id: "1107"
#     label: "IchigoBUS"
#     license_plate: "1107"
#   }
#   position {
#     latitude: 40.8257713
#     longitude: 140.714035
#   }
#   current_stop_sequence: 7
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337684
# }
#
# id: "VP-35"
# vehicle {
#   trip {
#     trip_id: "平日_17時03分_系統15031"
#   }
#   vehicle {
#     id: "1307"
#     label: "IchigoBUS"
#     license_plate: "1307"
#   }
#   position {
#     latitude: 40.8099861
#     longitude: 140.763748
#   }
#   current_stop_sequence: 12
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337679
# }
#
# id: "VP-36"
# vehicle {
#   trip {
#     trip_id: "平日_17時20分_系統24012"
#   }
#   vehicle {
#     id: "1414"
#     label: "IchigoBUS"
#     license_plate: "1414"
#   }
#   position {
#     latitude: 40.7948227
#     longitude: 140.761292
#   }
#   current_stop_sequence: 3
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337680
# }
#
# id: "VP-37"
# vehicle {
#   trip {
#     trip_id: "平日_17時15分_系統1052"
#   }
#   vehicle {
#     id: "1355"
#     label: "IchigoBUS"
#     license_plate: "1355"
#   }
#   position {
#     latitude: 40.8231
#     longitude: 140.747757
#   }
#   current_stop_sequence: 5
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337688
# }
#
# id: "VP-38"
# vehicle {
#   trip {
#     trip_id: "平日_17時08分_系統35162"
#   }
#   vehicle {
#     id: "1254"
#     label: "IchigoBUS"
#     license_plate: "1254"
#   }
#   position {
#     latitude: 40.8202667
#     longitude: 140.730789
#   }
#   current_stop_sequence: 12
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337688
# }
#
# id: "VP-39"
# vehicle {
#   trip {
#     trip_id: "平日_16時45分_系統12142"
#   }
#   vehicle {
#     id: "0827"
#     label: "IchigoBUS"
#     license_plate: "0827"
#   }
#   position {
#     latitude: 40.8230057
#     longitude: 140.745895
#   }
#   current_stop_sequence: 28
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337674
# }
#
# id: "VP-40"
# vehicle {
#   trip {
#     trip_id: "平日_16時42分_系統6171"
#   }
#   vehicle {
#     id: "1036"
#     label: "IchigoBUS"
#     license_plate: "1036"
#   }
#   position {
#     latitude: 40.8180847
#     longitude: 140.790314
#   }
#   current_stop_sequence: 21
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337679
# }
#
# id: "VP-41"
# vehicle {
#   trip {
#     trip_id: "平日_17時10分_系統41061"
#   }
#   vehicle {
#     id: "0974"
#     label: "IchigoBUS"
#     license_plate: "0974"
#   }
#   position {
#     latitude: 40.834465
#     longitude: 140.6828
#   }
#   current_stop_sequence: 7
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337689
# }
#
# id: "VP-42"
# vehicle {
#   trip {
#     trip_id: "平日_17時18分_系統8032"
#   }
#   vehicle {
#     id: "1102"
#     label: "IchigoBUS"
#     license_plate: "1102"
#   }
#   position {
#     latitude: 40.7917671
#     longitude: 140.784912
#   }
#   current_stop_sequence: 6
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337678
# }
#
# id: "VP-43"
# vehicle {
#   trip {
#     trip_id: "平日_17時03分_系統56022"
#   }
#   vehicle {
#     id: "1176"
#     label: "IchigoBUS"
#     license_plate: "1176"
#   }
#   position {
#     latitude: 40.8254623
#     longitude: 140.771164
#   }
#   current_stop_sequence: 10
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337687
# }
#
# id: "VP-44"
# vehicle {
#   trip {
#     trip_id: "平日_17時15分_系統33091"
#   }
#   vehicle {
#     id: "0830"
#     label: "IchigoBUS"
#     license_plate: "0830"
#   }
#   position {
#     latitude: 40.8272629
#     longitude: 140.737335
#   }
#   current_stop_sequence: 2
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337678
# }
#
# id: "VP-45"
# vehicle {
#   trip {
#     trip_id: "平日_16時31分_系統22032"
#   }
#   vehicle {
#     id: "0723"
#     label: "IchigoBUS"
#     license_plate: "0723"
#   }
#   position {
#     latitude: 40.8261719
#     longitude: 140.69603
#   }
#   current_stop_sequence: 25
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337688
# }
#
# id: "VP-46"
# vehicle {
#   trip {
#     trip_id: "平日_17時05分_系統39052"
#   }
#   vehicle {
#     id: "0976"
#     label: "IchigoBUS"
#     license_plate: "0976"
#   }
#   position {
#     latitude: 40.8257027
#     longitude: 140.71257
#   }
#   current_stop_sequence: 12
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337682
# }
#
# id: "VP-47"
# vehicle {
#   trip {
#     trip_id: "平日_17時17分_系統47021"
#   }
#   vehicle {
#     id: "1103"
#     label: "IchigoBUS"
#     license_plate: "1103"
#   }
#   position {
#     latitude: 40.8261719
#     longitude: 140.775894
#   }
#   current_stop_sequence: 6
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337679
# }
#
# id: "VP-48"
# vehicle {
#   trip {
#     trip_id: "平日_16時29分_系統16131"
#   }
#   vehicle {
#     id: "1110"
#     label: "IchigoBUS"
#     license_plate: "1110"
#   }
#   position {
#     latitude: 40.7580757
#     longitude: 140.774826
#   }
#   current_stop_sequence: 36
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337634
# }
#
# id: "VP-49"
# vehicle {
#   trip {
#     trip_id: "平日_17時10分_系統48212"
#   }
#   vehicle {
#     id: "1041"
#     label: "IchigoBUS"
#     license_plate: "1041"
#   }
#   position {
#     latitude: 40.8233643
#     longitude: 140.741806
#   }
#   current_stop_sequence: 5
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337664
# }
#
# id: "VP-50"
# vehicle {
#   trip {
#     trip_id: "平日_17時20分_系統14021"
#   }
#   vehicle {
#     id: "1108"
#     label: "IchigoBUS"
#     license_plate: "1108"
#   }
#   position {
#     latitude: 40.8239365
#     longitude: 140.745392
#   }
#   current_stop_sequence: 4
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337686
# }
#
# id: "VP-51"
# vehicle {
#   trip {
#     trip_id: "平日_16時55分_系統42012"
#   }
#   vehicle {
#     id: "1038"
#     label: "IchigoBUS"
#     license_plate: "1038"
#   }
#   position {
#     latitude: 40.8256187
#     longitude: 140.727646
#   }
#   current_stop_sequence: 15
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337649
# }
#
# id: "VP-52"
# vehicle {
#   trip {
#     trip_id: "平日_17時30分_系統38051"
#   }
#   vehicle {
#     id: "1179"
#     label: "IchigoBUS"
#     license_plate: "1179"
#   }
#   position {
#     latitude: 40.828167
#     longitude: 140.735138
#   }
#   current_stop_sequence: 1
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337632
# }
#
# id: "VP-53"
# vehicle {
#   trip {
#     trip_id: "平日_17時02分_系統49022"
#   }
#   vehicle {
#     id: "1039"
#     label: "IchigoBUS"
#     license_plate: "1039"
#   }
#   position {
#     latitude: 40.832798
#     longitude: 140.791245
#   }
#   current_stop_sequence: 18
#   current_status: IN_TRANSIT_TO
#   timestamp: 1734337679
# }

# %% [markdown]
# #### 2-c) Pandas での読み込み

# %%
data = []
for entity in feed.entity:
    if not entity.HasField('vehicle'):
        continue
    
    vehicle = entity.vehicle    
    data.append({
        'vhiecle_id': vehicle.vehicle.id,
        'trip_id': vehicle.trip.trip_id,
        'current_stop_sequence': vehicle.current_stop_sequence,
        'cuttent_status': vehicle.current_status,
        'lat': vehicle.position.latitude,
        'lon': vehicle.position.longitude
    })

df_vehicle = pd.DataFrame(data)
df_vehicle
# Out:
#    vhiecle_id            trip_id  current_stop_sequence  cuttent_status  \
# 0        1253  平日_16時44分_系統17032                     22               2
# 1        1397  平日_17時15分_系統16031                      5               2
# 2        1106  平日_16時30分_系統80031                     19               2
# 3        1105  平日_16時49分_系統39082                     21               2
# 4        1252  平日_16時52分_系統20131                     20               2
# 5        0727  平日_17時20分_系統24011                      4               2
# 6        1447  平日_17時25分_系統15032                      2               2
# 7        1040  平日_17時15分_系統28102                      6               2
# 29  40.808125  140.736938
# 30  40.828308  140.734940
# 31  40.823135  140.743317
# 32  40.832954  140.791412
# 33  40.825771  140.714035
# 34  40.809986  140.763748
# 35  40.794823  140.761292
# 36  40.823101  140.747757
# 37  40.820267  140.730789
# 38  40.823006  140.745895
# 39  40.818085  140.790314
# 40  40.834465  140.682800
# 41  40.791767  140.784912
# 42  40.825462  140.771164
# 43  40.827263  140.737335
# 44  40.826172  140.696030
# 45  40.825703  140.712570
# 46  40.826172  140.775894
# 47  40.758076  140.774826
# 48  40.823364  140.741806
# 49  40.823936  140.745392
# 50  40.825619  140.727646
# 51  40.828167  140.735138
# 52  40.832798  140.791245

# %% [markdown]
# #### 2-d) GeoPandas での読み込み

# %%
gdf_vehicle = gpd.GeoDataFrame(df_vehicle, geometry=gpd.points_from_xy(df_vehicle['lon'], df_vehicle['lat']), crs=4326)
gdf_vehicle
# Out:
#    vhiecle_id            trip_id  current_stop_sequence  cuttent_status  \
# 0        1253  平日_16時44分_系統17032                     22               2
# 1        1397  平日_17時15分_系統16031                      5               2
# 2        1106  平日_16時30分_系統80031                     19               2
# 3        1105  平日_16時49分_系統39082                     21               2
# 4        1252  平日_16時52分_系統20131                     20               2
# 5        0727  平日_17時20分_系統24011                      4               2
# 6        1447  平日_17時25分_系統15032                      2               2
# 7        1040  平日_17時15分_系統28102                      6               2
# 8        0719  平日_16時36分_系統21082                     24               2
# 9        0728   平日_17時11分_系統6161                      9               2
# 10       1339  平日_17時12分_系統22022                      8               2
# 11       0664  平日_16時55分_系統42051                     21               2
# 12       1340  平日_17時00分_系統21031                     12               2
# 13       1255  平日_17時28分_系統12081                      1               2
# 14       1388  平日_17時07分_系統47032                     27               2
# 15       1348  平日_17時05分_系統41121                     15               2
# 16       1389  平日_16時40分_系統14021                     25               2
# 17       1391  平日_17時00分_系統80041                     11               2
# 18       0729  平日_17時25分_系統44374                      1               2
# 19       1446  平日_17時05分_系統17002                     13               2
# 20       0663  平日_16時41分_系統45021                     22               2
# 21       1347   平日_17時15分_系統6162                     11               2
# 22       1444  平日_17時23分_系統12142                      4               2
# 23       1256  平日_17時20分_系統16042                      6               2
# 24       1337  平日_17時18分_系統21172                      2               2
# 25       1338  平日_17時13分_系統39061                      5               2
# 26       1250  平日_17時09分_系統45181                     10               2
# 27       1251  平日_16時20分_系統14022                     35               2
# 28       1310  平日_17時24分_系統56061                      5               2
# 29       1309  平日_17時18分_系統37032                      5               2
# 30       0892  平日_17時27分_系統37031                      1               2
# 31       0890  平日_16時40分_系統25052                     28               2
# 32       1312   平日_17時20分_系統1021                      8               2
# 33       1107  平日_17時08分_系統36201                      7               2
# 34       1307  平日_17時03分_系統15031                     12               2
# 35       1414  平日_17時20分_系統24012                      3               2
# 36       1355   平日_17時15分_系統1052                      5               2
# 37       1254  平日_17時08分_系統35162                     12               2
# 38       0827  平日_16時45分_系統12142                     28               2
# 39       1036   平日_16時42分_系統6171                     21               2
# 40       0974  平日_17時10分_系統41061                      7               2
# 41       1102   平日_17時18分_系統8032                      6               2
# 43  40.827263  140.737335  POINT (140.73734 40.82726)
# 44  40.826172  140.696030  POINT (140.69603 40.82617)
# 45  40.825703  140.712570  POINT (140.71257 40.82570)
# 46  40.826172  140.775894  POINT (140.77589 40.82617)
# 47  40.758076  140.774826  POINT (140.77483 40.75808)
# 48  40.823364  140.741806  POINT (140.74181 40.82336)
# 49  40.823936  140.745392  POINT (140.74539 40.82394)
# 50  40.825619  140.727646  POINT (140.72765 40.82562)
# 51  40.828167  140.735138  POINT (140.73514 40.82817)
# 52  40.832798  140.791245  POINT (140.79124 40.83280)

# %%
gdf_vehicle.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c5e0455a09975e0f411b6c984c1d3c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c5e0455a09975e0f411b6c984c1d3c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c5e0455a09975e0f411b6c984c1d3c1 = L.map(
#                 &quot;map_7c5e0455a09975e0f411b6c984c1d3c1&quot;,
#                 {
#                     center: [40.81446647644043, 140.74588012695312],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7c5e0455a09975e0f411b6c984c1d3c1);
#
#
#
#
#
#             var tile_layer_2214784db4c47e59504a7920e5c312f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2214784db4c47e59504a7920e5c312f9.addTo(map_7c5e0455a09975e0f411b6c984c1d3c1);
#
#
#             map_7c5e0455a09975e0f411b6c984c1d3c1.fitBounds(
#                 [[40.75807571411133, 140.68280029296875], [40.87085723876953, 140.8089599609375]],
#                 {}
#             );
#
#
#         function geo_json_83f68f52d1b10ee9ae1c361954c8cae6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_83f68f52d1b10ee9ae1c361954c8cae6_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_83f68f52d1b10ee9ae1c361954c8cae6_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_83f68f52d1b10ee9ae1c361954c8cae6_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_83f68f52d1b10ee9ae1c361954c8cae6_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_83f68f52d1b10ee9ae1c361954c8cae6.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_83f68f52d1b10ee9ae1c361954c8cae6_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_83f68f52d1b10ee9ae1c361954c8cae6 = L.geoJson(null, {
#                 onEachFeature: geo_json_83f68f52d1b10ee9ae1c361954c8cae6_onEachFeature,
#
#                 style: geo_json_83f68f52d1b10ee9ae1c361954c8cae6_styler,
#                 pointToLayer: geo_json_83f68f52d1b10ee9ae1c361954c8cae6_pointToLayer,
#         });
#
#         function geo_json_83f68f52d1b10ee9ae1c361954c8cae6_add (data) {
#             geo_json_83f68f52d1b10ee9ae1c361954c8cae6
#                 .addData(data);
#         }
#             geo_json_83f68f52d1b10ee9ae1c361954c8cae6_add({&quot;bbox&quot;: [140.68280029296875, 40.75807571411133, 140.8089599609375, 40.87085723876953], &quot;features&quot;: [{&quot;bbox&quot;: [140.75025939941406, 40.82254409790039, 140.75025939941406, 40.82254409790039], &quot;geometry&quot;: {&quot;coordinates&quot;: [140.75025939941406, 40.82254409790039], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;current_stop_sequence&quot;: 22, &quot;cuttent_status&quot;: 2, &quot;lat&quot;: 40.82254409790039, &quot;lon&quot;: 140.75025939941406, &quot;trip_id&quot;: &quot;\u5e73\u65e5_16\u664244\u5206_\u7cfb\u7d7117032&quot;, &quot;vhiecle_id&quot;: &quot;1253&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [140.74691772460938, 40.8231

# %% [markdown]
# ### 3. GTFSの読み込み
# #### 3-a) GTFSのダウンロードと展開

# %%
AOMORI_BUS_GTFS = 'https://api-public.odpt.org/api/v4/files/odpt/AomoriCity/AllLines.zip?date=20241201'

ZIP_PATH = 'tmp.zip'
TMPDIR_PATH = 'tmp/'

# %%
response = requests.get(AOMORI_BUS_GTFS)

if response.status_code == 200:
  with open(ZIP_PATH, 'wb') as f:
    f.write(response.content)

if not os.path.exists(TMPDIR_PATH):
  os.makedirs(TMPDIR_PATH)

with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
  zip_ref.extractall(TMPDIR_PATH)

# %% [markdown]
# #### 3-b) stops.txt / routes.txt / trips.txt / stop_times.txt の読み込み

# %%
df_stops = pd.read_csv(TMPDIR_PATH + 'stops.txt')
df_stops = df_stops[['stop_id', 'stop_name', 'stop_lat', 'stop_lon']]
df_stops
# Out:
#     stop_id   stop_name   stop_lat    stop_lon
# 0      1_01  青森駅 (降車専用)  40.828081  140.734870
# 1      1_02    青森駅 ②のりば  40.828131  140.734587
# 2      1_03    青森駅 ③のりば  40.828027  140.734523
# 3      1_04    青森駅 ④のりば  40.827924  140.734468
# 4      1_06    青森駅 ⑥のりば  40.828250  140.734850
# ..      ...         ...        ...         ...
# 817  864_01     大野中央公園前  40.800569  140.726947
# 818  867_01          安田  40.804843  140.708184
# 819  867_02          安田  40.805341  140.708471
# 820  263_01      総合体育館前  40.813405  140.746322
# 821  263_02      総合体育館前  40.813306  140.746163
#
# [822 rows x 4 columns]

# %%
df_routes = pd.read_csv(TMPDIR_PATH + 'routes.txt')
df_routes = df_routes[['route_id', 'route_short_name', 'route_long_name']]
df_routes
# Out:
#           route_id route_short_name  route_long_name
# 0     国道・古川線(1021)        A1 国道・古川線              NaN
# 1    造道・八重田線(1022)      C10 造道・八重田線              NaN
# 2    造道・八重田線(1041)      C12 造道・八重田線              NaN
# 3     国道・古川線(1051)        A1 国道・古川線              NaN
# 4    造道・八重田線(1052)      C10 造道・八重田線              NaN
# ..             ...              ...              ...
# 251  沖館・新田線(42052)       W53 沖館・新田線              NaN
# 252  浪館中央循環(82031)           浪館中央循環              NaN
# 253  浪館中央循環(82032)           浪館中央循環              NaN
# 254   旭町通り線(18001)        M36 旭町通り線              NaN
# 255  国道・古川線(18002)        A1 国道・古川線              NaN
#
# [256 rows x 3 columns]

# %%
df_trips = pd.read_csv(TMPDIR_PATH + 'trips.txt')
df_trips = df_trips[['route_id', 'service_id', 'trip_id', 'trip_headsign']]
df_trips
# Out:
#             route_id service_id             trip_id         trip_headsign
# 0       国道・古川線(1051)         平日    平日_05時50分_系統1051         A1青森駅（国道・古川線）
# 1     造道・八重田線(39202)         平日   平日_06時00分_系統39202  C10県病→東部〈営〉（造道・八重田線）
# 2      石江・新城線(39081)         平日   平日_06時00分_系統39081      T50西部〈営〉（石江・新城線）
# 3       浪館通り線(35141)         平日   平日_06時05分_系統35141       P40慈恵会病院（浪館通り線）
# 4       国道・古川線(1051)         平日    平日_06時07分_系統1051         A1青森駅（国道・古川線）
# ...              ...        ...                 ...                   ...
# 1607   石江・新城線(16052)        土日祝  土日祝_21時45分_系統16052      T50西部〈営〉（石江・新城線）
# 1608   造道・八重田線(1052)        土日祝   土日祝_21時45分_系統1052  C10古川→東部〈営〉（造道・八重田線）
# 1609     観光通り線(9031)        土日祝   土日祝_21時52分_系統9031        K32幸畑団地（観光通り線）
# 1610   石江・新城線(39051)        土日祝  土日祝_21時52分_系統39051      T50西部〈営〉（石江・新城線）
# 1611   造道・八重田線(1052)        土日祝   土日祝_22時05分_系統1052  C10古川→東部〈営〉（造道・八重田線）
#
# [1612 rows x 4 columns]

# %%
df_stop_times = pd.read_csv(TMPDIR_PATH + 'stop_times.txt')
df_stop_times = df_stop_times[['trip_id', 'arrival_time', 'departure_time', 'stop_id', 'stop_sequence', 'stop_headsign']]
df_stop_times
# Out:
#                  trip_id arrival_time departure_time stop_id  stop_sequence  \
# 0       平日_05時50分_系統1051     05:50:00       05:50:00  726_01              1
# 1       平日_05時50分_系統1051     05:51:00       05:51:00   53_01              2
# 2       平日_05時50分_系統1051     05:51:00       05:51:00   52_01              3
# 3       平日_05時50分_系統1051     05:52:00       05:52:00   51_01              4
# 4       平日_05時50分_系統1051     05:53:00       05:53:00   50_01              5
# ...                  ...          ...            ...     ...            ...
# 44666  土日祝_22時05分_系統1052     22:30:00       22:30:00   50_02             21
# 44667  土日祝_22時05分_系統1052     22:31:00       22:31:00   51_02             22
# 44668  土日祝_22時05分_系統1052     22:31:00       22:31:00   52_02             23
# 44669  土日祝_22時05分_系統1052     22:32:00       22:32:00   53_02             24
# 44670  土日祝_22時05分_系統1052     22:34:00       22:39:00  726_04             25
#
#              stop_headsign
# 0          ♿ A1青森駅（国道・古川線）
# 1          ♿ A1青森駅（国道・古川線）
# 2          ♿ A1青森駅（国道・古川線）
# 3          ♿ A1青森駅（国道・古川線）
# 4          ♿ A1青森駅（国道・古川線）
# ...                    ...
# 44666  ♿ C10東部〈営〉（造道・八重田線）
# 44667  ♿ C10東部〈営〉（造道・八重田線）
# 44668  ♿ C10東部〈営〉（造道・八重田線）
# 44669  ♿ C10東部〈営〉（造道・八重田線）
# 44670  ♿ C10東部〈営〉（造道・八重田線）
#
# [44671 rows x 6 columns]

# %% [markdown]
# #### 3-c) 特定の路線での絞り込み

# %%
df_routes_a1 = df_routes[df_routes['route_short_name'] == 'A1 国道・古川線']
df_trips_a1 = df_routes_a1.merge(df_trips)
df_trips_a1
# Out:
#           route_id route_short_name  route_long_name service_id  \
# 0     国道・古川線(1021)        A1 国道・古川線              NaN         平日
# 1     国道・古川線(1021)        A1 国道・古川線              NaN         平日
# 2     国道・古川線(1021)        A1 国道・古川線              NaN         平日
# 3     国道・古川線(1021)        A1 国道・古川線              NaN         平日
# 4     国道・古川線(1021)        A1 国道・古川線              NaN         平日
# ..             ...              ...              ...        ...
# 432  国道・古川線(12212)        A1 国道・古川線              NaN        土日祝
# 433  国道・古川線(16152)        A1 国道・古川線              NaN         平日
# 434  国道・古川線(16152)        A1 国道・古川線              NaN        土日祝
# 435  国道・古川線(16152)        A1 国道・古川線              NaN        土日祝
# 436  国道・古川線(18002)        A1 国道・古川線              NaN        土日祝
#
#                 trip_id       trip_headsign
# 0      平日_06時28分_系統1021       A1青森駅（国道・古川線）
# 1      平日_06時59分_系統1021       A1青森駅（国道・古川線）
# 2      平日_07時30分_系統1021       A1青森駅（国道・古川線）
# 3      平日_07時47分_系統1021       A1青森駅（国道・古川線）
# 4      平日_08時15分_系統1021       A1青森駅（国道・古川線）
# ..                  ...                 ...
# 432  土日祝_09時10分_系統12212  A1中央大橋→青森駅（国道・古川線）
# 433   平日_13時00分_系統16152  A1中央大橋→青森駅（国道・古川線）
# 434  土日祝_13時04分_系統16152  A1中央大橋→青森駅（国道・古川線）
# 435  土日祝_18時22分_系統16152  A1中央大橋→青森駅（国道・古川線）
# 436  土日祝_13時08分_系統18002    A1旭町→青森駅（国道・古川線）
#
# [437 rows x 6 columns]

# %% [markdown]
# #### 3-d) 特定の路線上の車両位置情報を確認

# %%
gdf_vehicle_a1 = gdf_vehicle.merge(df_trips_a1)
gdf_vehicle_a1
# Out:
#    vhiecle_id            trip_id  current_stop_sequence  cuttent_status  \
# 0        1253  平日_16時44分_系統17032                     22               2
# 1        1040  平日_17時15分_系統28102                      6               2
# 2        1339  平日_17時12分_系統22022                      8               2
# 3        1388  平日_17時07分_系統47032                     27               2
# 4        0729  平日_17時25分_系統44374                      1               2
# 5        1446  平日_17時05分_系統17002                     13               2
# 6        1347   平日_17時15分_系統6162                     11               2
# 7        1256  平日_17時20分_系統16042                      6               2
# 8        1310  平日_17時24分_系統56061                      5               2
# 9        1309  平日_17時18分_系統37032                      5               2
# 10       0890  平日_16時40分_系統25052                     28               2
# 11       1312   平日_17時20分_系統1021                      8               2
# 12       1414  平日_17時20分_系統24012                      3               2
# 13       1254  平日_17時08分_系統35162                     12               2
# 14       0976  平日_17時05分_系統39052                     12               2
#
#           lat         lon                    geometry       route_id  \
# 0   40.822544  140.750259  POINT (140.75026 40.82254)  国道・古川線(17032)
# 1   40.802860  140.740463  POINT (140.74046 40.80286)  国道・古川線(28102)
# 2   40.791424  140.760574  POINT (140.76057 40.79142)  国道・古川線(22022)
# 3   40.870857  140.683533  POINT (140.68353 40.87086)  国道・古川線(47032)
# 4   40.815659  140.687424  POINT (140.68742 40.81566)  国道・古川線(44374)
# 5   40.790443  140.761032  POINT (140.76103 40.79044)  国道・古川線(17002)
# 6   40.827137  140.794983  POINT (140.79498 40.82714)   国道・古川線(6162)
# 7   40.776859  140.765823  POINT (140.76582 40.77686)  国道・古川線(16042)
# 8   40.838768  140.803009  POINT (140.80301 40.83877)  国道・古川線(56061)
# 9   40.808125  140.736938  POINT (140.73694 40.80812)  国道・古川線(37032)
# 10  40.823135  140.743317  POINT (140.74332 40.82314)  国道・古川線(25052)
# 11  40.832954  140.791412  POINT (140.79141 40.83295)   国道・古川線(1021)
# 12  40.794823  140.761292  POINT (140.76129 40.79482)  国道・古川線(24012)
# 13  40.820267  140.730789  POINT (140.73079 40.82027)  国道・古川線(35162)
# 14  40.825703  140.712570  POINT (140.71257 40.82570)  国道・古川線(39052)
#
#    route_short_name  route_long_name service_id        trip_headsign
# 0         A1 国道・古川線              NaN         平日   A1観光通り→青森駅（国道・古川線）
# 1         A1 国道・古川線              NaN         平日     A1旭町→青森駅（国道・古川線）
# 2         A1 国道・古川線              NaN         平日   A1観光通り→青森駅（国道・古川線）
# 3         A1 国道・古川線              NaN         平日        A1青森駅（国道・古川線）
# 4         A1 国道・古川線              NaN         平日        A1青森駅（国道・古川線）
# 5         A1 国道・古川線              NaN         平日   A1中央大橋→青森駅（国道・古川線）
# 6         A1 国道・古川線              NaN         平日   A1小柳団地→青森駅（国道・古川線）
# 7         A1 国道・古川線              NaN         平日     A1旭町→青森駅（国道・古川線）
# 8         A1 国道・古川線              NaN         平日  A1東バイパス→青森駅（国道・古川線）
# 9         A1 国道・古川線              NaN         平日        A1青森駅（国道・古川線）
# 10        A1 国道・古川線              NaN         平日        A1青森駅（国道・古川線）
# 11        A1 国道・古川線              NaN         平日        A1青森駅（国道・古川線）
# 12        A1 国道・古川線              NaN         平日   A1観光通り→青森駅（国道・古川線）
# 13        A1 国道・古川線              NaN         平日        A1青森駅（国道・古川線）
# 14        A1 国道・古川線              NaN         平日        A1青森駅（国道・古川線）

# %%
df_stop_times_renamed = df_stop_times.rename(columns={'stop_sequence' : 'current_stop_sequence'})
df_stops_names = df_stops[['stop_id', 'stop_name']]
gdf_vehicle_a1.merge(df_stop_times_renamed).merge(df_stops_names)
# Out:
#    vhiecle_id            trip_id  current_stop_sequence  cuttent_status  \
# 0        1253  平日_16時44分_系統17032                     22               2
# 1        1040  平日_17時15分_系統28102                      6               2
# 2        1339  平日_17時12分_系統22022                      8               2
# 3        1388  平日_17時07分_系統47032                     27               2
# 4        0729  平日_17時25分_系統44374                      1               2
# 5        1446  平日_17時05分_系統17002                     13               2
# 6        1347   平日_17時15分_系統6162                     11               2
# 7        1256  平日_17時20分_系統16042                      6               2
# 8        1310  平日_17時24分_系統56061                      5               2
# 9        1309  平日_17時18分_系統37032                      5               2
# 10       0890  平日_16時40分_系統25052                     28               2
# 11       1312   平日_17時20分_系統1021                      8               2
# 12       1414  平日_17時20分_系統24012                      3               2
# 13       1254  平日_17時08分_系統35162                     12               2
# 14       0976  平日_17時05分_系統39052                     12               2
#
#           lat         lon                    geometry       route_id  \
# 0   40.822544  140.750259  POINT (140.75026 40.82254)  国道・古川線(17032)
# 1   40.802860  140.740463  POINT (140.74046 40.80286)  国道・古川線(28102)
# 2   40.791424  140.760574  POINT (140.76057 40.79142)  国道・古川線(22022)
# 3   40.870857  140.683533  POINT (140.68353 40.87086)  国道・古川線(47032)
# 4   40.815659  140.687424  POINT (140.68742 40.81566)  国道・古川線(44374)
# 5   40.790443  140.761032  POINT (140.76103 40.79044)  国道・古川線(17002)
# 6   40.827137  140.794983  POINT (140.79498 40.82714)   国道・古川線(6162)
# 7   40.776859  140.765823  POINT (140.76582 40.77686)  国道・古川線(16042)
# 8   40.838768  140.803009  POINT (140.80301 40.83877)  国道・古川線(56061)
# 9   40.808125  140.736938  POINT (140.73694 40.80812)  国道・古川線(37032)
