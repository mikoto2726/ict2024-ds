# %% [markdown]
# # データ・サイエンス	データ・サイエンス社会応用論 / ICT社会応用演習Ⅳ
# ## 11-4. GTFS Realtime : Trip Update

# %% [markdown]
# ### 1. 下準備

# %%
import requests
import zipfile
import os
from google.transit import gtfs_realtime_pb2
import pandas as pd
import geopandas as gpd

# %%
AOMORI_BUS_ALERT_URL = 'https://api-public.odpt.org/api/v4/gtfs/realtime/odpt_AomoriCity_AllLines_alert'
AOMORI_BUS_TRIPUPDATE_URL = 'https://api-public.odpt.org/api/v4/gtfs/realtime/odpt_AomoriCity_AllLines_trip_update'
AOMORI_BUS_VEHICLEPOSITION_URL = 'https://api-public.odpt.org/api/v4/gtfs/realtime/odpt_AomoriCity_AllLines_vehicle'

# %% [markdown]
# ### 2. GTFS Realtime のダウンロード
# #### 2-a) フィードの読み込み

# %%
response = requests.get(AOMORI_BUS_TRIPUPDATE_URL)

if response.status_code == 200:
    pb_data = response.content

# %%
feed = gtfs_realtime_pb2.FeedMessage()
feed.ParseFromString(pb_data)
# Out:
# 3001

# %% [markdown]
# #### 2-b) ヘッダとエンティティの表示

# %%
print(feed.header)
# Out:
# gtfs_realtime_version: "1.0"
# incrementality: FULL_DATASET
# timestamp: 1734338658

# %%
for entity in feed.entity:
    print(entity)
# Out:
# id: "TU0"
# trip_update {
#   trip {
#     trip_id: "平日_17時30分_系統22021"
#   }
#   stop_time_update {
#     stop_sequence: 8
#     departure {
#       delay: 123
#     }
#   }
# }
#
# id: "TU1"
# trip_update {
#   trip {
#     trip_id: "平日_16時44分_系統17032"
#   }
#   stop_time_update {
#     stop_sequence: 25
#     departure {
#       delay: 1214
#     }
#   }
# }
#
# id: "TU2"
# trip_update {
#   trip {
#     trip_id: "平日_17時15分_系統16031"
#   }
#   stop_time_update {
#     stop_sequence: 11
#     departure {
#       delay: 734
#     }
#   }
# }
#
# id: "TU3"
# trip_update {
#   trip {
#     trip_id: "平日_17時45分_系統12141"
#   }
#   stop_time_update {
#     stop_sequence: 1
#     departure {
#       delay: 0
#     }
#   }
# }
#
# id: "TU4"
# trip_update {
#   trip {
#     trip_id: "平日_16時49分_系統39082"
#   }
#   stop_time_update {
#     stop_sequence: 30
#     departure {
#       delay: 794
#     }
#   }
# }
#
# id: "TU5"
# trip_update {
#   trip {
#     trip_id: "平日_17時31分_系統8031"
#   }
#   stop_time_update {
#     stop_sequence: 5
#     departure {
#       delay: 314
#     }
#   }
# }
#
# id: "TU6"
# trip_update {
#   trip {
#     trip_id: "平日_17時20分_系統24011"
#   }
#   stop_time_update {
#     stop_sequence: 9
#     departure {
#       delay: 554
#     }
#   }
# }
#
# id: "TU7"
# trip_update {
#   trip {
#     trip_id: "平日_17時25分_系統15032"
#   }
#   stop_time_update {
#     stop_sequence: 13
#     departure {
#       delay: 194
#     }
#   }
# }
#
# id: "TU8"
# trip_update {
#   trip {
#     trip_id: "平日_17時15分_系統28102"
#   }
#   stop_time_update {
#     stop_sequence: 10
#     departure {
#       delay: 1154
#     }
#   }
# }
#
# id: "TU9"
# trip_update {
#   trip {
#     trip_id: "平日_17時44分_系統21081"
#   }
#   stop_time_update {
#     stop_sequence: 1
#     departure {
#       delay: 0
#     }
#   }
# }
#
# id: "TU10"
# trip_update {
#   trip {
#     trip_id: "平日_17時11分_系統6161"
#   }
#   stop_time_update {
#     stop_sequence: 14
#     departure {
#       delay: 614
#     }
#   }
# }
#
# id: "TU11"
# trip_update {
#   trip {
#     trip_id: "平日_17時38分_系統45021"
#   }
#   stop_time_update {
#     stop_sequence: 6
#     departure {
#       delay: 74
#     }
#   }
# }
#
# id: "TU12"
# trip_update {
#   trip {
#     trip_id: "平日_17時33分_系統49021"
#   }
#   stop_time_update {
#     stop_sequence: 4
#     departure {
#       delay: 254
#     }
#   }
# }
#
# id: "TU13"
# trip_update {
#   trip {
#     trip_id: "平日_17時40分_系統14022"
#   }
#   stop_time_update {
#     stop_sequence: 2
#     departure {
#       delay: 74
#     }
#   }
# }
#
# id: "TU14"
# trip_update {
#   trip {
#     trip_id: "平日_17時12分_系統22022"
#   }
#   stop_time_update {
#     stop_sequence: 12
#     departure {
#       delay: 794
#     }
#   }
# }
#
# id: "TU15"
# trip_update {
#   trip {
#     trip_id: "平日_16時55分_系統42051"
#   }
#   stop_time_update {
#     stop_sequence: 26
#     departure {
#       delay: 1034
#     }
#   }
# }
#
# id: "TU16"
# trip_update {
#   trip {
#     trip_id: "平日_17時00分_系統21031"
#   }
#   stop_time_update {
#     stop_sequence: 18
#     departure {
#       delay: 1094
#     }
#   }
# }
#
# id: "TU17"
# trip_update {
#   trip {
#     trip_id: "平日_17時28分_系統12081"
#   }
#   stop_time_update {
#     stop_sequence: 6
#     departure {
#       delay: 434
#     }
#   }
# }
#
# id: "TU18"
# trip_update {
#   trip {
#     trip_id: "平日_17時33分_系統33071"
#   }
#   stop_time_update {
#     stop_sequence: 10
#     departure {
#       delay: 58
#     }
#   }
# }
#
# id: "TU19"
# trip_update {
#   trip {
#     trip_id: "平日_17時38分_系統39181"
#   }
#   stop_time_update {
#     stop_sequence: 3
#     departure {
#       delay: 76
#     }
#   }
# }
#
# id: "TU20"
# trip_update {
#   trip {
#     trip_id: "平日_17時45分_系統80031"
#   }
#   stop_time_update {
#     stop_sequence: 2
#     departure {
#       delay: 0
#     }
#   }
# }
#
# id: "TU21"
# trip_update {
#   trip {
#     trip_id: "平日_17時07分_系統47032"
#   }
#   stop_time_update {
#     stop_sequence: 41
#     departure {
#       delay: 494
#     }
#   }
# }
#
# id: "TU22"
# trip_update {
#   trip {
#     trip_id: "平日_17時05分_系統41121"
#   }
#   stop_time_update {
#     stop_sequence: 21
#     departure {
#       delay: 614
#     }
#   }
# }
#
# id: "TU23"
# trip_update {
#   trip {
#     trip_id: "平日_16時40分_系統14021"
#   }
#   stop_time_update {
#     stop_sequence: 32
#     departure {
#       delay: 434
#     }
#   }
# }
#
# id: "TU24"
# trip_update {
#   trip {
#     trip_id: "平日_17時00分_系統80041"
#   }
#   stop_time_update {
#     stop_sequence: 15
#     departure {
#       delay: 674
#     }
#   }
# }
#
# id: "TU25"
# trip_update {
#   trip {
#     trip_id: "平日_17時25分_系統44374"
#   }
#   stop_time_update {
#     stop_sequence: 11
#     departure {
#       delay: 254
#     }
#   }
# }
#
# id: "TU26"
# trip_update {
#   trip {
#     trip_id: "平日_17時05分_系統17002"
#   }
#   stop_time_update {
#     stop_sequence: 17
#     departure {
#       delay: 439
#     }
#   }
# }
#
# id: "TU27"
# trip_update {
#   trip {
#     trip_id: "平日_16時41分_系統45021"
#   }
#   stop_time_update {
#     stop_sequence: 26
#     departure {
#       delay: 1334
#     }
#   }
# }
#
# id: "TU28"
# trip_update {
#   trip {
#     trip_id: "平日_17時15分_系統6162"
#   }
#   stop_time_update {
#     stop_sequence: 18
#     departure {
#       delay: 434
#     }
#   }
# }
#
# id: "TU29"
# trip_update {
#   trip {
#     trip_id: "平日_17時23分_系統12142"
#   }
#   stop_time_update {
#     stop_sequence: 16
#     departure {
#       delay: 74
#     }
#   }
# }
#
# id: "TU30"
# trip_update {
#   trip {
#     trip_id: "平日_17時37分_系統12062"
#   }
#   stop_time_update {
#     stop_sequence: 5
#     departure {
#       delay: 194
#     }
#   }
# }
#
# id: "TU31"
# trip_update {
#   trip {
#     trip_id: "平日_17時20分_系統16042"
#   }
#   stop_time_update {
#     stop_sequence: 14
#     departure {
#       delay: 494
#     }
#   }
# }
#
# id: "TU32"
# trip_update {
#   trip {
#     trip_id: "平日_17時18分_系統21172"
#   }
#   stop_time_update {
#     stop_sequence: 7
#     departure {
#       delay: 614
#     }
#   }
# }
#
# id: "TU33"
# trip_update {
#   trip {
#     trip_id: "平日_17時13分_系統39061"
#   }
#   stop_time_update {
#     stop_sequence: 11
#     departure {
#       delay: 854
#     }
#   }
# }
#
# id: "TU34"
# trip_update {
#   trip {
#     trip_id: "平日_17時09分_系統45181"
#   }
#   stop_time_update {
#     stop_sequence: 13
#     departure {
#       delay: 554
#     }
#   }
# }
#
# id: "TU35"
# trip_update {
#   trip {
#     trip_id: "平日_16時20分_系統14022"
#   }
#   stop_time_update {
#     stop_sequence: 41
#     departure {
#       delay: 914
#     }
#   }
# }
#
# id: "TU36"
# trip_update {
#   trip {
#     trip_id: "平日_17時24分_系統56061"
#   }
#   stop_time_update {
#     stop_sequence: 17
#     departure {
#       delay: 194
#     }
#   }
# }
#
# id: "TU37"
# trip_update {
#   trip {
#     trip_id: "平日_17時18分_系統37032"
#   }
#   stop_time_update {
#     stop_sequence: 11
#     departure {
#       delay: 494
#     }
#   }
# }
#
# id: "TU38"
# trip_update {
#   trip {
#     trip_id: "平日_17時27分_系統37031"
#   }
#   stop_time_update {
#     stop_sequence: 4
#     departure {
#       delay: 434
#     }
#   }
# }
#
# id: "TU39"
# trip_update {
#   trip {
#     trip_id: "平日_17時30分_系統1051"
#   }
#   stop_time_update {
#     stop_sequence: 11
#     departure {
#       delay: 74
#     }
#   }
# }
#
# id: "TU40"
# trip_update {
#   trip {
#     trip_id: "平日_17時20分_系統1021"
#   }
#   stop_time_update {
#     stop_sequence: 14
#     departure {
#       delay: 434
#     }
#   }
# }
#
# id: "TU41"
# trip_update {
#   trip {
#     trip_id: "平日_17時03分_系統15031"
#   }
#   stop_time_update {
#     stop_sequence: 17
#     departure {
#       delay: 914
#     }
#   }
# }
#
# id: "TU42"
# trip_update {
#   trip {
#     trip_id: "平日_17時20分_系統24012"
#   }
#   stop_time_update {
#     stop_sequence: 8
#     departure {
#       delay: 434
#     }
#   }
# }
#
# id: "TU43"
# trip_update {
#   trip {
#     trip_id: "平日_17時15分_系統1052"
#   }
#   stop_time_update {
#     stop_sequence: 12
#     departure {
#       delay: 554
#     }
#   }
# }
#
# id: "TU44"
# trip_update {
#   trip {
#     trip_id: "平日_17時43分_系統39122"
#   }
#   stop_time_update {
#     stop_sequence: 1
#     departure {
#       delay: 32
#     }
#   }
# }
#
# id: "TU45"
# trip_update {
#   trip {
#     trip_id: "平日_17時10分_系統41061"
#   }
#   stop_time_update {
#     stop_sequence: 11
#     departure {
#       delay: 854
#     }
#   }
# }
#
# id: "TU46"
# trip_update {
#   trip {
#     trip_id: "平日_17時18分_系統8032"
#   }
#   stop_time_update {
#     stop_sequence: 13
#     departure {
#       delay: 292
#     }
#   }
# }
#
# id: "TU47"
# trip_update {
#   trip {
#     trip_id: "平日_17時35分_系統35162"
#   }
#   stop_time_update {
#     stop_sequence: 5
#     departure {
#       delay: 194
#     }
#   }
# }
#
# id: "TU48"
# trip_update {
#   trip {
#     trip_id: "平日_17時03分_系統56022"
#   }
#   stop_time_update {
#     stop_sequence: 16
#     departure {
#       delay: 854
#     }
#   }
# }
#
# id: "TU49"
# trip_update {
#   trip {
#     trip_id: "平日_17時15分_系統33091"
#   }
#   stop_time_update {
#     stop_sequence: 6
#     departure {
#       delay: 1094
#     }
#   }
# }
#
# id: "TU50"
# trip_update {
#   trip {
#     trip_id: "平日_17時42分_系統39251"
#   }
#   stop_time_update {
#     stop_sequence: 1
#     departure {
#       delay: 0
#     }
#   }
# }
#
# id: "TU51"
# trip_update {
#   trip {
#     trip_id: "平日_17時42分_系統25051"
#   }
#   stop_time_update {
#     stop_sequence: 1
#     departure {
#       delay: 122
#     }
#   }
# }
#
# id: "TU52"
# trip_update {
#   trip {
#     trip_id: "平日_17時17分_系統47021"
#   }
#   stop_time_update {
#     stop_sequence: 12
#     departure {
#       delay: 434
#     }
#   }
# }
#
# id: "TU53"
# trip_update {
#   trip {
#     trip_id: "平日_17時10分_系統48212"
#   }
#   stop_time_update {
#     stop_sequence: 9
#     departure {
#       delay: 1034
#     }
#   }
# }
#
# id: "TU54"
# trip_update {
#   trip {
#     trip_id: "平日_17時20分_系統14021"
#   }
#   stop_time_update {
#     stop_sequence: 10
#     departure {
#       delay: 494
#     }
#   }
# }
#
# id: "TU55"
# trip_update {
#   trip {
#     trip_id: "平日_16時55分_系統42012"
#   }
#   stop_time_update {
#     stop_sequence: 22
#     departure {
#       delay: 1274
#     }
#   }
# }
#
# id: "TU56"
# trip_update {
#   trip {
#     trip_id: "平日_17時30分_系統38051"
#   }
#   stop_time_update {
#     stop_sequence: 5
#     departure {
#       delay: 194
#     }
#   }
# }
#
# id: "TU57"
# trip_update {
#   trip {
#     trip_id: "平日_17時02分_系統49022"
#   }
#   stop_time_update {
#     stop_sequence: 26
#     departure {
#       delay: 374
#     }
#   }
# }

# %% [markdown]
# #### 2-c) Pandas での読み込み

# %%
data = []
for entity in feed.entity:
    if not entity.HasField('trip_update'):
        continue
    
    trip_update = entity.trip_update

    for stop_time_update in trip_update.stop_time_update:    
        data.append({
            'trip_id': trip_update.trip.trip_id,
            'stop_sequence': stop_time_update.stop_sequence,
            'delay': stop_time_update.departure.delay
        })

df_trip_update = pd.DataFrame(data)
df_trip_update
# Out:
#               trip_id  stop_sequence  delay
# 0   平日_17時30分_系統22021              8    123
# 1   平日_16時44分_系統17032             25   1214
# 2   平日_17時15分_系統16031             11    734
# 3   平日_17時45分_系統12141              1      0
# 4   平日_16時49分_系統39082             30    794
# 5    平日_17時31分_系統8031              5    314
# 6   平日_17時20分_系統24011              9    554
# 7   平日_17時25分_系統15032             13    194
# 8   平日_17時15分_系統28102             10   1154
# 9   平日_17時44分_系統21081              1      0
# 10   平日_17時11分_系統6161             14    614
# 11  平日_17時38分_系統45021              6     74
# 12  平日_17時33分_系統49021              4    254
# 13  平日_17時40分_系統14022              2     74
# 14  平日_17時12分_系統22022             12    794
# 15  平日_16時55分_系統42051             26   1034
# 16  平日_17時00分_系統21031             18   1094
# 17  平日_17時28分_系統12081              6    434
# 18  平日_17時33分_系統33071             10     58
# 19  平日_17時38分_系統39181              3     76
# 20  平日_17時45分_系統80031              2      0
# 21  平日_17時07分_系統47032             41    494
# 22  平日_17時05分_系統41121             21    614
# 23  平日_16時40分_系統14021             32    434
# 24  平日_17時00分_系統80041             15    674
# 25  平日_17時25分_系統44374             11    254
# 26  平日_17時05分_系統17002             17    439
# 27  平日_16時41分_系統45021             26   1334
# 28   平日_17時15分_系統6162             18    434
# 29  平日_17時23分_系統12142             16     74
# 30  平日_17時37分_系統12062              5    194
# 31  平日_17時20分_系統16042             14    494
# 32  平日_17時18分_系統21172              7    614
# 33  平日_17時13分_系統39061             11    854
# 34  平日_17時09分_系統45181             13    554
# 35  平日_16時20分_系統14022             41    914
# 36  平日_17時24分_系統56061             17    194
# 37  平日_17時18分_系統37032             11    494
# 38  平日_17時27分_系統37031              4    434
# 39   平日_17時30分_系統1051             11     74
# 40   平日_17時20分_系統1021             14    434
# 41  平日_17時03分_系統15031             17    914
# 42  平日_17時20分_系統24012              8    434
# 43   平日_17時15分_系統1052             12    554
# 44  平日_17時43分_系統39122              1     32
# 45  平日_17時10分_系統41061             11    854
# 46   平日_17時18分_系統8032             13    292
# 47  平日_17時35分_系統35162              5    194
# 48  平日_17時03分_系統56022             16    854
# 49  平日_17時15分_系統33091              6   1094
# 50  平日_17時42分_系統39251              1      0
# 51  平日_17時42分_系統25051              1    122
# 52  平日_17時17分_系統47021             12    434
# 53  平日_17時10分_系統48212              9   1034
# 54  平日_17時20分_系統14021             10    494
# 55  平日_16時55分_系統42012             22   1274
# 56  平日_17時30分_系統38051              5    194
# 57  平日_17時02分_系統49022             26    374

# %% [markdown]
# ### 3. GTFSの読み込み
# #### 3-a) GTFSのダウンロードと展開

# %%
AOMORI_BUS_GTFS = 'https://api-public.odpt.org/api/v4/files/odpt/AomoriCity/AllLines.zip?date=20241201'

ZIP_PATH = 'tmp.zip'
TMPDIR_PATH = 'tmp/'

# %%
response = requests.get(AOMORI_BUS_GTFS)

if response.status_code == 200:
  with open(ZIP_PATH, 'wb') as f:
    f.write(response.content)

if not os.path.exists(TMPDIR_PATH):
  os.makedirs(TMPDIR_PATH)

with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
  zip_ref.extractall(TMPDIR_PATH)

# %% [markdown]
# #### 3-b) stops.txt / routes.txt / trips.txt / stop_times.txt の読み込み

# %%
df_stops = pd.read_csv(TMPDIR_PATH + 'stops.txt')
df_stops = df_stops[['stop_id', 'stop_name', 'stop_lat', 'stop_lon']]
df_stops
# Out:
#     stop_id   stop_name   stop_lat    stop_lon
# 0      1_01  青森駅 (降車専用)  40.828081  140.734870
# 1      1_02    青森駅 ②のりば  40.828131  140.734587
# 2      1_03    青森駅 ③のりば  40.828027  140.734523
# 3      1_04    青森駅 ④のりば  40.827924  140.734468
# 4      1_06    青森駅 ⑥のりば  40.828250  140.734850
# ..      ...         ...        ...         ...
# 817  864_01     大野中央公園前  40.800569  140.726947
# 818  867_01          安田  40.804843  140.708184
# 819  867_02          安田  40.805341  140.708471
# 820  263_01      総合体育館前  40.813405  140.746322
# 821  263_02      総合体育館前  40.813306  140.746163
#
# [822 rows x 4 columns]

# %%
df_routes = pd.read_csv(TMPDIR_PATH + 'routes.txt')
df_routes = df_routes[['route_id', 'route_short_name', 'route_long_name']]
df_routes
# Out:
#           route_id route_short_name  route_long_name
# 0     国道・古川線(1021)        A1 国道・古川線              NaN
# 1    造道・八重田線(1022)      C10 造道・八重田線              NaN
# 2    造道・八重田線(1041)      C12 造道・八重田線              NaN
# 3     国道・古川線(1051)        A1 国道・古川線              NaN
# 4    造道・八重田線(1052)      C10 造道・八重田線              NaN
# ..             ...              ...              ...
# 251  沖館・新田線(42052)       W53 沖館・新田線              NaN
# 252  浪館中央循環(82031)           浪館中央循環              NaN
# 253  浪館中央循環(82032)           浪館中央循環              NaN
# 254   旭町通り線(18001)        M36 旭町通り線              NaN
# 255  国道・古川線(18002)        A1 国道・古川線              NaN
#
# [256 rows x 3 columns]

# %%
df_trips = pd.read_csv(TMPDIR_PATH + 'trips.txt')
df_trips = df_trips[['route_id', 'service_id', 'trip_id', 'trip_headsign']]
df_trips
# Out:
#             route_id service_id             trip_id         trip_headsign
# 0       国道・古川線(1051)         平日    平日_05時50分_系統1051         A1青森駅（国道・古川線）
# 1     造道・八重田線(39202)         平日   平日_06時00分_系統39202  C10県病→東部〈営〉（造道・八重田線）
# 2      石江・新城線(39081)         平日   平日_06時00分_系統39081      T50西部〈営〉（石江・新城線）
# 3       浪館通り線(35141)         平日   平日_06時05分_系統35141       P40慈恵会病院（浪館通り線）
# 4       国道・古川線(1051)         平日    平日_06時07分_系統1051         A1青森駅（国道・古川線）
# ...              ...        ...                 ...                   ...
# 1607   石江・新城線(16052)        土日祝  土日祝_21時45分_系統16052      T50西部〈営〉（石江・新城線）
# 1608   造道・八重田線(1052)        土日祝   土日祝_21時45分_系統1052  C10古川→東部〈営〉（造道・八重田線）
# 1609     観光通り線(9031)        土日祝   土日祝_21時52分_系統9031        K32幸畑団地（観光通り線）
# 1610   石江・新城線(39051)        土日祝  土日祝_21時52分_系統39051      T50西部〈営〉（石江・新城線）
# 1611   造道・八重田線(1052)        土日祝   土日祝_22時05分_系統1052  C10古川→東部〈営〉（造道・八重田線）
#
# [1612 rows x 4 columns]

# %%
df_stop_times = pd.read_csv(TMPDIR_PATH + 'stop_times.txt')
df_stop_times = df_stop_times[['trip_id', 'arrival_time', 'departure_time', 'stop_id', 'stop_sequence', 'stop_headsign']]
df_stop_times
# Out:
#                  trip_id arrival_time departure_time stop_id  stop_sequence  \
# 0       平日_05時50分_系統1051     05:50:00       05:50:00  726_01              1
# 1       平日_05時50分_系統1051     05:51:00       05:51:00   53_01              2
# 2       平日_05時50分_系統1051     05:51:00       05:51:00   52_01              3
# 3       平日_05時50分_系統1051     05:52:00       05:52:00   51_01              4
# 4       平日_05時50分_系統1051     05:53:00       05:53:00   50_01              5
# ...                  ...          ...            ...     ...            ...
# 44666  土日祝_22時05分_系統1052     22:30:00       22:30:00   50_02             21
# 44667  土日祝_22時05分_系統1052     22:31:00       22:31:00   51_02             22
# 44668  土日祝_22時05分_系統1052     22:31:00       22:31:00   52_02             23
# 44669  土日祝_22時05分_系統1052     22:32:00       22:32:00   53_02             24
# 44670  土日祝_22時05分_系統1052     22:34:00       22:39:00  726_04             25
#
#              stop_headsign
# 0          ♿ A1青森駅（国道・古川線）
# 1          ♿ A1青森駅（国道・古川線）
# 2          ♿ A1青森駅（国道・古川線）
# 3          ♿ A1青森駅（国道・古川線）
# 4          ♿ A1青森駅（国道・古川線）
# ...                    ...
# 44666  ♿ C10東部〈営〉（造道・八重田線）
# 44667  ♿ C10東部〈営〉（造道・八重田線）
# 44668  ♿ C10東部〈営〉（造道・八重田線）
# 44669  ♿ C10東部〈営〉（造道・八重田線）
# 44670  ♿ C10東部〈営〉（造道・八重田線）
#
# [44671 rows x 6 columns]

# %% [markdown]
# #### 3-c) 特定の路線での絞り込み

# %%
df_routes_a1 = df_routes[df_routes['route_short_name'] == 'A1 国道・古川線']
df_trips_a1 = df_routes_a1.merge(df_trips)
df_trips_a1
# Out:
#           route_id route_short_name  route_long_name service_id  \
# 0     国道・古川線(1021)        A1 国道・古川線              NaN         平日
# 1     国道・古川線(1021)        A1 国道・古川線              NaN         平日
# 2     国道・古川線(1021)        A1 国道・古川線              NaN         平日
# 3     国道・古川線(1021)        A1 国道・古川線              NaN         平日
# 4     国道・古川線(1021)        A1 国道・古川線              NaN         平日
# ..             ...              ...              ...        ...
# 432  国道・古川線(12212)        A1 国道・古川線              NaN        土日祝
# 433  国道・古川線(16152)        A1 国道・古川線              NaN         平日
# 434  国道・古川線(16152)        A1 国道・古川線              NaN        土日祝
# 435  国道・古川線(16152)        A1 国道・古川線              NaN        土日祝
# 436  国道・古川線(18002)        A1 国道・古川線              NaN        土日祝
#
#                 trip_id       trip_headsign
# 0      平日_06時28分_系統1021       A1青森駅（国道・古川線）
# 1      平日_06時59分_系統1021       A1青森駅（国道・古川線）
# 2      平日_07時30分_系統1021       A1青森駅（国道・古川線）
# 3      平日_07時47分_系統1021       A1青森駅（国道・古川線）
# 4      平日_08時15分_系統1021       A1青森駅（国道・古川線）
# ..                  ...                 ...
# 432  土日祝_09時10分_系統12212  A1中央大橋→青森駅（国道・古川線）
# 433   平日_13時00分_系統16152  A1中央大橋→青森駅（国道・古川線）
# 434  土日祝_13時04分_系統16152  A1中央大橋→青森駅（国道・古川線）
# 435  土日祝_18時22分_系統16152  A1中央大橋→青森駅（国道・古川線）
# 436  土日祝_13時08分_系統18002    A1旭町→青森駅（国道・古川線）
#
# [437 rows x 6 columns]

# %% [markdown]
# #### 3-d) 特定の路線上のルート更新情報を確認

# %%
df_trip_update_a1 = df_trip_update.merge(df_trips_a1)
df_trip_update_a1
# Out:
#               trip_id  stop_sequence  delay       route_id route_short_name  \
# 0   平日_16時44分_系統17032             25   1214  国道・古川線(17032)        A1 国道・古川線
# 1   平日_17時15分_系統28102             10   1154  国道・古川線(28102)        A1 国道・古川線
# 2   平日_17時12分_系統22022             12    794  国道・古川線(22022)        A1 国道・古川線
# 3   平日_17時07分_系統47032             41    494  国道・古川線(47032)        A1 国道・古川線
# 4   平日_17時25分_系統44374             11    254  国道・古川線(44374)        A1 国道・古川線
# 5   平日_17時05分_系統17002             17    439  国道・古川線(17002)        A1 国道・古川線
# 6    平日_17時15分_系統6162             18    434   国道・古川線(6162)        A1 国道・古川線
# 7   平日_17時20分_系統16042             14    494  国道・古川線(16042)        A1 国道・古川線
# 8   平日_17時24分_系統56061             17    194  国道・古川線(56061)        A1 国道・古川線
# 9   平日_17時18分_系統37032             11    494  国道・古川線(37032)        A1 国道・古川線
# 10   平日_17時30分_系統1051             11     74   国道・古川線(1051)        A1 国道・古川線
# 11   平日_17時20分_系統1021             14    434   国道・古川線(1021)        A1 国道・古川線
# 12  平日_17時20分_系統24012              8    434  国道・古川線(24012)        A1 国道・古川線
# 13  平日_17時35分_系統35162              5    194  国道・古川線(35162)        A1 国道・古川線
#
#     route_long_name service_id        trip_headsign
# 0               NaN         平日   A1観光通り→青森駅（国道・古川線）
# 1               NaN         平日     A1旭町→青森駅（国道・古川線）
# 2               NaN         平日   A1観光通り→青森駅（国道・古川線）
# 3               NaN         平日        A1青森駅（国道・古川線）
# 4               NaN         平日        A1青森駅（国道・古川線）
# 5               NaN         平日   A1中央大橋→青森駅（国道・古川線）
# 6               NaN         平日   A1小柳団地→青森駅（国道・古川線）
# 7               NaN         平日     A1旭町→青森駅（国道・古川線）
# 8               NaN         平日  A1東バイパス→青森駅（国道・古川線）
# 9               NaN         平日        A1青森駅（国道・古川線）
# 10              NaN         平日        A1青森駅（国道・古川線）
# 11              NaN         平日        A1青森駅（国道・古川線）
# 12              NaN         平日   A1観光通り→青森駅（国道・古川線）
# 13              NaN         平日        A1青森駅（国道・古川線）

# %%
df_stops_names = df_stops[['stop_id', 'stop_name']]
df_trip_update_a1.merge(df_stop_times).merge(df_stops_names)
# Out:
#               trip_id  stop_sequence  delay       route_id route_short_name  \
# 0   平日_16時44分_系統17032             25   1214  国道・古川線(17032)        A1 国道・古川線
# 1   平日_17時15分_系統28102             10   1154  国道・古川線(28102)        A1 国道・古川線
# 2   平日_17時12分_系統22022             12    794  国道・古川線(22022)        A1 国道・古川線
# 3   平日_17時07分_系統47032             41    494  国道・古川線(47032)        A1 国道・古川線
# 4   平日_17時25分_系統44374             11    254  国道・古川線(44374)        A1 国道・古川線
# 5   平日_17時05分_系統17002             17    439  国道・古川線(17002)        A1 国道・古川線
# 6    平日_17時15分_系統6162             18    434   国道・古川線(6162)        A1 国道・古川線
# 7   平日_17時20分_系統16042             14    494  国道・古川線(16042)        A1 国道・古川線
# 8   平日_17時24分_系統56061             17    194  国道・古川線(56061)        A1 国道・古川線
# 9   平日_17時18分_系統37032             11    494  国道・古川線(37032)        A1 国道・古川線
# 10   平日_17時30分_系統1051             11     74   国道・古川線(1051)        A1 国道・古川線
# 11   平日_17時20分_系統1021             14    434   国道・古川線(1021)        A1 国道・古川線
# 12  平日_17時20分_系統24012              8    434  国道・古川線(24012)        A1 国道・古川線
# 13  平日_17時35分_系統35162              5    194  国道・古川線(35162)        A1 国道・古川線
#
#     route_long_name service_id        trip_headsign arrival_time  \
# 0               NaN         平日   A1観光通り→青森駅（国道・古川線）     17:22:00
# 1               NaN         平日     A1旭町→青森駅（国道・古川線）     17:24:00
# 2               NaN         平日   A1観光通り→青森駅（国道・古川線）     17:28:00
# 3               NaN         平日        A1青森駅（国道・古川線）     17:34:00
# 4               NaN         平日        A1青森駅（国道・古川線）     17:39:00
# 5               NaN         平日   A1中央大橋→青森駅（国道・古川線）     17:34:00
# 6               NaN         平日   A1小柳団地→青森駅（国道・古川線）     17:36:00
# 7               NaN         平日     A1旭町→青森駅（国道・古川線）     17:35:00
# 8               NaN         平日  A1東バイパス→青森駅（国道・古川線）     17:40:00
# 9               NaN         平日        A1青森駅（国道・古川線）     17:33:00
# 10              NaN         平日        A1青森駅（国道・古川線）     17:41:00
# 11              NaN         平日        A1青森駅（国道・古川線）     17:35:00
# 12              NaN         平日   A1観光通り→青森駅（国道・古川線）     17:35:00
# 13              NaN         平日        A1青森駅（国道・古川線）     17:39:00
#
#    departure_time stop_id         stop_headsign  stop_name
# 0        17:22:00    3_05         A1青森駅（国道・古川線）    古川 ⑤のりば
# 1        17:24:00  272_02       ♿ A1青森駅（国道・古川線）        甲田町
# 2        17:28:00  240_02       ♿ A1青森駅（国道・古川線）   サンロード青森前
# 3        17:34:00  416_02       ♿ A1青森駅（国道・古川線）    沖館消防分署前
# 4        17:39:00  349_02       ♿ A1青森駅（国道・古川線）       西上古川
# 5        17:34:00  734_02  ♿ A1中央大橋→青森駅（国道・古川線）  シーナシーナ青森前
# 6        17:36:00  180_01      A1桜川→青森駅（国道・古川線）      佃中学校前
# 7        17:35:00  291_02    ♿ A1旭町→青森駅（国道・古川線）     やはぎ宿舎前
# 8        17:40:00   12_01         A1青森駅（国道・古川線）      合浦公園前
# 9        17:33:00   17_01         A1青森駅（国道・古川線）      新町一丁目
# 10       17:41:00   46_01       ♿ A1青森駅（国道・古川線）   県立中央病院通り
# 11       17:35:00   10_01       ♿ A1青森駅（国道・古川線）      栄町二丁目
# 12       17:35:00  239_02       ♿ A1青森駅（国道・古川線）  みちのく銀行本店前
# 13       17:39:00   28_02       ♿ A1青森駅（国道・古川線）        下安田
